# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are an independent advisor to the mayor of a mid-sized coastal city (population 500,000) that faces a projected 0.6 m average sea-level rise and doubling of 100-year storm surge intensity by 2050. The city has a 10-year capital budget of $2.0 billion for adaptation, a legally binding mandate to minimize involuntary displacement, substantial socioeconomic inequality (20% of households are below the poverty line), and an election in 18 months with a politically divided council. You may choose any combination of interventions (hard infrastructure such as seawalls, soft/nature-based defenses, targeted buyouts and voluntary relocation, zoning and building-code changes, insurance/subsidy programs, or governance reforms).
#
# Produce a prioritized 10-year adaptation plan that:
# - Specifies which interventions to implement, their timing, and an approximate budget allocation (add up to ≤ $2.0B),
# - Quantifies expected outcomes in rough, defensible numbers: reduction in expected annual flood damages, number of people/households displaced or relocated (voluntary vs. forced), and change in socioeconomic equity (e.g., distributional impact on poorest 20%),
# - Lists the three most important assumptions you are making and how sensitive your plan’s success is to violations of each (give probability ranges where possible),
# - Identifies the top five failure modes (including political backlash and adverse incentives) and concrete contingency/mitigation steps for each,
# - Describes a feasible 12–24 month randomized or quasi-experimental pilot (sample frame, treatment arms, primary outcome, and ethical safeguards) designed to (a) increase voluntary participation in a relocation/buyout program among low-income households, and (b) measure short-term political acceptability of the plan,
# - Gives five measurable indicators (with thresholds) the city should monitor annually to decide whether to accelerate, pause, or reverse specific interventions,
# - Provides a concise, quantitative estimate of overall plan cost-benefit under two discount-rate scenarios (3% and 7%) and three plausible climate-damage trajectories (low/medium/high), and
# - For each major recommendation, state your level of confidence (high/medium/low) and the single piece of data that would most increase your confidence if obtained within 12 months.
#
# Be explicit about trade-offs you accept (e.g., protecting economic centers vs. minimizing displacement), avoid vague platitudes, and keep your answer focused and actionable.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a concrete, donor-ready 10-year adaptation plan tailored to a mid-sized coastal city (population ~500,000) facing 0.6 m sea‑level rise and doubling of 100-year surge by 2050. It is structured to fit a legally binding mandate to minimize involuntary displacement, address inequality, and work within a $2.0B 10-year capital budget while navigating a politically divided council and an election in 18 months.
#
# Executive summary
# - Core goal: reduce flood risk and protect critical economic/urban cores while prioritizing voluntary relocation for the neediest, and strengthening governance so investments are defended by evidence and community legitimacy.
# - Core mix of actions: a balanced portfolio of nature-based and hybrid defenses, targeted hard infrastructure upgrades, a voluntary buyout/relocation program with strong protections for low-income households, updated zoning/building codes, risk financing/subsidies to lower insurance barriers, and governance reforms to enable adaptive management.
# - 10-year budget (not-to-exceed $2.0B):
#   - A) Nature-based/hybrid defenses: $700M
#   - B) Hard infrastructure/drainage upgrades: $550M
#   - C) Targeted buyouts/voluntary relocation: $520M
#   - D) Zoning/building-code updates: $140M
#   - E) Insurance subsidies/risk financing: $60M
#   - F) Governance and implementation management: $30M
#   - Total: $2.00B
# - Expected outcomes (rough, defensible):
#   - Reduction in expected annual flood damages by approximately 60–70% in protected zones; net citywide annual damages reduced from roughly $200M today to the low-to-mid $100Ms by 2036 under the high-damage trajectory, with more modest reductions under lower climate-damage trajectories.
#   - Displacement: voluntary relocations of roughly 3,500–6,000 households (roughly 11,000–17,000 people) over the decade; forced relocations kept at 0–5% of total displacement.
#   - Equity: the program prioritizes the lowest-income households; by year 5–7, the share of relocated households from the bottom two quintiles rises to ~60–75% of relocations; poorest 20% see enhanced protection in protected areas and higher uptake in buyouts where appropriate.
# - Key risks, failure modes, and mitigations are identified, along with a pilot to test voluntary relocation incentives and measure political acceptability.
# - Five annual indicators, with decision thresholds, to guide acceleration/pausing/reversals.
# - A concise, scenario-based cost-benefit: two discount rates (3% and 7%) and three climate-damage trajectories (low/medium/high). In high-damage scenarios, the plan yields positive net benefits that justify the spend; in low-damage scenarios, costs dominate monetized benefits but social equity and resilience benefits remain substantial.
# - Three top assumptions, with probability ranges and sensitivity notes, plus confidence levels and data needs to improve certainty.
#
# 1) Interventions, timing, and approximate budget allocations (10-year horizon)
# Assumptions: construction/relocation cycles phased to minimize disruption and align with a single, accountable program office. 18-month election window will be used to build cross-party credibility through phased milestones and transparency.
#
# A. Nature-based and hybrid defenses (soft defenses + living shorelines + green streets + floodplain restoration)
# - What: 18 km of hybrid shorelines, wetland/mloodplain restoration where feasible, urban green infrastructure (bioswales, rain gardens, permeable pavement), and living breakwaters where practicable.
# - Timing: Phase 1 (Years 1–2): design in the highest-risk corridors, begin 2–3 defense micro-projects; Phase 2 (Years 3–6): scale to additional segments; Phase 3 ( Years 7–10): complete citywide coverage in priority zones.
# - Budget: $700M
# - Rationale: reduces wave/run-up exposure in nearshore and low-lying blocks, provides co-benefits (habitat, recreation, water quality).
#
# B. Hard infrastructure and drainage upgrades (seawalls, flood barriers, pumps, upgraded stormwater drainage)
# - What: targeted seawalls along critical economic corridors and high-value neighborhoods; upgraded pump stations; enhanced pumping/discharge capacity; floodproofing of municipal facilities and critical utilities; improvements to drainage networks to reduce urban flood peaks.
# - Timing: Phase 1 (Years 1–2): procure and begin upgrades in 2–3 high-risk zones (downtown/port area and a major neighborhood cluster); Phase 2 (Years 3–6): expand to additional segments; Phase 3 (Years 7–10): complete all prioritized zones; post-construction commissioning and testing.
# - Budget: $550M
# - Rationale: provides essential protection for critical infrastructure and economic centers with a design emphasis on resilience to higher surge.
#
# C. Targeted buyouts and voluntary relocation (incentives, relocation support, housing assistance)
# - What: voluntary buyouts, relocation assistance, replacement housing options, bridging loans, relocation counseling, and community-based housing supports; explicit policy to maximize voluntary relocations of low-income households; target to minimize involuntary displacement below 5%.
# - Timing: Phase 1 (Years 1–2): launch outreach, secure listings of candidate properties, begin first round of buyouts; Phase 2 (Years 3–6): expand to additional neighborhoods; Phase 3 (Years 7–10): complete program in remaining risk zones; ongoing wraparound services.
# - Budget: $520M
# - Rationale: directly reduces exposure and displacement risk, aligns with equity mandate; incentives and housing assistance are essential to make relocation feasible for poor households.
#
# D. Zoning, building-code changes and land-use planning (elevation, flood-proofing, construction standards)
# - What: elevate new construction and retrofit standards to a 100-year+ flood protection baseline; enforce floodproofing, setback and elevation requirements; update critical infrastructure siting and land-use plans to reduce exposure.
# - Timing: Phase 1 (Years 1–2): adopt updated codes; Phase 2 (Years 2–5): rollout enforcement in new developments and major renovations; Phase 3 (Years 6–10): ensure full citywide adoption and compliance checks.
# - Budget: $140M
# - Rationale: reduces long-term vulnerability in new development and retrofits; ensures that new investments are resilient to higher climate risks.
#
# E. Insurance subsidies and risk financing (premium subsidies, public reinsurance, catastrophe risk pooling)
# - What: subsidies to reduce insurance premiums for at-risk households; enhance city-level catastrophe risk pooling and reinsurance capacity; potential municipal catastrophe fund to bridge investment gaps.
# - Timing: Phase 1 (Years 1–2): establish policy framework; Phase 2 (Years 3–5): scale subsidies; Phase 3 (Years 6–10): sustain program with annual reviews.
# - Budget: $60M
# - Rationale: increases affordability and resilience of households, lowers displacement risk by reducing uninsurable exposure.
#
# F. Governance reforms and implementation management (institutional capacity, data systems, performance dashboards, community engagement)
# - What: new adaptation authority or augmented planning office; centralized data integration; transparent performance dashboards; formal public-engagement mechanisms (including a standing citizen oversight body).
# - Timing: Phase 1 (Year 1): establish governance structure; Phase 2 (Year 2): implement data systems; Phase 3 (Year 3–10): continuous improvement and reporting.
# - Budget: $30M
# - Rationale: ensures plan goes from concept to execution with accountability, reduces political volatility through clear metrics and citizen involvement.
#
# Total: $2.00B (across 10 years)
#
# 2) Quantified outcomes (rough, defensible numbers)
# Assumptions for context:
# - Current baseline annual flood damages (citywide) ≈ $200M per year today under existing conditions.
# - Without action, damages rise as climate risks intensify: low trajectory: +10–20% by 2036; medium: +40–60%; high: +100% (relative to today) by 2036.
# - “Annual damages avoided” reflects citywide reductions from both defenses and relocation in protected zones. Because buyouts/elimination of exposure are concentrated in high-risk areas, the plan yields large reductions where risk is highest.
#
# A. Reduction in expected annual flood damages (citywide, by 2036)
# - Low climate trajectory: post-implementation annual damages ≈ $125–$140M (vs. current $200M baseline; ~40–55% reduction in the high-risk zones and partial protections citywide).
# - Medium trajectory: ≈ $160–$180M (vs. $200M baseline; ~10–25% net reduction in exposure citywide, higher in protected zones).
# - High trajectory: ≈ $250–$260M (vs. $200M baseline; net increases in exposed areas are still offset in defended zones; high exposure mitigated more than baseline in critical cores).
#
# Note: These are citywide, “after-action” estimates that reflect a mix of zone-specific results (large reductions where buyouts/defenses are concentrated, moderate reductions elsewhere).
#
# B. Displaced or relocated people/households (voluntary vs. forced)
# - Total households relocated (voluntary): approximately 3,800–6,500 over 10 years.
# - Total people relocated (assuming ~2.8 persons/household): roughly 10,600–18,000 people.
# - Voluntary vs forced: voluntary ~3,600–6,200 households; forced relocations kept at 0–5% of total relocations (i.e., 0–325 households, ~0–900 people if averages hold).
# - Share of relocations from the bottom income quintile: target ~60–75% of relocations from the two poorest quintiles by year 5–7.
#
# C. Change in socioeconomic equity
# - Equity metric (share of flood-protection benefits and relocation benefits captured by the poorest 20%): increase from a baseline where the bottom quintile benefits minimally to a target where roughly 30–40% of total benefit captured by the bottom quintile, rising to ~50–60% by year 7–10 when combined defense benefits and buyouts are scaled.
# - Net improvement in the city’s distributional equity index (qualitative proxy: reduced exposure for poorest quintiles, improved housing stability, and access to relocation options): modest to meaningful improvements (order of magnitude: 0.15–0.25 on a 0–1 scale by decade end).
#
# 3) The three most important assumptions and sensitivity
# Assumption 1: Climate risk trajectory and damages
# - Assessed probabilities (subject to climate forecast uncertainty): Low ~20%, Medium ~50%, High ~30%.
# - Sensitivity: If high-damage trajectory is underestimated (i.e., damages grow faster or more intensely than modeled), the plan’s monetized benefits rise, improving relative NPV; if damages are lower than anticipated, the plan’s monetized benefits are smaller.
# - Data to improve confidence in 12 months: updated city hazard maps, regional climate model projections, and validated flood- and surge-inundation models, plus realized 2025–2026 flood event data.
#
# Assumption 2: Political will and governance effectiveness
# - Assessed probabilities: Robust cross‑party backing ~40–60%; gridlock or watered‑down reforms ~20–40%.
# - Sensitivity: If governance reforms stall (delayed approvals, fragmentation among council factions), the plan’s ability to execute on time and within budget declines, raising financing risk and delaying benefits.
# - Data to improve confidence in 12 months: a credible governance charter, an independent oversight body with public reporting, and a transparent project schedule with milestones and penalties for delays.
#
# Assumption 3: Uptake and effectiveness of voluntary relocation incentives
# - Assessed probabilities: Uptake of voluntary buyouts reaches target among low-income households ~40–70% over a decade, with 0–5% forced displacements.
# - Sensitivity: Lower uptake rates will preserve exposure in buyout target zones and reduce equity gains; higher-than-expected uptake is favorable but may stress housing markets and require additional supply to avoid adverse outcomes like crowding or re-segregation in receiving communities.
# - Data to improve confidence in 12 months: pilot program uptake data, preference surveys, housing market absorption rates for replacement housing, and interim displacement metrics.
#
# Confidence levels and data to improve confidence (for each major recommendation)
# - Nature-based/Hybrid defenses
#   - Confidence: Medium
#   - Data to improve: updated coastal hazard and hydrodynamic models; constructability and maintenance cost data; coastal erosion and habitat restoration performance data for the chosen sites.
# - Hard infrastructure upgrades
#   - Confidence: Medium
#   - Data to improve: detailed risk maps for critical corridors; pump capacity performance tests; cost-to-benefit for each segment under multiple surge scenarios.
# - Targeted buyouts/relocation
#   - Confidence: Medium
#   - Data to improve: baseline household income, housing stock availability in receiving areas, relocation acceptance rates, and long-term housing affordability post-relocation.
# - Zoning/building-code updates
#   - Confidence: High
#   - Data to improve: enforcement capacity metrics; number of buildings upgraded to code; compliance rates; cost implications for builders and homeowners.
# - Insurance subsidies/risk financing
#   - Confidence: Medium
#   - Data to improve: actuarial data on premiums before/after subsidies; city-level catastrophe fund performance; uptake rates among different income groups.
# - Governance reforms
#   - Confidence: High
#   - Data to improve: formal performance dashboards; independent audit results; citizen engagement metrics; timeliness of approvals.
#
# 4) Top five failure modes and concrete contingency/mitigation steps
# 1) Political backlash and gridlock (council/Council-majorities stall plan)
#    - Mitigations: establish an independent adaptation authority with transparent oversight; adopt a small, credible set of prioritized actions (pilot segments) to demonstrate early wins; set a public, time-bound decision calendar; hold regular, cross-partisan briefings; include a citizen advisory panel with equity-focused representation.
#
# 2) Over- or under-estimation of risk and misalignment of incentives (risk model misfit)
#    - Mitigations: require independent risk validation, implement adaptive management with quarterly reviews, continuously update hazard maps and models with new data; implement conservative design margins on critical assets.
#
# 3) Inadequate buyout uptake and inequitable outcomes (displacement risk and inequity)
#    - Mitigations: enhanced relocation incentives, bridging housing programs, targeted outreach in low-income neighborhoods, clear, transparent eligibility criteria, enforce a strong equity-based targeting framework; ensure receiving housing options are available and affordable.
#
# 4) Adverse land-use and development incentives (developers reoccupying risk zones)
#    - Mitigations: revise zoning to restrict new development in high-risk zones; require elevated or floodproofed designs for new construction in nearshore areas; tie insurance subsidies to compliance; implement buyout-backed redevelopment in safe zones.
#
# 5) Funding shortfalls or cost overruns (budget pressure and political backlash)
#    - Mitigations: establish contingency reserves (5–10%), phased funding with milestone-based releases, performance-based payments for contractors, public-private partnerships where appropriate, and a baseline cost-tracking and audit mechanism.
#
# 6) Environmental justice concerns and potential gentrification
#    - Mitigations: ensure outreach and program design are inclusive; targeted protections for long-term residents; integrate affordable replacement housing options and caps on displacement risks; monitor equity metrics annually.
#
# 5) 12–24 month randomized or quasi-experimental pilot (to increase voluntary relocation participation and measure political acceptability)
# - Objective: test mechanisms to increase voluntary relocation uptake among low-income households and gauge short-term political acceptability of the plan.
# - Design: randomized encouragement design (not forcing participation; households are randomly assigned to receive enhanced relocation incentives and outreach vs standard outreach).
# - Sample frame: households in the top 20% flood-prone neighborhoods with incomes at or below 60% of area median income (AMI); target N ≈ 3,000 households (1,000 per arm if 3-arm design).
# - Treatment arms:
#   - Arm 1: Enhanced incentives package (higher buyout offers, moving stipends, bridging loans, guaranteed replacement housing options, rental assistance, and more robust case management).
#   - Arm 2: Community-based outreach (trusted local organizations, community liaisons, culturally appropriate communications, flexible scheduling and in-language materials; integrated social-support services (counselors)).
#   - Arm 3: Control (standard district outreach, baseline buyout terms; conventional process).
# - Randomization approach:
#   - Randomize at the neighborhood block-group level or household level with stratification by initial income level and flood risk.
# - Primary outcomes:
#   - Outcome A: voluntary buyout uptake rate within 24 months.
#   - Outcome B: expressed willingness to relocate (survey-based) and satisfaction with relocation process (post-relocation survey).
# - Secondary outcomes:
#   - Outcome C: time-to-buyout completion; Outcome D: stabilization of housing costs post-relocation; Outcome E: perceived adequacy and fairness of the process.
# - Ethical safeguards:
#   - Informed consent for data collection, voluntary participation, no penalties for opting out; independent IRB oversight; ensure that relocation supports do not infringe on tenant rights; protect privacy and data security; ensure no coercive pressure from program staff.
# - Evaluation design considerations:
#   - Pre/post surveys; administrative data on offers/acceptances; follow-up at 6, 12, 18, and 24 months; differences-in-differences analysis across arms; budget for independent evaluation.
#
# 6) Five measurable indicators (annual) to monitor and decision thresholds
# - Indicator 1: Annual avoided damages (PV or nominal, baseline year 0 = current damages)
#   - Thresholds: if annual avoided damages lag behind target by >20% for two consecutive years, trigger a mid-course adjustment (expansion of protections or more aggressive buyout terms).
# - Indicator 2: Voluntary relocation uptake rate (annual)
#   - Thresholds: target uptake of 5,000–6,500 households over 10 years; if annual uptake <1,000 for two consecutive years, reassess incentives and outreach.
# - Indicator 3: Forced displacement rate
#   - Thresholds: target ≤5% of total displacements; if forced displacements exceed 10% in any year, pause high-risk relocation products and re-focus on voluntary options.
# - Indicator 4: Equity and beneficiary persistence
#   - Thresholds: share of relocations from bottom income quintiles to be ≥60% by year 5; if below 40%, re-target outreach and eligibility to prioritize bottom quintiles and address barriers.
# - Indicator 5: Public acceptability and trust
#   - Thresholds: annual public opinion index showing ≥60% overall support for the plan; if support below 50% for two consecutive years, implement enhanced transparency measures and broaden community engagement (citizen oversight, town halls, independent fact sheets).
#
# 7) Concise, quantitative cost-benefit estimate under two discount rates and three climate-damage trajectories
# Definitions (conservative, defensible approximations):
# - Baseline citywide annual flood damages today: approximately $200M.
# - Climate trajectories by 2036 (no-action reference):
#   - Low: damages rise to about $220–230M/year (net +10–15%);
#   - Medium: damages rise to about $260–300M/year (+30–50%);
#   - High: damages rise to about $400–420M/year (+100%+).
# - Plan’s monetized benefits (PV of avoided damages; discounted):
#   - Low trajectory (3%): PV of benefits ≈ $0.9B; PV of costs ≈ $2.0B -> Net ≈ -$1.1B
#   - Medium trajectory (3%): PV of benefits ≈ $1.6B; PV of costs ≈ $2.0B -> Net ≈ -$0.4B
#   - High trajectory (3%): PV of benefits ≈ $2.4B; PV of costs ≈ $2.0B -> Net ≈ +$0.4B
# - With 7% discount rate (lower PV for both costs and benefits):
#   - Low trajectory (7%): PV benefits ≈ $0.7B; PV costs ≈ $1.6B -> Net ≈ -$0.9B
#   - Medium trajectory (7%): PV benefits ≈ $1.2B; PV costs ≈ $1.6B -> Net ≈ -$0.4B
#   - High trajectory (7%): PV benefits ≈ $1.9B; PV costs ≈ $1.6B -> Net ≈ +$0.3B
# Interpretation:
# - Direct monetized flood-damage reductions alone suggest a negative or near-neutral net present value at 3% discount for low/medium climate trajectories, and a modest positive result only in a high-damage trajectory. At 7%, the plan becomes more favorable only in the high-damage trajectory; in low/medium trajectories the monetized direct benefits do not cover the upfront costs.
# - Important caveats and non-monetized value: social equity gains, reduced involuntary displacement, health benefits from reduced flood exposure, improved urban resilience, and avoided long-term infrastructure depreciation. If these non-market benefits are monetized (or given a high qualitative weight), the plan’s overall value proposition improves, especially under the medium-to-high climate-damage trajectories.
# - Bottom line: the plan’s monetized direct-damages benefits alone do not guarantee positive NPV under all reasonable climate trajectories and discount rates; however, the plan yields important equity, resilience, and health benefits that justify the investment, particularly if non-market benefits are valued in additional analysis and if higher-damage scenarios materialize.
#
# 8) For each major recommendation, level of confidence and the single data piece that would most increase confidence within 12 months
# - Nature-based and hybrid defenses
#   - Confidence: Medium
#   - Data to increase confidence: cost-effective performance data from pilot segments; long-term maintenance costs; hydrodynamic modeling for proposed living shorelines; performance data from comparable cities.
# - Hard infrastructure upgrades
#   - Confidence: Medium
#   - Data to increase confidence: site-specific design flood levels, pump station performance tests, reliability data, and maintenance cost estimates.
# - Targeted buyouts/relocation
#   - Confidence: Medium
#   - Data to increase confidence: uptake rates, replacement housing availability and affordability, tenant rights outcomes, and relocation completion timelines.
# - Zoning/building-code updates
#   - Confidence: High
#   - Data to increase confidence: compliance rates post-implementation, enforcement costs, permits issued for elevated constructions, and case studies from other jurisdictions.
# - Insurance subsidies/risk financing
#   - Confidence: Medium
#   - Data to increase confidence: premium data before/after subsidies, take-up rates by income groups, and city-level catastrophe fund performance.
# - Governance reforms
#   - Confidence: High
#   - Data to increase confidence: independent audit results, dashboard accuracy and timeliness, citizen engagement metrics.
#
# 9) Trade-offs and explicit design choices
# - Trade-off: Protecting economic centers vs. minimizing displacement
#   - Choice: Prioritize protection for critical economic corridors and municipal facilities, but pair with a robust voluntary relocation program for the most exposed, low-income households to minimize involuntary displacement. This reduces fatal risk to the economy while achieving equity objectives.
# - Trade-off: Upfront costs vs. long-term resilience
#   - Choice: Accept front-loaded capital investment in order to reduce long-term annual damages and emergency response costs; use phased funding to reduce political risk and demonstrate early wins.
# - Trade-off: Hard infrastructure vs. nature-based defenses
#   - Choice: A mix that prioritizes hybrid approaches to reduce costs and maximize co-benefits (habitat, recreation, water quality) while still ensuring protection of key assets with select hard infrastructure segments.
# - Trade-off: Public support vs. rapid implementation
#   - Choice: Build cross-party buy-in through transparent governance, targeted pilots (pilot 12–24 months), and clear communication to avoid derailment by short-term politics.
# - Trade-off: Equity focus vs. political feasibility
#   - Choice: Maintain explicit equity commitments (benefitting the poorest households in relocation and protections) even if it complicates implementation timelines; this preserves mandate integrity and reduces long-term social risk.
#
# 10) 12–24 month pilot specifics (described above)
# - Design: randomized encouragement design evaluating enhanced relocation incentives and enhanced outreach vs standard outreach.
# - Sample: ~3,000 low-income households in high-risk zones (1,000 per arm in a 3-arm design).
# - Outcomes: uptake of voluntary buyouts; willingness to relocate; satisfaction with relocation process; time to completion; equity measures in uptake.
# - Safeguards: informed consent; not coercive; privacy protections; independent evaluation; IRB review; ensure replacement housing supply.
#
# 11) Five actionable indicators to monitor annually (thresholds used to accelerate/pause/reverse)
# - Indicator 1: Annual avoided damages (PV or nominal)
#   - Threshold: if annual avoided damages lag target by >20% for two consecutive years, reallocate resources or adjust incentives.
# - Indicator 2: Voluntary relocation uptake rate
#   - Threshold: annual uptake <1,000 households for two consecutive years triggers plan adjustment and targeted outreach.
# - Indicator 3: Forced displacement rate
#   - Threshold: share of forced relocations >10% of total relocations triggers pause on aggressive buyout pacing and re-target strategies.
# - Indicator 4: Equity attainment
#   - Threshold: share of relocations from bottom quintile <40% by year 5 triggers targeted outreach and policy amendments to improve equity.
# - Indicator 5: Public acceptability and legitimacy
#   - Threshold: citywide support below 50% for two consecutive annual surveys triggers enhanced communications and governance reforms.
#
# 12) Final notes on implementation and confidence
# - The plan is deliberately explicit about trade-offs and is designed to be implemented in a politically plausible, phased manner within the 18-month window and within a $2.0B cap.
# - The proposed pilot provides a concrete means to learn what incentives work in practice to maximize voluntary relocations among low-income households and to gauge short-term political acceptability before scaling to full implementation.
# - The plan assumes a robust, independent governance structure and transparent reporting to build trust across a divided council and the community.
# - If non-market benefits and health co-benefits are monetized in a broader economic analysis (beyond the monetized damages), the plan’s overall value proposition strengthens in all climate trajectories.
#
# If you’d like, I can tailor the numbers to your city’s actual current annual flood damages, hazard maps, housing stock, and existing insurance coverage. I can also prepare a one-page executive summary and a draft governance charter for the adaptation authority to help accelerate a council-ready package.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# # 10-Year Coastal Adaptation Plan: Priority-Based Implementation Strategy
#
# ## I. INTERVENTION PORTFOLIO & BUDGET ALLOCATION
#
# ### Phase 1: Immediate Actions (Years 0-3) - $720M
#
# **1. Hybrid Defense for Economic Core ($380M)**
# - **Intervention**: Elevated seawall + tidal marsh restoration along 8 km waterfront downtown/port district
# - **Timing**: Design Y0-1, construction Y1-3
# - **Rationale**: Protects 40% of tax base, employs nature-based buffer where feasible
# - **Expected outcome**: Reduces expected annual damages (EAD) from $180M to $45M in protected zone (~75% reduction for 35,000 jobs, 8,000 residents)
#
# **2. Voluntary Buyout Program - Priority Zones ($200M)**
# - **Intervention**: Purchase 800 properties in highest-risk areas (<2m elevation, repetitive loss history)
# - **Timing**: Rolling enrollment Y0-3, conversion to wetlands Y2-4
# - **Payment structure**: 125% pre-flood fair market value + $50K relocation subsidy + right of first refusal for affordable housing in safer zones
# - **Expected outcome**:
#   - 800 households relocated (est. 2,400 people)
#   - 70% voluntary participation rate (target low-income: 340 households)
#   - Reduces citywide EAD by $28M
#   - Distributional impact: +15% net wealth transfer to participating low-income households vs. status quo erosion
#
# **3. Emergency Building Code Reform ($40M implementation)**
# - **Intervention**: Mandate first-floor elevation +1.2m for new construction/substantial renovation in flood zones; create fast-track permitting + $30M subsidy pool for low-income compliance
# - **Timing**: Ordinance Y0, enforcement Y1+
# - **Expected outcome**: 450 retrofits Y1-10, reducing structure damage 60% per building
#
# **4. Flood Insurance Transition Program ($100M reserve)**
# - **Intervention**: Municipal catastrophe bond + means-tested premium subsidies to prevent NFIP policy lapses
# - **Timing**: Y0-2 setup
# - **Expected outcome**: Maintain 85% insurance coverage (down from 72% without intervention) among bottom income quintile
#
# ### Phase 2: Adaptive Measures (Years 4-7) - $880M
#
# **5. Living Shoreline Expansion ($320M)**
# - **Intervention**: Restore 15 km oyster reefs, salt marshes, and dune systems along eastern residential coast
# - **Timing**: Staged construction Y4-7
# - **Expected outcome**: Attenuate storm surge 20-35 cm, reduce EAD by $52M in adjacent neighborhoods (18,000 residents, 60% below median income)
#
# **6. Strategic Elevation of Critical Infrastructure ($280M)**
# - **Intervention**: Raise 3 sewage treatment plants, 2 power substations, hospital access roads
# - **Timing**: Y4-6
# - **Expected outcome**: Prevent $420M in cascade failures during 100-year event
#
# **7. Affordable Housing Development in Low-Risk Zones ($200M)**
# - **Intervention**: Public-private partnership to build 1,200 units at 60% AMI eligibility on elevated municipal land
# - **Timing**: Y5-8 construction
# - **Expected outcome**: House 600 buyout participants + 600 existing wait-list families, net zero involuntary displacement
#
# **8. Expanded Buyouts - Phase 2 ($80M)**
# - **Intervention**: Additional 250 properties in moderate-risk areas
# - **Timing**: Y5-7
# - **Expected outcome**: 750 people relocated, $9M EAD reduction
#
# ### Phase 3: Resilience Lock-In (Years 8-10) - $400M
#
# **9. Adaptive Traffic & Utility Networks ($220M)**
# - **Intervention**: Reroute 6 arterial roads, elevate water mains, create redundant power loops
# - **Expected outcome**: Reduce post-storm recovery time 40% (economic continuity benefit)
#
# **10. Community Resilience Hubs ($80M)**
# - **Intervention**: Retrofit 12 schools

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Mayor, Members of the City Council,
#
# This memo outlines a prioritized 10-year adaptation plan for our mid-sized coastal city, designed to address the projected 0.6m average sea-level rise and doubling of 100-year storm surge intensity by 2050, within your $2.0 billion capital budget. My recommendations are based on the core principles of minimizing involuntary displacement, addressing socioeconomic inequality, and balancing long-term resilience with the immediate political context.
#
# ### **1. Prioritized 10-Year Adaptation Plan (Budget: $2.0 Billion)**
#
# Our strategy is a "layered defense" approach, blending protective infrastructure, managed retreat, and city-wide resilience building. It's phased to allow for learning, adaptation, and political navigation.
#
# **Phase 1 (Years 1-3: Immediate Action & Foundation - ~$550 Million)**
# *   **Goal:** Secure critical infrastructure, initiate voluntary programs, and establish regulatory and governance frameworks. Focus on politically feasible, visible projects for early wins.
# *   **Interventions:**
#     1.  **Targeted Soft/Nature-Based Defenses (Primary Priority):** Mangrove restoration, dune creation, and living shorelines in 3-5 high-vulnerability coastal segments. Focus on areas with existing ecological potential or where they can augment existing grey infrastructure.
#         *   *Budget:* $150M.
#         *   *Confidence: High.* *Data Needed:* Comprehensive habitat mapping and high-resolution hydrodynamic modeling to optimize placement and design for maximum wave attenuation.
#     2.  **Critical Infrastructure Hardening (Strategic):** Flood-proofing and elevating key municipal services (e.g., wastewater treatment plants, main hospitals, emergency services hubs) and vital transportation arteries serving economic centers.
#         *   *Budget:* $200M.
#         *   *Confidence: High.* *Data Needed:* Detailed vulnerability assessments for specific critical infrastructure assets under 2050 climate scenarios, including cascading failure analysis.
#     3.  **Voluntary Relocation/Buyout Program - Pilot Phase (Targeted, Equity-Focused):** Launch a pilot program (detailed in Section 5) for 500-700 households in 1-2 of the highest-risk, predominantly low-income neighborhoods. Offer above-market value buyouts (120-130% of pre-flood risk value) and comprehensive assistance for relocation/rehousing in safer, designated "receiving zones."
#         *   *Budget:* $100M.
#         *   *Confidence: Medium.* *Data Needed:* Detailed property valuation data, demographic mapping of high-risk areas, and survey data on relocation preferences/barriers for low-income households.
#     4.  **Zoning & Building Code Updates (Initial Draft & Public Consultation):** Develop new zoning ordinances to restrict new construction in the 50-year floodplain and updated building codes requiring elevated foundations and flood-resistant materials in the 100-year floodplain. Identify and zone initial "receiving zones" for relocated populations.
#         *   *Budget:* $30M (staffing, consultants, extensive public engagement).
#         *   *Confidence: High.* *Data Needed:* Legal review of existing zoning authority and potential eminent domain implications for receiving zones.
#     5.  **Governance Reform - Climate Resilience Office & Stakeholder Task Force:** Establish a dedicated Climate Resilience Office to coordinate efforts and a multi-stakeholder task force (community reps, businesses, environmental groups) to provide ongoing advice and build consensus.
#         *   *Budget:* $20M (initial staffing, office setup).
#         *   *Confidence: High.* *Data Needed:* Best practices from other cities on effective multi-stakeholder governance models for climate adaptation.
#     6.  **Data & Modeling Refinement:** Invest in high-resolution flood modeling, socioeconomic vulnerability mapping, and ecosystem service valuation to inform future interventions.
#         *   *Budget:* $30M.
#         *   *Confidence: High.* *Data Needed:* Existing LiDAR data and bathymetry data for the entire coastal zone.
#     7.  **Public Awareness & Education Campaign:** Launch a city-wide campaign to inform residents about climate risks, the plan, and available resources, fostering community resilience.
#         *   *Budget:* $20M.
#         *   *Confidence: High.* *Data Needed:* Public perception surveys on climate change risks and preferred adaptation strategies.
#
# **Phase 2 (Years 4-7: Scaling Up & Integrated Solutions - ~$850 Million)**
# *   **Goal:** Expand successful pilot programs, implement regulatory changes, and invest in larger-scale, strategically critical infrastructure.
# *   **Interventions:**
#     1.  **Expanded Voluntary Relocation/Buyout Program:** Scale up the program, incorporating lessons learned from the pilot. Continue offering strong incentives for low-income households and expand to other high-risk, non-critical areas. Develop "resilience hubs" in receiving zones with enhanced public services (schools, clinics, community centers).
#         *   *Budget:* $350M.
#         *   *Confidence: Medium.* *Data Needed:* Longitudinal data from the pilot program on participant satisfaction, re-housing success, and community integration.
#     2.  **Major Hard Infrastructure Projects (Strategic Seawalls/Levees):** Construct targeted seawalls or flood barriers to protect specific, high-value economic districts or large dense populations that cannot reasonably be relocated and have clear cost-benefit justification. These will be integrated with nature-based features where possible.
#         *   *Budget:* $300M.
#         *   *Confidence: Medium.* *Data Needed:* Detailed engineering designs and cost-benefit analysis for specific hard infrastructure proposals, including long-term maintenance costs and residual risk assessments.
#     3.  **City-Wide Building Code & Zoning Enforcement:** Implement and rigorously enforce the new zoning ordinances and building codes. Provide subsidies and financial incentives for existing homeowners (especially low-income) to retrofit properties to meet new standards.
#         *   *Budget:* $100M (for subsidies and enforcement).
#         *   *Confidence: High.* *Data Needed:* Baseline data on current building code compliance rates, particularly in vulnerable areas.
#     4.  **Flood-Resilient Green Infrastructure:** Expand green infrastructure projects (e.g., permeable surfaces, bioswales, urban wetlands) throughout the city to manage stormwater, reduce urban heat island effect, and provide flood protection.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Detailed hydrologic modeling to identify optimal locations for green infrastructure to maximize stormwater retention and flood reduction benefits.
#
# **Phase 3 (Years 8-10: Long-Term Resilience & Adaptive Management - ~$600 Million)**
# *   **Goal:** Integrate adaptation into all city planning, continue strategic protection, and prepare for future challenges.
# *   **Interventions:**
#     1.  **Continued Voluntary Relocation/Buyout & Redevelopment:** Sustain the program, strategically acquiring additional high-risk properties and transforming vacated land into nature-based defenses, open space, or buffer zones.
#         *   *Budget:* $200M.
#         *   *Confidence: Medium.* *Data Needed:* Public perception and economic impact studies on the long-term transformation of vacated land and receiving zones.
#     2.  **Regional Collaboration & Early Warning Systems:** Invest in regional partnerships for adaptation strategies (e.g., shared flood models, emergency response protocols) and develop advanced local early warning systems for storm surge and flooding.
#         *   *Budget:* $50M.
#         *   *Confidence: High.* *Data Needed:* Inventory of existing regional agreements and emergency communication protocols.
#     3.  **Adaptive Management Fund:** Establish a dedicated fund for unforeseen adaptation needs, research and development of new technologies, and to scale up or pivot interventions based on monitoring data and evolving climate projections.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Detailed analysis of historical disaster relief spending and potential future funding gaps.
#     4.  **Insurance/Subsidy Program Development:** Collaborate with state and federal partners to develop a specialized flood insurance subsidy program for low-to-moderate income households in remaining high-risk zones who cannot or choose not to relocate, ensuring affordability while incentivizing risk reduction.
#         *   *Budget:* $50M (initial seed funding/subsidies for low-income).
#         *   *Confidence: Medium.* *Data Needed:* Actuarial analysis of current flood insurance uptake and claims among low-income households, and assessment of federal/state appetite for partnership.
#     5.  **Long-term Monitoring & Research:** Continuously monitor sea-level rise, storm intensity, and the effectiveness of all interventions. Fund local research into climate impacts and adaptation solutions.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Baseline ecological data for nature-based solutions and socio-economic data for relocated communities.
#     6.  **Climate-Resilient Infrastructure Upgrades:** Continue investing in upgrades to grey infrastructure (e.g., drainage systems, power grids) to make them more resilient to climate impacts, guided by lessons learned.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Infrastructure condition assessments across all municipal systems.
#
# ### **2. Quantified Expected Outcomes (by 2033 - end of 10-year plan, impacting 2050 targets)**
#
# *   **Reduction in Expected Annual Flood Damages (by 2050):**
#     *   *Baseline (without plan):* Projected $200-300 million annually by 2050.
#     *   *With Plan:* **~60-70% reduction**, bringing annual damages down to **$60-120 million by 2050.**
# *   **Number of People/Households Displaced or Relocated (by 2033):**
#     *   *Voluntary Relocation/Buyouts:* **2,500 - 4,000 households** (approx. 7,500 - 12,000 people) voluntarily relocated through incentivized programs.
#     *   *Forced Displacement:* **Minimized to effectively zero**, fulfilling the legal mandate.
# *   **Change in Socioeconomic Equity (Distributional impact on poorest 20%):**
#     *   **Significant positive impact.** Poorest 20% in high-risk zones will be offered above-market value buyouts and comprehensive relocation support.
#     *   **Quantitative Proxy:** Aim for a **10-15% reduction in the number of households below the poverty line living in the 100-year floodplain** by 2033, and a **25-30% reduction in their expected uninsured flood losses.**
#
# ### **3. Three Most Important Assumptions & Sensitivity**
#
# 1.  **Political Will & Bipartisan Cooperation Persist:**
#     *   *Details:* The $2.0B budget is sustained, and the politically divided council cooperates on necessary legislative changes (zoning, building codes). The upcoming election does not derail the plan.
#     *   *Sensitivity:* **High.** *Violation:* Gridlock or funding cuts (20-40% probability) would cause delays, cost overruns, incomplete projects, and potential failure to meet adaptation goals.
# 2.  **Sufficient Voluntary Participation in Buyout/Relocation:**
#     *   *Details:* Incentives (above-market value, assistance) are sufficient to encourage a critical mass of residents, especially low-income households, to voluntarily participate.
#     *   *Sensitivity:* **Medium-High.** *Violation:* Low participation rates (15-30% probability) would undermine equity goals and the non-displacement mandate, leading to continued exposure and higher future damage costs.
# 3.  **Future Climate Projections are Broadly Accurate:**
#     *   *Details:* The 0.6m SLR and 2x 100-year storm surge by 2050 projections are sufficient for planning.
#     *   *Sensitivity:* **Medium.** *Violation (Worse Case):* Impacts significantly accelerate beyond projections (10-20% probability of underestimation) rendering interventions insufficient, requiring costly emergency upgrades. *Violation (Better Case):* Impacts are less severe (5-10% probability of overestimation) leading to over-investment, though with residual co-benefits.
#
# ### **4. Top Five Failure Modes & Contingency/Mitigation**
#
# 1.  **Failure Mode: Political Backlash & Loss of Public Support.**
#     *   *Contingency:* Implement extensive, ongoing public outreach and education, involve affected communities in co-design, start with successful pilots, and ensure legal robustness of policies.
# 2.  **Failure Mode: Low Voluntary Participation in Buyout/Relocation.**
#     *   *Contingency:* Enhance incentives (increase buyout offers to 150%, expand assistance), empower community-led relocation efforts, invest heavily in attractive "resilience hubs" in receiving zones, and continuously refine strategies based on pilot feedback.
# 3.  **Failure Mode: Cost Overruns & Budget Exhaustion.**
#     *   *Contingency:* Strict project management, rigorous cost estimates, contingency planning, value engineering, active pursuit of state/federal/private grants, and judicious use of the Adaptive Management Fund.
# 4.  **Failure Mode: Maladaptation (Interventions Worsen Problems).**
#     *   *Contingency:* Integrated planning with advanced modeling, thorough Environmental Impact Assessments, robust monitoring and evaluation systems to detect issues early, and active regional collaboration to avoid shifting risks.
# 5.  **Failure Mode: Adverse Incentives (e.g., "Moral Hazard").**
#     *   *Contingency:* Link flood insurance subsidies to mandatory mitigation measures, use risk-based pricing (with affordability measures) to communicate true risk, maintain strict zoning/building codes, and conduct ongoing public education on individual preparedness.
#
# ### **5. Feasible 12–24 Month Randomized or Quasi-Experimental Pilot**
#
# **Objectives:** (a) Increase voluntary participation in relocation/buyout among low-income households, and (b) measure short-term political acceptability.
#
# **Intervention Target:** One of the highest-risk, predominantly low-income neighborhoods (approx. 500-700 households) designated as the "Pilot Zone."
#
# **Treatment Arms (for Voluntary Participation within Pilot Zone):**
# *   **Control Group (N=~200-250 households):** Standard city communications on flood risk; "fair market value" buyout offer (pre-flood risk appraisal).
# *   **Treatment Group 1 (N=~150-200 households):** All control elements PLUS: 120% of pre-flood risk market value buyout; personalized relocation counseling; detailed information on "resilience hubs."
# *   **Treatment Group 2 (N=~150-200 households):** All elements of Treatment Group 1 PLUS: Trusted, paid community relocation liaison; participatory workshops for future land use visioning of the vacated neighborhood.
#
# **Primary Outcomes (12-24 months):**
# *   **(a) Voluntary Participation:** Percentage of households in each group formally accepting a buyout offer.
# *   **(b) Short-Term Political Acceptability (City-wide):** Change in public support for the overall adaptation plan (pre/post city-wide random sample survey, 2,000 registered voters, 5-point Likert scale).
#
# **Ethical Safeguards:** Truly voluntary participation, no diminished services for non-participants, confidentiality of personal data, no "stigma" for control group, clear exit strategy, independent ethical review, and commitment to offering successful treatments to all eligible households post-pilot.
#
# ### **6. Five Measurable Indicators (with Thresholds) for Annual Monitoring**
#
# 1.  **Annual Sea-Level Rise & Storm Surge Frequency/Intensity (Observed vs. Projected):**
#     *   *Metric:* Observed SLR (mm/year) and number of storm surge events >0.5m/1.0m MHHW.
#     *   *Thresholds:* **Accelerate:** SLR > 7mm/year OR 2+ major surge events (>1.0m MHHW) in 3 years. **Pause/Re-evaluate:** SLR < 3mm/year over 5 years.
# 2.  **Voluntary Buyout/Relocation Participation Rate & Equity:**
#     *   *Metric:* % of eligible low-income households accepting buyout offers; % satisfaction with new housing/community for relocated households.
#     *   *Thresholds:* **Accelerate/Enhance:** < 40% participation for low-income OR < 60% satisfaction. **Maintain:** 60-80% participation AND > 75% satisfaction.
# 3.  **Number of Repetitive Flood Claims & Expected Annual Flood Damages (Monetized):**
#     *   *Metric:* % change in properties with 2+ claims in 5 years; estimated annual damages.
#     *   *Thresholds:* **Accelerate:** 10% increase in repetitive claims OR estimated annual damages exceed $150M (inflation-adjusted) for 2 consecutive years. **Maintain:** 5% decrease in claims AND damages below $100M.
# 4.  **Public & Political Acceptance of Adaptation Plan:**
#     *   *Metric:* Quarterly "support for adaptation plan" survey score (avg. 1-5); % of "yes" votes on key council resolutions.
#     *   *Thresholds:* **Accelerate/Adjust Strategy:** Avg. survey score < 3.0 OR > 30% of key council votes fail. **Maintain:** Avg. survey score > 3.5 AND > 70% of key votes pass.
# 5.  **Ecological Health of Nature-Based Defenses (NBDs):**
#     *   *Metric:* % of target NBD area established and healthy; biodiversity index; erosion rates in NBD zones.
#     *   *Thresholds:* **Accelerate/Remediate:** < 70% of target NBD healthy OR significant erosion detected. **Maintain:** > 90% of target NBD healthy AND stable erosion rates.
#
# ### **7. Overall Plan Cost-Benefit Estimate (Present Value over 30 years)**
#
# *   **Plan Cost (PV):** $2.0 Billion
# *   **Benefits (PV from flood damage reduction, excluding co-benefits):**
#
# | Scenario                 | Discount Rate (r) | PV of Costs ($B) | PV of Benefits (Low Damage Trajectory) ($B) | PV of Benefits (Medium Damage Trajectory) ($B) | PV of Benefits (High Damage Trajectory) ($B) | Net Benefit (Low) ($B) | Net Benefit (Medium) ($B) | Net Benefit (High) ($B) |
# | :----------------------- | :---------------- | :--------------- | :------------------------------------------ | :--------------------------------------------- | :------------------------------------------- | :--------------------- | :------------------------ | :---------------------- |
# | **Low Discount Rate**    | **3%**            | **2.00**         | 2.80                                        | 4.20                                           | 5.80                                         | **0.80**               | **2.20**                  | **3.80**                |
# | **High Discount Rate**   | **7%**            | **2.00**         | 1.80                                        | 2.80                                           | 3.80                                         | **-0.20**              | **0.80**                  | **1.80**                |
#
# **Conclusion:** The plan generally yields a positive cost-benefit, particularly under a lower discount rate and considering the significant potential for high climate damages. Even at a 7% discount rate, the plan breaks even or provides positive net benefits in medium to high damage scenarios. This represents a fiscally responsible investment, especially when non-monetized co-benefits (social equity, avoided trauma, ecological improvements) and the legal mandate to minimize displacement are considered.
#
# ### **8. Confidence Levels and Key Data Points for Major Recommendations**
#
# *   **Targeted Soft/Nature-Based Defenses:** **High confidence.** *Data Needed:* Hydrodynamic modeling validating specific NBD designs.
# *   **Critical Infrastructure Hardening:** **High confidence.** *Data Needed:* Engineering vulnerability assessments and cost-benefit analyses for each asset.
# *   **Voluntary Relocation/Buyout Program:** **Medium confidence.** *Data Needed:* Results from the 12-24 month pilot program.
# *   **Zoning & Building Code Updates:** **High confidence.** *Data Needed:* Comprehensive legal opinion on city's authority and "takings" implications.
# *   **Governance Reform:** **High confidence.** *Data Needed:* Case studies of similar offices/task forces in other mid-sized coastal cities.
# *   **Major Hard Infrastructure Projects:** **Medium confidence.** *Data Needed:* Independent engineering feasibility studies and detailed cost-benefit analyses for specific projects.
# *   **Insurance/Subsidy Program Development:** **Medium confidence.** *Data Needed:* Actuarial study detailing flood risk profiles, insurance gaps, and partnership models.
#
# This plan offers a robust, actionable, and equitable pathway to a more resilient future for our city. It embraces necessary trade-offs, prioritizing the minimization of involuntary displacement while strategically protecting critical economic functions.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# # **10-Year Coastal Adaptation Plan for Mid-Sized City**
#
# ## **1. Prioritized 10-Year Plan & Budget Allocation ($2.0B Total)**
#
# **Phase 1: Years 1–4 (Foundation & High-Impact Protection) — $850M**
# - **Zoning & Building Code Reform** ($50M): Immediate moratorium on new construction in highest-risk zones (V-Zone+0.6m); mandatory elevation/flood-proofing for major renovations; expedited permitting for retrofits.
# - **Hybrid Structural-Natural Defenses** ($600M): Construct 4.5 km of deployable floodwalls/gates at critical port/economic nodes; restore 200 hectares of oyster reefs/marshes as wave buffers in front of low-income neighborhoods.
# - **Voluntary Buyout Program Launch** ($150M): Purchase 400 highest-risk, repetitive-loss properties (≈800 households) at pre-disaster value + 20% relocation assistance.
# - **Equity-Focused Subsidy Program** ($50M): Grants covering 75% of elevation/retrofit costs for low-income homeowners (target: 2,000 households).
#
# **Phase 2: Years 5–7 (Expansion & Managed Transition) — $750M**
# - **Nature-Based Expansion** ($300M): Additional 300 hectares of mangrove/wetland restoration; beach nourishment with engineered dunes.
# - **Buyout Expansion** ($250M): Additional 600 properties (≈1,200 households), prioritized by voluntary uptake.
# - **Stormwater & Drainage Upgrades** ($150M): Green infrastructure in flood-prone urban corridors.
# - **Risk-Based Insurance Pool** ($50M): City-backed reinsurance to lower premiums for middle-income households.
#
# **Phase 3: Years 8–10 (Governance & Resilience) — $400M**
# - **Floodproof Critical Infrastructure** ($250M): Water treatment plants, emergency shelters, hospitals.
# - **Adaptive Governance & Monitoring** ($150M): Real-time flood monitoring; community resilience hubs; plan revision.
#
# ## **2. Quantified Expected Outcomes (by 2034)**
# - **Reduction in Expected Annual Flood Damages**: From current $120M/year to $70M/year (42% reduction).
# - **Displacement/Relocation**:
#   - Voluntary relocation: 2,000 households (≈5,000 people) via buyouts.
#   - Involuntary displacement: ≤100 households (only if immediate safety threat).
# - **Socioeconomic Equity Impact**: Poorest 20% see 50% reduction in expected flood damages (vs. 35% reduction for highest-income quintile). 2,000 low-income households receive retrofit subsidies.
#
# ## **3. Key Assumptions & Sensitivity**
# 1. **Assumption**: Voluntary buyout uptake reaches 40% of eligible households.
#    - *Sensitivity*: If uptake <20%, forced displacement risks increase; if >60%, budget overallocated. Success probability: 60% (±15%).
# 2. **Assumption**: Storm surge intensity doubles by 2050 as projected.
#    - *Sensitivity*: If triples, hybrid defenses become inadequate by 2040. Probability of exceedance: 30%.
# 3. **Assumption**: No major economic recession disrupting budget.
#    - *Sensitivity*: Recession >3 years delays Phase 2–3. Probability: 40%.
#
# ## **4. Top Five Failure Modes & Contingencies**
# 1. **Political backlash from property owners in buyout zones**.
#    - *Contingency*: Pre-commit to council vote after pilot results; allow opt-in to alternative defense zones.
# 2. **Gentrification from elevated properties**.
#    - *Contingency*: Pair zoning changes with community land trusts and property tax caps for low-income residents.
# 3. **Cost overruns on hybrid infrastructure**.
#    - *Contingency*: Fixed-price contracts with 15% contingency reserve; switch to simpler nature-based if overrun >20%.
# 4. **Low participation in voluntary buyouts**.
#    - *Contingency*: Increase relocation bonus incrementally; offer rental assistance alternatives.
# 5. **Legal challenges to zoning changes**.
#    - *Contingency*: Phased implementation starting with most vulnerable parcels; establish hardship variances.
#
# ## **5. 12–24 Month Pilot Design**
# - **Objective**: Increase voluntary buyout participation among low-income households & gauge political acceptability.
# - **Sample Frame**: 600 owner-occupied households in highest-risk zone, income <150% poverty line.
# - **Treatment Arms**:
#   - Arm A: Standard offer (pre-disaster value + 10% bonus).
#   - Arm B: Enhanced offer (pre-disaster value + 20% bonus + guaranteed affordable housing option).
#   - Arm C: Enhanced offer + community navigator (trusted local assists).
# - **Primary Outcomes**:
#   - (a) Sign-up rate for buyout at 12 months.
#   - (b) Pre/post poll of citywide residents on plan acceptability.
# - **Ethical Safeguards**: Independent oversight; right to withdraw; control group offered standard program after trial.
#
# ## **6. Five Annual Monitoring Indicators & Thresholds**
# 1. **Voluntary buyout sign-up rate**: <15% → enhance incentives; >40% → expand program.
# 2. **Flood damage claims per $1M insured value**: Increase >10% year-on-year → accelerate defenses.
# 3. **Low-income household retrofit grants utilized**: <50% of allocated funds → simplify application.
# 4. **Public approval of adaptation plan (polling)**: <45% support → pause new measures, increase outreach.
# 5. **Cost per hectare of nature-based defense**: >$1.5M → switch to more cost-effective sites.
#
# ## **7. Cost-Benefit Analysis**
# - **Benefits**: Reduced flood damages ($50M/year from Year 5), avoided catastrophic losses ($300M every 20 years), ecosystem services ($5M/year).
# - **Costs**: $2.0B over 10 years, plus $20M/year maintenance.
# - **Net Present Value (2024–2050)**:
#   - **Low damage trajectory (1.5× surge)**: 3% discount rate: +$180M; 7%: –$200M.
#   - **Medium (2× surge)**: 3%: +$400M; 7%: +$50M.
#   - **High (3× surge)**: 3%: +$1.1B; 7%: +$500M.
#
# ## **8. Confidence Levels & Critical Data Needs**
# - **Hybrid structural-natural defenses** (High confidence). *Critical data*: Geotechnical survey of substrate for marsh restoration success.
# - **Voluntary buyout uptake target** (Medium confidence). *Critical data*: Pilot results on enhanced-offer participation rates.
# - **Zoning changes political viability** (Low confidence). *Critical data*: Pre-election polling of swing districts on development restrictions.
# - **Equity retrofit subsidy uptake** (Medium confidence). *Critical data*: Survey of low-income homeowners on barriers to application.
#
# ## **Explicit Trade-Offs Accepted**
# 1. **Protecting economic centers over uniform defense**: 70% of infrastructure budget protects port/downtown (30% of geography but 60% of economic value).
# 2. **Voluntary relocation over holding all ground**: Accepts retreat from 5% of current developed area to avoid later forced displacement.
# 3. **Near-term budget focus on hybrid defenses over full buyouts**: This reduces damages quickly but requires later retreat from some areas that become indefensible post-2050.
#
# ---
# **Plan Summary**: This plan reduces flood risk by 42%, voluntarily relocates 2,000 households, prioritizes protection for low-income communities, and remains within budget. Success hinges on voluntary participation, accurate climate projections, and sustained political will. The pilot and annual indicators allow for adaptive management.

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **MID‑SIZE COASTAL CITY – 10‑YEAR ADAPTATION PLAN (2025‑2035)**
# *Population ≈ 500 000, 0.6 m SLR & 2× 100‑yr storm surge by 2050*
#
# ---
#
# ## 1.  Core Interventions, Timing & Budget (≤ $2.0 B)
#
# | Phase (Year) | Intervention | Scope & Rationale | Approx. Cost (US$) | % of Total |
# |--------------|--------------|-------------------|-------------------|------------|
# | **2025‑2027** | **(A) Strategic “Hybrid” Seawall‑Barrier** | • 7 km reinforced concrete + movable gate protecting downtown, port, and the city’s primary utility corridor. <br>• Designed to withstand a 2‑× storm surge plus 0.6 m SLR with a 1‑m freeboard safety margin. | $1.0 B | 50 % |
# | **2025‑2029** | **(B) Nature‑Based Defenses** | • 500 ha of tidal marsh & mangrove restoration (incl. land acquisition, planting, hydrologic reconnection). <br>• 3 km of living‑shore dune‑grass buffer along the residential beachfront. | $200 M | 10 % |
# | **2025‑2030** | **(C) Targeted Voluntary Buy‑outs / Relocation** | • 2 000 high‑risk dwellings (≈ 5 % of at‑risk housing) – priority to households below the poverty line (≈ 60 % of purchases). <br>• Includes “green‑relocation” grants for moving to pre‑identified safe‑zone neighborhoods. | $300 M | 15 % |
# | **2025‑2035** | **(D) Zoning & Building‑Code Reform** | • Adopt “Flood‑Resilience Overlay” for all parcels within 0.5 km of projected 2050 shoreline. <br>• Provide fast‑track permits & density bonuses for elevating new construction ≥ 1.2 m above projected BFE. | $100 M | 5 % |
# | **2025‑2028** | **(E) Insurance/Subsidy & Risk‑Education Program** | • Tiered premium subsidies for low‑income (≤ 150 % FPL) – 30 % reduction on NFIP rates. <br>• Community outreach, flood‑risk dashboards, and “Resilience Savings Accounts” (matched grants for home‑hardening). | $100 M | 5 % |
# | **2025‑2027** | **(F) Governance & Institutional Reforms** | • Create a Climate‑Resilience Office (CRO) with authority to coordinate all interventions, monitor performance, and manage the $250 M contingency fund. | $50 M | 2.5 % |
# | **2025‑2026** | **(G) Contingency/Reserve** | • Unspent funds, cost overruns, emergency repairs. | $250 M | 12.5 % |
# | **TOTAL** | | | **$2.0 B** | **100 %** |
#
# *All spending is front‑loaded (≈ 80 % in the first five years) to lock‑in physical protection before the 2030‑mid‑decade storm intensification peak.*
#
# ---
#
# ## 2.  Quantified Expected Outcomes (10‑yr horizon)
#
# | Metric | Baseline (2025) | Projected 2035 (with plan) | Reduction / Improvement | Comments |
# |--------|----------------|----------------------------|--------------------------|----------|
# | **Annual expected flood damage** (direct property & infrastructure) | $300 M (2025) – rising 4 %/yr without action → $440 M by 2035 | $150 M average (2025‑2035) | **≈ 45 % cut** (≈ $135 M/yr avoided) | Savings driven by seawall + nature‑based attenuation (≈ 30 %); buy‑outs eliminate highest‑risk structures (≈ 15 %). |
# | **Households displaced (forced)** | 5 % of at‑risk households (~2 500) would be forced by 2035 under business‑as‑usual | < 200 (≈ 0.2 %) | **≥ 92 % reduction** | All relocation is voluntary; emergency‑evacuation plans limit forced moves. |
# | **Households voluntarily relocated (buy‑out)** | 0 | 2 000 (≈ 5 % of at‑risk) | — | 60 % of these are low‑income → 1 200 poor households. |
# | **Low‑income (bottom 20 %) risk exposure** | 30 % of this group lives in 1‑in‑5 most flood‑prone parcels | 12 % (after buy‑outs + elevation incentives) | **60 % relative risk drop** | Measured as probability of flood depth > 0.5 m per year. |
# | **Flood‑insurance coverage (low‑income)** | 45 % (2025) | 85 % (2028) | +40 ppt | Subsidy + education drives uptake. |
# | **Economic activity protected** | $12 B of taxable commercial/industrial floor space in core district | 95 % retained (seawall protects) | – | Trade‑off: heavy investment in core vs. peripheral neighborhoods. |
#
# ---
#
# ## 3.  Three Core Assumptions & Sensitivity
#
# | # | Assumption | Reasonable Range (probability) | Sensitivity |
# |---|------------|--------------------------------|-------------|
# | **A** | **SLR reaches 0.6 m by 2050** (median IPCC AR6 RCP4.5) | 0.6 m ± 0.1 m (≈ 70 % chance) | *If SLR is > 0.8 m*, seawall freeboard must be increased → extra $150‑200 M. *If SLR is < 0.4 m*, we could defer part of the hard barrier (cost saving ≈ $100 M). |
# | **B** | **100‑yr storm surge intensity doubles** (wind‑speed & surge height) | 2× ± 30 % (≈ 55 % chance) | *If surge increase is only 1.5×*, the hybrid barrier can be built to lower height, saving ≈ $80 M. *If surge spikes to 2.5×*, we would need additional overtopping protection (≈ $120 M). |
# | **C** | **Low‑income households will accept voluntary buy‑outs when offered ≥ 80 % of market value + relocation grant** | Acceptance 70‑85 % (≈ 75 % chance) | *If acceptance falls below 55 %*, we must increase the grant or shift to more aggressive zoning (cost ≈ $50 M). *If acceptance exceeds 90 %*, we could re‑allocate excess funds to nature‑based projects. |
#
# Overall plan success is **medium‑high** (≈ 70 % probability of achieving ≥ 40 % damage reduction and ≤ 200 forced displacements) given current scientific confidence and community‑engagement pilots (see §5).
#
# ---
#
# ## 4.  Top‑5 Failure Modes & Mitigation
#
# | # | Failure Mode | Likely Consequence | Contingency / Mitigation |
# |---|--------------|-------------------|--------------------------|
# | **1** | **Political backlash over “big‑seawall” cost** (election 2027) | Funding freeze, re‑allocation to other priorities | • Phase the barrier (Phase I: 4 km protecting the most critical assets) with clear cost‑benefit communication; <br>• Establish a “Resilience Bond” financed through a modest (0.1 %) property tax dedicated to the project; <br>• Early bipartisan outreach using local business coalition data on avoided losses. |
# | **2** | **Buy‑out program perceived as “selling out” low‑income neighborhoods** | Low participation, protests, legal challenges | • Co‑design the program with community NGOs; <br>• Offer “green‑relocation” grants for moving to affordable, pre‑built resilient housing; <br>• Publicly publish transparent cost‑benefit and equity impact analyses. |
# | **3** | **Gentrification after protection of downtown** (property values surge) | Displacement of renters & small businesses | • Pair the seawall with inclusionary‑housing ordinances that reserve 20 % of new units for households ≤ 150 % FPL; <br>• Use a “Community Land Trust” to hold key parcels for affordable use. |
# | **4** | **Construction delays / cost overruns (seawall, wetlands)** | Budget overspend, missed 2030 target | • Fixed‑price EPC contracts with performance penalties; <br>• Independent “Resilience Oversight Committee” with quarterly audits; <br>• Maintain $250 M contingency reserve (see Table 1). |
# | **5** | **Insurance/subsidy fraud or moral hazard** | Uncontrolled premium losses, reduced fiscal sustainability | • Link subsidies to verified elevation/retrofit standards; <br>• Require annual flood‑risk re‑assessment for continued eligibility; <br>• Use GIS‑based fraud detection analytics. |
#
# ---
#
# ## 5.  12‑24‑Month Pilot to Boost Low‑Income Relocation & Test Political Acceptability
#
# | Element | Design |
# |---------|--------|
# | **Sample frame** | 1 200 low‑income (≤ 150 % FPL) households in the top 30 % flood‑risk parcels (identified via high‑resolution LiDAR flood maps). |
# | **Randomisation** (three arms, 400 households each) | 1. **Cash‑Incentive Arm** – 85 % market‑value buy‑out + $5 k relocation grant (baseline offer). <br>2. **Counselling‑Plus‑Design Arm** – Same cash offer + a dedicated case‑worker, a “design‑your‑new‑home” workshop, and a guaranteed spot in a new affordable‑resilient‑housing complex. <br>3. **Control Arm** – Standard city outreach (information brochure, no additional services). |
# | **Primary outcomes (12‑month horizon)** | • % of households signing a buy‑out agreement (target > 70 % in Arm 2, > 55 % in Arm 1, < 30 % in Control). <br>• Change in “plan acceptability” score (1‑5 Likert) measured via door‑to‑door surveys across the whole pilot area. |
# | **Secondary outcomes** | • Median time from offer to contract signing; <br>• Reported perceived fairness; <br>• Uptake of flood‑insurance among remaining at‑risk households. |
# | **Ethical safeguards** | • Informed consent with clear explanation that participation is voluntary and will not affect eligibility for the standard city program. <br>• Independent Institutional Review Board (IRB) oversight. <br>• Data anonymisation; opt‑out option for any household at any stage. |
# | **Timeline** | • **Month 1‑3** – GIS risk mapping & household recruitment. <br>• **Month 4‑6** – Randomisation & baseline survey. <br>• **Month 7‑18** – Offer rollout, counselling, monitoring. <br>• **Month 19‑24** – Final survey, analysis, policy brief. |
#
# *Result:* The pilot will quantify the “price‑elasticity” of low‑income buy‑out acceptance and provide a rapid gauge of political support (acceptability score) before the 2027 council election.
#
# ---
#
# ## 6.  Five Annual Monitoring Indicators (with Decision Thresholds)
#
# | Indicator | Target (2025‑2035) | Threshold for Action |
# |-----------|-------------------|-----------------------|
# | **1. Annual Flood‑Damage Expenditure** (city‑reported, $M) | ≤ $150 M (average) | > $180 M → Review/strengthen physical defenses (add height, expand nature‑based area). |
# | **2. Low‑Income Flood‑Insurance Coverage** (% of eligible households) | ≥ 85 % | < 70 % → Increase subsidy or expand outreach budget by 20 %. |
# | **3. Voluntary Buy‑Outs Completed** (units/yr) | 200 ± 30 | < 150 yr → Boost cash incentive or expand counselling pilot. |
# | **4. Equity Risk‑Reduction Ratio** (risk reduction for poorest 20 % ÷ city‑wide risk reduction) | ≥ 1.0 (i.e., poorest benefit at least as much) | < 0.8 → Re‑allocate funds to targeted retrofits or expand affordable‑housing set‑aside. |
# | **5. Council/Mayor Public‑Support Index** (average score of city‑wide poll, 1‑5) | ≥ 3.5 (≥ 70 % “support”) | < 3.0 → Launch city‑wide communication campaign; consider adjusting financing mechanism. |
#
# Indicators are compiled by the **Climate‑Resilience Office** and presented at the quarterly City Council “Resilience Review”.
#
# ---
#
# ## 7.  Cost‑Benefit Estimate (NPV, 10 yr)
#
# ### Assumptions
# * **Discount rates**: 3 % (social planner) vs. 7 % (municipal finance).
# * **Damage trajectories** (baseline without adaptation):
#   * **Low** – 1 %/yr increase (minimal storm intensification).
#   * **Medium** – 3 %/yr (current IPCC median).
#   * **High** – 6 %/yr (upper‑range storm surge).
# * **Adaptation effect** – 45 % reduction in damages (flat over the horizon).
#
# | Scenario | Discount % | Present Value of Damages (no action) | PV of Damages **with plan** | PV of Adaptation Cost* | **Net Benefit (NPV)** |
# |----------|-----------|--------------------------------------|----------------------------|------------------------|----------------------|
# | Low | 3 % | $3.2 B | $1.8 B | $1.5 B | **+$0.0 B** |
# | Low | 7 % | $2.8 B | $1.6 B | $1.5 B | **+$0.1 B** |
# | Medium | 3 % | $4.9 B | $2.7 B | $1.5 B | **+$0.7 B** |
# | Medium | 7 % | $4.2 B | $2.3 B | $1.5 B | **+$0.3 B** |
# | High | 3 % | $7.9 B | $4.4 B | $1.5

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# **Prioritized 10-Year Adaptation Plan**
#
# With a $2.0 billion budget, I propose the following interventions:
#
# 1. **Seawall and Dunes System** (2.5B, $1.25B, 2024-2029):
# 	* Construct a 5 km seawall and build a 3 km long dunes system to protect the city center.
# 	* Expected reduction in annual flood damages: $120 million (20% decrease).
# 	* Number of displaced/households relocated: 10,000 (20% decrease).
# 	* Change in socioeconomic equity: Reduction in flood-related economic hardship among the poorest 20%.
# 2. **Smart Grid and Flood-Proofing Zoning** (400M, $200M, 2024-2028):
# 	* Upgrade the city's electrical grid to withstand flooding and install smart sensors to monitor storm surges.
# 	* Implement zoning regulations that require new construction to be built above grade or use flood-proof materials.
# 3. **Relocation/ Buyout Program** (300M, $150M, 2024-2029):
# 	* Establish a voluntary relocation program for low-income households in high-risk flood areas.
# 	* Offer buyouts or relocation packages to encourage voluntary participation.
# 	* Expected increase in voluntary participation: 40% ( increase in program enrollment).
# 4. **Insurance/Subbidy Programs** (400M, $200M, 2024-2028):
# 	* Implement a city-funded insurance program to cover flood-related losses.
# 	* Offer subsidies to households in high-risk flood areas to help mitigate financial burden.
# 5. **Governance Reforms** (200M, $100M, 2025-2029):
# 	* Implement a participatory budgeting process to ensure inclusive decision-making.
# 	* Establish a flood resiliency trust fund to prioritize adaptation investments.
#
# **Assumptions and Sensitivity**
#
# 1. **Sea-Level Rise and Storm Surge Intensity**: High sensitivity (50% impact on plan's success, 1:1 probability range). Assuming 0.6 m sea-level rise and doubling of 100-year storm surge intensity is a reasonable assumption based on current IPCC projections.
# 2. **Economic Growth and Inflation**: Medium sensitivity (30% impact on plan's success, 2:1 probability range). Assuming a 2% annual economic growth rate and moderate inflation (1.5%) is a conservative estimate based on historical data.
# 3. **Citizen Engagement and Participation**: Medium sensitivity (30% impact on plan's success, 2:1 probability range). Assuming high levels of citizen engagement and participation in the adaptation process is crucial for successful implementation.
#
# **Failure Modes and Contingency Planning**
#
# 1. **Political Backlash**: Establish a stakeholder advisory committee to ensure inclusive decision-making.
# 2. **Adverse Incentives**: Implement a revenue neutral, carbon-fund-based financing mechanism to reduce the burden on taxpayers.
# 3. **Insufficient Public Engagement**: Establish community outreach programs to ensure informed decision-making by all stakeholders.
# 4. **Inadequate Funding**: Prioritize interventions with the greatest expected outcomes and implement phase-in financing plans.
# 5. **Low-Intensity Storms**: Implement adaptive management plans to address unexpected storm intensity.
#
# **Pilot Study**
#
# Title: "Flood-Resilient Neighborhoods"
#
# * Sample Frame: 1,500 low-income households in high-risk flood areas.
# * Treatment Arms:
# 	+ Group A: Standard relocation/buyout program.
# 	+ Group B: Enhanced program with community engagement and education components.
# 	+ Group C: Control group with no additional program components.
# * Primary Outcome: Increase in voluntary participation in the relocation/buyout program among low-income households.
# * Ethical Safeguards: Randomized controlled trial with informed consent and anonymized data.
#
# **Performance Monitoring**
#
# 1. Annual Flood Risk Assessment.
# 2. Displacement/Relocation Program Metrics: Enrollment rates, retention rates, and program effectiveness.
# 3. Economic Benefit Categorization: Reduction in flood-related losses, increase in economic productivity, and reduction in poverty rates.
# 4. Social Equity Metrics: Distribution of benefits, reduction in flood-related hardship among vulnerable populations.
# 5. Stakeholder Engagement Indices: Citizen participation rates, stakeholder satisfaction, and community engagement quality.
#
# **Cost-Benefit Analysis**
#
# Scenario 1 (3% discount rate): -$1.3 billion (benefit: - $1.1 billion displacement cost reduction, - $150 million increased economic costs; - $50 million loss of avoided damages).
#
# Scenario 2 (7% discount rate): -2.1 billion (benefit: - $1.6 billion displacement cost reduction, - $200 million increased economic costs; - $80 million loss of avoided damages).
#
# Scenario 3 (Low Climate Damage Trajectory): +$1.5 billion (benefit: +$1.2 billion displacement cost reduction, + $100 million increased economic costs; -$200 million loss of avoided damages).
#
# Scenario 4 (Medium Climate Damage Trajectory): +$2.2 billion (benefit: +$1.8 billion displacement cost reduction, + $150 million increased economic costs; -$300 million loss of avoided damages).
#
# Scenario 5 (High Climate Damage Trajectory): +$3.2 billion (benefit: +$2.6 billion displacement cost reduction, + $200 million increased economic costs; -$400 million loss of avoided damages).
#
# **Confidence Levels**
#
# 1. Seawall and Dunes System: High (90%), 3D lidar data collection within 12 months to increase confidence.
# 2. Relocation/Buyout Program: High (90%), Establish a stakeholder advisory committee to ensure inclusive decision-making.
# 3. Smart Grid and Flood-Proofing Zoning: Medium (60%), Monitor performance and make adjustments as necessary.
# 4. Insurance/Subsidy Programs: Medium (60%), Develop comprehensive actuarial models to ensure risk-sharing mechanisms are in place.
# 5. Governance Reforms: Medium (60%), Implement participatory budgeting and community outreach programs to ensure inclusive decision-making.
#
# Note: A comprehensive, multi-year implementation plan will require ongoing monitoring, adaptation, and fine-tuning to achieve the planned outcomes. This plan provides a starting point for the city to prioritize their adaptations.

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano', 'claude-sonnet-4-5', 'gemini-2.5-flash', 'deepseek-chat', 'openai/gpt-oss-120b', 'llama3.2']
# ['Below is a concrete, donor-ready 10-year adaptation plan tailored to a mid-sized coastal city (population ~500,000) facing 0.6 m sea‑level rise and doubling of 100-year surge by 2050. It is structured to fit a legally binding mandate to minimize involuntary displacement, address inequality, and work within a $2.0B 10-year capital budget while navigating a politically divided council and an election in 18 months.\n\nExecutive summary\n- Core goal: reduce flood risk and protect critical economic/urban cores while prioritizing voluntary relocation for the neediest, and strengthening governance so investments are defended by evidence and community legitimacy.\n- Core mix of actions: a balanced portfolio of nature-based and hybrid defenses, targeted hard infrastructure upgrades, a voluntary buyout/relocation program with strong protections for low-income households, updated zoning/building codes, risk financing/subsidies to lower insurance barriers, and governance reforms to enable adaptive management.\n- 10-year budget (not-to-exceed $2.0B): \n  - A) Nature-based/hybrid defenses: $700M\n  - B) Hard infrastructure/drainage upgrades: $550M\n  - C) Targeted buyouts/voluntary relocation: $520M\n  - D) Zoning/building-code updates: $140M\n  - E) Insurance subsidies/risk financing: $60M\n  - F) Governance and implementation management: $30M\n  - Total: $2.00B\n- Expected outcomes (rough, defensible): \n  - Reduction in expected annual flood damages by approximately 60–70% in protected zones; net citywide annual damages reduced from roughly $200M today to the low-to-mid $100Ms by 2036 under the high-damage trajectory, with more modest reductions under lower climate-damage trajectories.\n  - Displacement: voluntary relocations of roughly 3,500–6,000 households (roughly 11,000–17,000 people) over the decade; forced relocations kept at 0–5% of total displacement.\n  - Equity: the program prioritizes the lowest-income households; by year 5–7, the share of relocated households from the bottom two quintiles rises to ~60–75% of relocations; poorest 20% see enhanced protection in protected areas and higher uptake in buyouts where appropriate.\n- Key risks, failure modes, and mitigations are identified, along with a pilot to test voluntary relocation incentives and measure political acceptability.\n- Five annual indicators, with decision thresholds, to guide acceleration/pausing/reversals.\n- A concise, scenario-based cost-benefit: two discount rates (3% and 7%) and three climate-damage trajectories (low/medium/high). In high-damage scenarios, the plan yields positive net benefits that justify the spend; in low-damage scenarios, costs dominate monetized benefits but social equity and resilience benefits remain substantial.\n- Three top assumptions, with probability ranges and sensitivity notes, plus confidence levels and data needs to improve certainty.\n\n1) Interventions, timing, and approximate budget allocations (10-year horizon)\nAssumptions: construction/relocation cycles phased to minimize disruption and align with a single, accountable program office. 18-month election window will be used to build cross-party credibility through phased milestones and transparency.\n\nA. Nature-based and hybrid defenses (soft defenses + living shorelines + green streets + floodplain restoration)\n- What: 18 km of hybrid shorelines, wetland/mloodplain restoration where feasible, urban green infrastructure (bioswales, rain gardens, permeable pavement), and living breakwaters where practicable.\n- Timing: Phase 1 (Years 1–2): design in the highest-risk corridors, begin 2–3 defense micro-projects; Phase 2 (Years 3–6): scale to additional segments; Phase 3 ( Years 7–10): complete citywide coverage in priority zones.\n- Budget: $700M\n- Rationale: reduces wave/run-up exposure in nearshore and low-lying blocks, provides co-benefits (habitat, recreation, water quality).\n\nB. Hard infrastructure and drainage upgrades (seawalls, flood barriers, pumps, upgraded st ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Below is a concrete, donor-ready 10-year adaptation plan tailored to a mid-sized coastal city (population ~500,000) facing 0.6 m sea‑level rise and doubling of 100-year surge by 2050. It is structured to fit a legally binding mandate to minimize involuntary displacement, address inequality, and work within a $2.0B 10-year capital budget while navigating a politically divided council and an election in 18 months.
#
# Executive summary
# - Core goal: reduce flood risk and protect critical economic/urban cores while prioritizing voluntary relocation for the neediest, and strengthening governance so investments are defended by evidence and community legitimacy.
# - Core mix of actions: a balanced portfolio of nature-based and hybrid defenses, targeted hard infrastructure upgrades, a voluntary buyout/relocation program with strong protections for low-income households, updated zoning/building codes, risk financing/subsidies to lower insurance barriers, and governance reforms to enable adaptive management.
# - 10-year budget (not-to-exceed $2.0B):
#   - A) Nature-based/hybrid defenses: $700M
#   - B) Hard infrastructure/drainage upgrades: $550M
#   - C) Targeted buyouts/voluntary relocation: $520M
#   - D) Zoning/building-code updates: $140M
#   - E) Insurance subsidies/risk financing: $60M
#   - F) Governance and implementation management: $30M
#   - Total: $2.00B
# - Expected outcomes (rough, defensible):
#   - Reduction in expected annual flood damages by approximately 60–70% in protected zones; net citywide annual damages reduced from roughly $200M today to the low-to-mid $100Ms by 2036 under the high-damage trajectory, with more modest reductions under lower climate-damage trajectories.
#   - Displacement: voluntary relocations of roughly 3,500–6,000 households (roughly 11,000–17,000 people) over the decade; forced relocations kept at 0–5% of total displacement.
#   - Equity: the program prioritizes the lowest-income households; by year 5–7, the share of relocated households from the bottom two quintiles rises to ~60–75% of relocations; poorest 20% see enhanced protection in protected areas and higher uptake in buyouts where appropriate.
# - Key risks, failure modes, and mitigations are identified, along with a pilot to test voluntary relocation incentives and measure political acceptability.
# - Five annual indicators, with decision thresholds, to guide acceleration/pausing/reversals.
# - A concise, scenario-based cost-benefit: two discount rates (3% and 7%) and three climate-damage trajectories (low/medium/high). In high-damage scenarios, the plan yields positive net benefits that justify the spend; in low-damage scenarios, costs dominate monetized benefits but social equity and resilience benefits remain substantial.
# - Three top assumptions, with probability ranges and sensitivity notes, plus confidence levels and data needs to improve certainty.
#
# 1) Interventions, timing, and approximate budget allocations (10-year horizon)
# Assumptions: construction/relocation cycles phased to minimize disruption and align with a single, accountable program office. 18-month election window will be used to build cross-party credibility through phased milestones and transparency.
#
# A. Nature-based and hybrid defenses (soft defenses + living shorelines + green streets + floodplain restoration)
# - What: 18 km of hybrid shorelines, wetland/mloodplain restoration where feasible, urban green infrastructure (bioswales, rain gardens, permeable pavement), and living breakwaters where practicable.
# - Timing: Phase 1 (Years 1–2): design in the highest-risk corridors, begin 2–3 defense micro-projects; Phase 2 (Years 3–6): scale to additional segments; Phase 3 ( Years 7–10): complete citywide coverage in priority zones.
# - Budget: $700M
# - Rationale: reduces wave/run-up exposure in nearshore and low-lying blocks, provides co-benefits (habitat, recreation, water quality).
#
# B. Hard infrastructure and drainage upgrades (seawalls, flood barriers, pumps, upgraded stormwater drainage)
# - What: targeted seawalls along critical economic corridors and high-value neighborhoods; upgraded pump stations; enhanced pumping/discharge capacity; floodproofing of municipal facilities and critical utilities; improvements to drainage networks to reduce urban flood peaks.
# - Timing: Phase 1 (Years 1–2): procure and begin upgrades in 2–3 high-risk zones (downtown/port area and a major neighborhood cluster); Phase 2 (Years 3–6): expand to additional segments; Phase 3 (Years 7–10): complete all prioritized zones; post-construction commissioning and testing.
# - Budget: $550M
# - Rationale: provides essential protection for critical infrastructure and economic centers with a design emphasis on resilience to higher surge.
#
# C. Targeted buyouts and voluntary relocation (incentives, relocation support, housing assistance)
# - What: voluntary buyouts, relocation assistance, replacement housing options, bridging loans, relocation counseling, and community-based housing supports; explicit policy to maximize voluntary relocations of low-income households; target to minimize involuntary displacement below 5%.
# - Timing: Phase 1 (Years 1–2): launch outreach, secure listings of candidate properties, begin first round of buyouts; Phase 2 (Years 3–6): expand to additional neighborhoods; Phase 3 (Years 7–10): complete program in remaining risk zones; ongoing wraparound services.
# - Budget: $520M
# - Rationale: directly reduces exposure and displacement risk, aligns with equity mandate; incentives and housing assistance are essential to make relocation feasible for poor households.
#
# D. Zoning, building-code changes and land-use planning (elevation, flood-proofing, construction standards)
# - What: elevate new construction and retrofit standards to a 100-year+ flood protection baseline; enforce floodproofing, setback and elevation requirements; update critical infrastructure siting and land-use plans to reduce exposure.
# - Timing: Phase 1 (Years 1–2): adopt updated codes; Phase 2 (Years 2–5): rollout enforcement in new developments and major renovations; Phase 3 (Years 6–10): ensure full citywide adoption and compliance checks.
# - Budget: $140M
# - Rationale: reduces long-term vulnerability in new development and retrofits; ensures that new investments are resilient to higher climate risks.
#
# E. Insurance subsidies and risk financing (premium subsidies, public reinsurance, catastrophe risk pooling)
# - What: subsidies to reduce insurance premiums for at-risk households; enhance city-level catastrophe risk pooling and reinsurance capacity; potential municipal catastrophe fund to bridge investment gaps.
# - Timing: Phase 1 (Years 1–2): establish policy framework; Phase 2 (Years 3–5): scale subsidies; Phase 3 (Years 6–10): sustain program with annual reviews.
# - Budget: $60M
# - Rationale: increases affordability and resilience of households, lowers displacement risk by reducing uninsurable exposure.
#
# F. Governance reforms and implementation management (institutional capacity, data systems, performance dashboards, community engagement)
# - What: new adaptation authority or augmented planning office; centralized data integration; transparent performance dashboards; formal public-engagement mechanisms (including a standing citizen oversight body).
# - Timing: Phase 1 (Year 1): establish governance structure; Phase 2 (Year 2): implement data systems; Phase 3 (Year 3–10): continuous improvement and reporting.
# - Budget: $30M
# - Rationale: ensures plan goes from concept to execution with accountability, reduces political volatility through clear metrics and citizen involvement.
#
# Total: $2.00B (across 10 years)
#
# 2) Quantified outcomes (rough, defensible numbers)
# Assumptions for context:
# - Current baseline annual flood damages (citywide) ≈ $200M per year today under existing conditions.
# - Without action, damages rise as climate risks intensify: low trajectory: +10–20% by 2036; medium: +40–60%; high: +100% (relative to today) by 2036.
# - “Annual damages avoided” reflects citywide reductions from both defenses and relocation in protected zones. Because buyouts/elimination of exposure are concentrated in high-risk areas, the plan yields large reductions where risk is highest.
#
# A. Reduction in expected annual flood damages (citywide, by 2036)
# - Low climate trajectory: post-implementation annual damages ≈ $125–$140M (vs. current $200M baseline; ~40–55% reduction in the high-risk zones and partial protections citywide).
# - Medium trajectory: ≈ $160–$180M (vs. $200M baseline; ~10–25% net reduction in exposure citywide, higher in protected zones).
# - High trajectory: ≈ $250–$260M (vs. $200M baseline; net increases in exposed areas are still offset in defended zones; high exposure mitigated more than baseline in critical cores).
#
# Note: These are citywide, “after-action” estimates that reflect a mix of zone-specific results (large reductions where buyouts/defenses are concentrated, moderate reductions elsewhere).
#
# B. Displaced or relocated people/households (voluntary vs. forced)
# - Total households relocated (voluntary): approximately 3,800–6,500 over 10 years.
# - Total people relocated (assuming ~2.8 persons/household): roughly 10,600–18,000 people.
# - Voluntary vs forced: voluntary ~3,600–6,200 households; forced relocations kept at 0–5% of total relocations (i.e., 0–325 households, ~0–900 people if averages hold).
# - Share of relocations from the bottom income quintile: target ~60–75% of relocations from the two poorest quintiles by year 5–7.
#
# C. Change in socioeconomic equity
# - Equity metric (share of flood-protection benefits and relocation benefits captured by the poorest 20%): increase from a baseline where the bottom quintile benefits minimally to a target where roughly 30–40% of total benefit captured by the bottom quintile, rising to ~50–60% by year 7–10 when combined defense benefits and buyouts are scaled.
# - Net improvement in the city’s distributional equity index (qualitative proxy: reduced exposure for poorest quintiles, improved housing stability, and access to relocation options): modest to meaningful improvements (order of magnitude: 0.15–0.25 on a 0–1 scale by decade end).
#
# 3) The three most important assumptions and sensitivity
# Assumption 1: Climate risk trajectory and damages
# - Assessed probabilities (subject to climate forecast uncertainty): Low ~20%, Medium ~50%, High ~30%.
# - Sensitivity: If high-damage trajectory is underestimated (i.e., damages grow faster or more intensely than modeled), the plan’s monetized benefits rise, improving relative NPV; if damages are lower than anticipated, the plan’s monetized benefits are smaller.
# - Data to improve confidence in 12 months: updated city hazard maps, regional climate model projections, and validated flood- and surge-inundation models, plus realized 2025–2026 flood event data.
#
# Assumption 2: Political will and governance effectiveness
# - Assessed probabilities: Robust cross‑party backing ~40–60%; gridlock or watered‑down reforms ~20–40%.
# - Sensitivity: If governance reforms stall (delayed approvals, fragmentation among council factions), the plan’s ability to execute on time and within budget declines, raising financing risk and delaying benefits.
# - Data to improve confidence in 12 months: a credible governance charter, an independent oversight body with public reporting, and a transparent project schedule with milestones and penalties for delays.
#
# Assumption 3: Uptake and effectiveness of voluntary relocation incentives
# - Assessed probabilities: Uptake of voluntary buyouts reaches target among low-income households ~40–70% over a decade, with 0–5% forced displacements.
# - Sensitivity: Lower uptake rates will preserve exposure in buyout target zones and reduce equity gains; higher-than-expected uptake is favorable but may stress housing markets and require additional supply to avoid adverse outcomes like crowding or re-segregation in receiving communities.
# - Data to improve confidence in 12 months: pilot program uptake data, preference surveys, housing market absorption rates for replacement housing, and interim displacement metrics.
#
# Confidence levels and data to improve confidence (for each major recommendation)
# - Nature-based/Hybrid defenses
#   - Confidence: Medium
#   - Data to improve: updated coastal hazard and hydrodynamic models; constructability and maintenance cost data; coastal erosion and habitat restoration performance data for the chosen sites.
# - Hard infrastructure upgrades
#   - Confidence: Medium
#   - Data to improve: detailed risk maps for critical corridors; pump capacity performance tests; cost-to-benefit for each segment under multiple surge scenarios.
# - Targeted buyouts/relocation
#   - Confidence: Medium
#   - Data to improve: baseline household income, housing stock availability in receiving areas, relocation acceptance rates, and long-term housing affordability post-relocation.
# - Zoning/building-code updates
#   - Confidence: High
#   - Data to improve: enforcement capacity metrics; number of buildings upgraded to code; compliance rates; cost implications for builders and homeowners.
# - Insurance subsidies/risk financing
#   - Confidence: Medium
#   - Data to improve: actuarial data on premiums before/after subsidies; city-level catastrophe fund performance; uptake rates among different income groups.
# - Governance reforms
#   - Confidence: High
#   - Data to improve: formal performance dashboards; independent audit results; citizen engagement metrics; timeliness of approvals.
#
# 4) Top five failure modes and concrete contingency/mitigation steps
# 1) Political backlash and gridlock (council/Council-majorities stall plan)
#    - Mitigations: establish an independent adaptation authority with transparent oversight; adopt a small, credible set of prioritized actions (pilot segments) to demonstrate early wins; set a public, time-bound decision calendar; hold regular, cross-partisan briefings; include a citizen advisory panel with equity-focused representation.
#
# 2) Over- or under-estimation of risk and misalignment of incentives (risk model misfit)
#    - Mitigations: require independent risk validation, implement adaptive management with quarterly reviews, continuously update hazard maps and models with new data; implement conservative design margins on critical assets.
#
# 3) Inadequate buyout uptake and inequitable outcomes (displacement risk and inequity)
#    - Mitigations: enhanced relocation incentives, bridging housing programs, targeted outreach in low-income neighborhoods, clear, transparent eligibility criteria, enforce a strong equity-based targeting framework; ensure receiving housing options are available and affordable.
#
# 4) Adverse land-use and development incentives (developers reoccupying risk zones)
#    - Mitigations: revise zoning to restrict new development in high-risk zones; require elevated or floodproofed designs for new construction in nearshore areas; tie insurance subsidies to compliance; implement buyout-backed redevelopment in safe zones.
#
# 5) Funding shortfalls or cost overruns (budget pressure and political backlash)
#    - Mitigations: establish contingency reserves (5–10%), phased funding with milestone-based releases, performance-based payments for contractors, public-private partnerships where appropriate, and a baseline cost-tracking and audit mechanism.
#
# 6) Environmental justice concerns and potential gentrification
#    - Mitigations: ensure outreach and program design are inclusive; targeted protections for long-term residents; integrate affordable replacement housing options and caps on displacement risks; monitor equity metrics annually.
#
# 5) 12–24 month randomized or quasi-experimental pilot (to increase voluntary relocation participation and measure political acceptability)
# - Objective: test mechanisms to increase voluntary relocation uptake among low-income households and gauge short-term political acceptability of the plan.
# - Design: randomized encouragement design (not forcing participation; households are randomly assigned to receive enhanced relocation incentives and outreach vs standard outreach).
# - Sample frame: households in the top 20% flood-prone neighborhoods with incomes at or below 60% of area median income (AMI); target N ≈ 3,000 households (1,000 per arm if 3-arm design).
# - Treatment arms:
#   - Arm 1: Enhanced incentives package (higher buyout offers, moving stipends, bridging loans, guaranteed replacement housing options, rental assistance, and more robust case management).
#   - Arm 2: Community-based outreach (trusted local organizations, community liaisons, culturally appropriate communications, flexible scheduling and in-language materials; integrated social-support services (counselors)).
#   - Arm 3: Control (standard district outreach, baseline buyout terms; conventional process).
# - Randomization approach:
#   - Randomize at the neighborhood block-group level or household level with stratification by initial income level and flood risk.
# - Primary outcomes:
#   - Outcome A: voluntary buyout uptake rate within 24 months.
#   - Outcome B: expressed willingness to relocate (survey-based) and satisfaction with relocation process (post-relocation survey).
# - Secondary outcomes:
#   - Outcome C: time-to-buyout completion; Outcome D: stabilization of housing costs post-relocation; Outcome E: perceived adequacy and fairness of the process.
# - Ethical safeguards:
#   - Informed consent for data collection, voluntary participation, no penalties for opting out; independent IRB oversight; ensure that relocation supports do not infringe on tenant rights; protect privacy and data security; ensure no coercive pressure from program staff.
# - Evaluation design considerations:
#   - Pre/post surveys; administrative data on offers/acceptances; follow-up at 6, 12, 18, and 24 months; differences-in-differences analysis across arms; budget for independent evaluation.
#
# 6) Five measurable indicators (annual) to monitor and decision thresholds
# - Indicator 1: Annual avoided damages (PV or nominal, baseline year 0 = current damages)
#   - Thresholds: if annual avoided damages lag behind target by >20% for two consecutive years, trigger a mid-course adjustment (expansion of protections or more aggressive buyout terms).
# - Indicator 2: Voluntary relocation uptake rate (annual)
#   - Thresholds: target uptake of 5,000–6,500 households over 10 years; if annual uptake <1,000 for two consecutive years, reassess incentives and outreach.
# - Indicator 3: Forced displacement rate
#   - Thresholds: target ≤5% of total displacements; if forced displacements exceed 10% in any year, pause high-risk relocation products and re-focus on voluntary options.
# - Indicator 4: Equity and beneficiary persistence
#   - Thresholds: share of relocations from bottom income quintiles to be ≥60% by year 5; if below 40%, re-target outreach and eligibility to prioritize bottom quintiles and address barriers.
# - Indicator 5: Public acceptability and trust
#   - Thresholds: annual public opinion index showing ≥60% overall support for the plan; if support below 50% for two consecutive years, implement enhanced transparency measures and broaden community engagement (citizen oversight, town halls, independent fact sheets).
#
# 7) Concise, quantitative cost-benefit estimate under two discount rates and three climate-damage trajectories
# Definitions (conservative, defensible approximations):
# - Baseline citywide annual flood damages today: approximately $200M.
# - Climate trajectories by 2036 (no-action reference):
#   - Low: damages rise to about $220–230M/year (net +10–15%);
#   - Medium: damages rise to about $260–300M/year (+30–50%);
#   - High: damages rise to about $400–420M/year (+100%+).
# - Plan’s monetized benefits (PV of avoided damages; discounted):
#   - Low trajectory (3%): PV of benefits ≈ $0.9B; PV of costs ≈ $2.0B -> Net ≈ -$1.1B
#   - Medium trajectory (3%): PV of benefits ≈ $1.6B; PV of costs ≈ $2.0B -> Net ≈ -$0.4B
#   - High trajectory (3%): PV of benefits ≈ $2.4B; PV of costs ≈ $2.0B -> Net ≈ +$0.4B
# - With 7% discount rate (lower PV for both costs and benefits):
#   - Low trajectory (7%): PV benefits ≈ $0.7B; PV costs ≈ $1.6B -> Net ≈ -$0.9B
#   - Medium trajectory (7%): PV benefits ≈ $1.2B; PV costs ≈ $1.6B -> Net ≈ -$0.4B
#   - High trajectory (7%): PV benefits ≈ $1.9B; PV costs ≈ $1.6B -> Net ≈ +$0.3B
# Interpretation:
# - Direct monetized flood-damage reductions alone suggest a negative or near-neutral net present value at 3% discount for low/medium climate trajectories, and a modest positive result only in a high-damage trajectory. At 7%, the plan becomes more favorable only in the high-damage trajectory; in low/medium trajectories the monetized direct benefits do not cover the upfront costs.
# - Important caveats and non-monetized value: social equity gains, reduced involuntary displacement, health benefits from reduced flood exposure, improved urban resilience, and avoided long-term infrastructure depreciation. If these non-market benefits are monetized (or given a high qualitative weight), the plan’s overall value proposition improves, especially under the medium-to-high climate-damage trajectories.
# - Bottom line: the plan’s monetized direct-damages benefits alone do not guarantee positive NPV under all reasonable climate trajectories and discount rates; however, the plan yields important equity, resilience, and health benefits that justify the investment, particularly if non-market benefits are valued in additional analysis and if higher-damage scenarios materialize.
#
# 8) For each major recommendation, level of confidence and the single data piece that would most increase confidence within 12 months
# - Nature-based and hybrid defenses
#   - Confidence: Medium
#   - Data to increase confidence: cost-effective performance data from pilot segments; long-term maintenance costs; hydrodynamic modeling for proposed living shorelines; performance data from comparable cities.
# - Hard infrastructure upgrades
#   - Confidence: Medium
#   - Data to increase confidence: site-specific design flood levels, pump station performance tests, reliability data, and maintenance cost estimates.
# - Targeted buyouts/relocation
#   - Confidence: Medium
#   - Data to increase confidence: uptake rates, replacement housing availability and affordability, tenant rights outcomes, and relocation completion timelines.
# - Zoning/building-code updates
#   - Confidence: High
#   - Data to increase confidence: compliance rates post-implementation, enforcement costs, permits issued for elevated constructions, and case studies from other jurisdictions.
# - Insurance subsidies/risk financing
#   - Confidence: Medium
#   - Data to increase confidence: premium data before/after subsidies, take-up rates by income groups, and city-level catastrophe fund performance.
# - Governance reforms
#   - Confidence: High
#   - Data to increase confidence: independent audit results, dashboard accuracy and timeliness, citizen engagement metrics.
#
# 9) Trade-offs and explicit design choices
# - Trade-off: Protecting economic centers vs. minimizing displacement
#   - Choice: Prioritize protection for critical economic corridors and municipal facilities, but pair with a robust voluntary relocation program for the most exposed, low-income households to minimize involuntary displacement. This reduces fatal risk to the economy while achieving equity objectives.
# - Trade-off: Upfront costs vs. long-term resilience
#   - Choice: Accept front-loaded capital investment in order to reduce long-term annual damages and emergency response costs; use phased funding to reduce political risk and demonstrate early wins.
# - Trade-off: Hard infrastructure vs. nature-based defenses
#   - Choice: A mix that prioritizes hybrid approaches to reduce costs and maximize co-benefits (habitat, recreation, water quality) while still ensuring protection of key assets with select hard infrastructure segments.
# - Trade-off: Public support vs. rapid implementation
#   - Choice: Build cross-party buy-in through transparent governance, targeted pilots (pilot 12–24 months), and clear communication to avoid derailment by short-term politics.
# - Trade-off: Equity focus vs. political feasibility
#   - Choice: Maintain explicit equity commitments (benefitting the poorest households in relocation and protections) even if it complicates implementation timelines; this preserves mandate integrity and reduces long-term social risk.
#
# 10) 12–24 month pilot specifics (described above)
# - Design: randomized encouragement design evaluating enhanced relocation incentives and enhanced outreach vs standard outreach.
# - Sample: ~3,000 low-income households in high-risk zones (1,000 per arm in a 3-arm design).
# - Outcomes: uptake of voluntary buyouts; willingness to relocate; satisfaction with relocation process; time to completion; equity measures in uptake.
# - Safeguards: informed consent; not coercive; privacy protections; independent evaluation; IRB review; ensure replacement housing supply.
#
# 11) Five actionable indicators to monitor annually (thresholds used to accelerate/pause/reverse)
# - Indicator 1: Annual avoided damages (PV or nominal)
#   - Threshold: if annual avoided damages lag target by >20% for two consecutive years, reallocate resources or adjust incentives.
# - Indicator 2: Voluntary relocation uptake rate
#   - Threshold: annual uptake <1,000 households for two consecutive years triggers plan adjustment and targeted outreach.
# - Indicator 3: Forced displacement rate
#   - Threshold: share of forced relocations >10% of total relocations triggers pause on aggressive buyout pacing and re-target strategies.
# - Indicator 4: Equity attainment
#   - Threshold: share of relocations from bottom quintile <40% by year 5 triggers targeted outreach and policy amendments to improve equity.
# - Indicator 5: Public acceptability and legitimacy
#   - Threshold: citywide support below 50% for two consecutive annual surveys triggers enhanced communications and governance reforms.
#
# 12) Final notes on implementation and confidence
# - The plan is deliberately explicit about trade-offs and is designed to be implemented in a politically plausible, phased manner within the 18-month window and within a $2.0B cap.
# - The proposed pilot provides a concrete means to learn what incentives work in practice to maximize voluntary relocations among low-income households and to gauge short-term political acceptability before scaling to full implementation.
# - The plan assumes a robust, independent governance structure and transparent reporting to build trust across a divided council and the community.
# - If non-market benefits and health co-benefits are monetized in a broader economic analysis (beyond the monetized damages), the plan’s overall value proposition strengthens in all climate trajectories.
#
# If you’d like, I can tailor the numbers to your city’s actual current annual flood damages, hazard maps, housing stock, and existing insurance coverage. I can also prepare a one-page executive summary and a draft governance charter for the adaptation authority to help accelerate a council-ready package.
# Competitor: claude-sonnet-4-5
#
# # 10-Year Coastal Adaptation Plan: Priority-Based Implementation Strategy
#
# ## I. INTERVENTION PORTFOLIO & BUDGET ALLOCATION
#
# ### Phase 1: Immediate Actions (Years 0-3) - $720M
#
# **1. Hybrid Defense for Economic Core ($380M)**
# - **Intervention**: Elevated seawall + tidal marsh restoration along 8 km waterfront downtown/port district
# - **Timing**: Design Y0-1, construction Y1-3
# - **Rationale**: Protects 40% of tax base, employs nature-based buffer where feasible
# - **Expected outcome**: Reduces expected annual damages (EAD) from $180M to $45M in protected zone (~75% reduction for 35,000 jobs, 8,000 residents)
#
# **2. Voluntary Buyout Program - Priority Zones ($200M)**
# - **Intervention**: Purchase 800 properties in highest-risk areas (<2m elevation, repetitive loss history)
# - **Timing**: Rolling enrollment Y0-3, conversion to wetlands Y2-4
# - **Payment structure**: 125% pre-flood fair market value + $50K relocation subsidy + right of first refusal for affordable housing in safer zones
# - **Expected outcome**:
#   - 800 households relocated (est. 2,400 people)
#   - 70% voluntary participation rate (target low-income: 340 households)
#   - Reduces citywide EAD by $28M
#   - Distributional impact: +15% net wealth transfer to participating low-income households vs. status quo erosion
#
# **3. Emergency Building Code Reform ($40M implementation)**
# - **Intervention**: Mandate first-floor elevation +1.2m for new construction/substantial renovation in flood zones; create fast-track permitting + $30M subsidy pool for low-income compliance
# - **Timing**: Ordinance Y0, enforcement Y1+
# - **Expected outcome**: 450 retrofits Y1-10, reducing structure damage 60% per building
#
# **4. Flood Insurance Transition Program ($100M reserve)**
# - **Intervention**: Municipal catastrophe bond + means-tested premium subsidies to prevent NFIP policy lapses
# - **Timing**: Y0-2 setup
# - **Expected outcome**: Maintain 85% insurance coverage (down from 72% without intervention) among bottom income quintile
#
# ### Phase 2: Adaptive Measures (Years 4-7) - $880M
#
# **5. Living Shoreline Expansion ($320M)**
# - **Intervention**: Restore 15 km oyster reefs, salt marshes, and dune systems along eastern residential coast
# - **Timing**: Staged construction Y4-7
# - **Expected outcome**: Attenuate storm surge 20-35 cm, reduce EAD by $52M in adjacent neighborhoods (18,000 residents, 60% below median income)
#
# **6. Strategic Elevation of Critical Infrastructure ($280M)**
# - **Intervention**: Raise 3 sewage treatment plants, 2 power substations, hospital access roads
# - **Timing**: Y4-6
# - **Expected outcome**: Prevent $420M in cascade failures during 100-year event
#
# **7. Affordable Housing Development in Low-Risk Zones ($200M)**
# - **Intervention**: Public-private partnership to build 1,200 units at 60% AMI eligibility on elevated municipal land
# - **Timing**: Y5-8 construction
# - **Expected outcome**: House 600 buyout participants + 600 existing wait-list families, net zero involuntary displacement
#
# **8. Expanded Buyouts - Phase 2 ($80M)**
# - **Intervention**: Additional 250 properties in moderate-risk areas
# - **Timing**: Y5-7
# - **Expected outcome**: 750 people relocated, $9M EAD reduction
#
# ### Phase 3: Resilience Lock-In (Years 8-10) - $400M
#
# **9. Adaptive Traffic & Utility Networks ($220M)**
# - **Intervention**: Reroute 6 arterial roads, elevate water mains, create redundant power loops
# - **Expected outcome**: Reduce post-storm recovery time 40% (economic continuity benefit)
#
# **10. Community Resilience Hubs ($80M)**
# - **Intervention**: Retrofit 12 schools
# Competitor: gemini-2.5-flash
#
# Mayor, Members of the City Council,
#
# This memo outlines a prioritized 10-year adaptation plan for our mid-sized coastal city, designed to address the projected 0.6m average sea-level rise and doubling of 100-year storm surge intensity by 2050, within your $2.0 billion capital budget. My recommendations are based on the core principles of minimizing involuntary displacement, addressing socioeconomic inequality, and balancing long-term resilience with the immediate political context.
#
# ### **1. Prioritized 10-Year Adaptation Plan (Budget: $2.0 Billion)**
#
# Our strategy is a "layered defense" approach, blending protective infrastructure, managed retreat, and city-wide resilience building. It's phased to allow for learning, adaptation, and political navigation.
#
# **Phase 1 (Years 1-3: Immediate Action & Foundation - ~$550 Million)**
# *   **Goal:** Secure critical infrastructure, initiate voluntary programs, and establish regulatory and governance frameworks. Focus on politically feasible, visible projects for early wins.
# *   **Interventions:**
#     1.  **Targeted Soft/Nature-Based Defenses (Primary Priority):** Mangrove restoration, dune creation, and living shorelines in 3-5 high-vulnerability coastal segments. Focus on areas with existing ecological potential or where they can augment existing grey infrastructure.
#         *   *Budget:* $150M.
#         *   *Confidence: High.* *Data Needed:* Comprehensive habitat mapping and high-resolution hydrodynamic modeling to optimize placement and design for maximum wave attenuation.
#     2.  **Critical Infrastructure Hardening (Strategic):** Flood-proofing and elevating key municipal services (e.g., wastewater treatment plants, main hospitals, emergency services hubs) and vital transportation arteries serving economic centers.
#         *   *Budget:* $200M.
#         *   *Confidence: High.* *Data Needed:* Detailed vulnerability assessments for specific critical infrastructure assets under 2050 climate scenarios, including cascading failure analysis.
#     3.  **Voluntary Relocation/Buyout Program - Pilot Phase (Targeted, Equity-Focused):** Launch a pilot program (detailed in Section 5) for 500-700 households in 1-2 of the highest-risk, predominantly low-income neighborhoods. Offer above-market value buyouts (120-130% of pre-flood risk value) and comprehensive assistance for relocation/rehousing in safer, designated "receiving zones."
#         *   *Budget:* $100M.
#         *   *Confidence: Medium.* *Data Needed:* Detailed property valuation data, demographic mapping of high-risk areas, and survey data on relocation preferences/barriers for low-income households.
#     4.  **Zoning & Building Code Updates (Initial Draft & Public Consultation):** Develop new zoning ordinances to restrict new construction in the 50-year floodplain and updated building codes requiring elevated foundations and flood-resistant materials in the 100-year floodplain. Identify and zone initial "receiving zones" for relocated populations.
#         *   *Budget:* $30M (staffing, consultants, extensive public engagement).
#         *   *Confidence: High.* *Data Needed:* Legal review of existing zoning authority and potential eminent domain implications for receiving zones.
#     5.  **Governance Reform - Climate Resilience Office & Stakeholder Task Force:** Establish a dedicated Climate Resilience Office to coordinate efforts and a multi-stakeholder task force (community reps, businesses, environmental groups) to provide ongoing advice and build consensus.
#         *   *Budget:* $20M (initial staffing, office setup).
#         *   *Confidence: High.* *Data Needed:* Best practices from other cities on effective multi-stakeholder governance models for climate adaptation.
#     6.  **Data & Modeling Refinement:** Invest in high-resolution flood modeling, socioeconomic vulnerability mapping, and ecosystem service valuation to inform future interventions.
#         *   *Budget:* $30M.
#         *   *Confidence: High.* *Data Needed:* Existing LiDAR data and bathymetry data for the entire coastal zone.
#     7.  **Public Awareness & Education Campaign:** Launch a city-wide campaign to inform residents about climate risks, the plan, and available resources, fostering community resilience.
#         *   *Budget:* $20M.
#         *   *Confidence: High.* *Data Needed:* Public perception surveys on climate change risks and preferred adaptation strategies.
#
# **Phase 2 (Years 4-7: Scaling Up & Integrated Solutions - ~$850 Million)**
# *   **Goal:** Expand successful pilot programs, implement regulatory changes, and invest in larger-scale, strategically critical infrastructure.
# *   **Interventions:**
#     1.  **Expanded Voluntary Relocation/Buyout Program:** Scale up the program, incorporating lessons learned from the pilot. Continue offering strong incentives for low-income households and expand to other high-risk, non-critical areas. Develop "resilience hubs" in receiving zones with enhanced public services (schools, clinics, community centers).
#         *   *Budget:* $350M.
#         *   *Confidence: Medium.* *Data Needed:* Longitudinal data from the pilot program on participant satisfaction, re-housing success, and community integration.
#     2.  **Major Hard Infrastructure Projects (Strategic Seawalls/Levees):** Construct targeted seawalls or flood barriers to protect specific, high-value economic districts or large dense populations that cannot reasonably be relocated and have clear cost-benefit justification. These will be integrated with nature-based features where possible.
#         *   *Budget:* $300M.
#         *   *Confidence: Medium.* *Data Needed:* Detailed engineering designs and cost-benefit analysis for specific hard infrastructure proposals, including long-term maintenance costs and residual risk assessments.
#     3.  **City-Wide Building Code & Zoning Enforcement:** Implement and rigorously enforce the new zoning ordinances and building codes. Provide subsidies and financial incentives for existing homeowners (especially low-income) to retrofit properties to meet new standards.
#         *   *Budget:* $100M (for subsidies and enforcement).
#         *   *Confidence: High.* *Data Needed:* Baseline data on current building code compliance rates, particularly in vulnerable areas.
#     4.  **Flood-Resilient Green Infrastructure:** Expand green infrastructure projects (e.g., permeable surfaces, bioswales, urban wetlands) throughout the city to manage stormwater, reduce urban heat island effect, and provide flood protection.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Detailed hydrologic modeling to identify optimal locations for green infrastructure to maximize stormwater retention and flood reduction benefits.
#
# **Phase 3 (Years 8-10: Long-Term Resilience & Adaptive Management - ~$600 Million)**
# *   **Goal:** Integrate adaptation into all city planning, continue strategic protection, and prepare for future challenges.
# *   **Interventions:**
#     1.  **Continued Voluntary Relocation/Buyout & Redevelopment:** Sustain the program, strategically acquiring additional high-risk properties and transforming vacated land into nature-based defenses, open space, or buffer zones.
#         *   *Budget:* $200M.
#         *   *Confidence: Medium.* *Data Needed:* Public perception and economic impact studies on the long-term transformation of vacated land and receiving zones.
#     2.  **Regional Collaboration & Early Warning Systems:** Invest in regional partnerships for adaptation strategies (e.g., shared flood models, emergency response protocols) and develop advanced local early warning systems for storm surge and flooding.
#         *   *Budget:* $50M.
#         *   *Confidence: High.* *Data Needed:* Inventory of existing regional agreements and emergency communication protocols.
#     3.  **Adaptive Management Fund:** Establish a dedicated fund for unforeseen adaptation needs, research and development of new technologies, and to scale up or pivot interventions based on monitoring data and evolving climate projections.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Detailed analysis of historical disaster relief spending and potential future funding gaps.
#     4.  **Insurance/Subsidy Program Development:** Collaborate with state and federal partners to develop a specialized flood insurance subsidy program for low-to-moderate income households in remaining high-risk zones who cannot or choose not to relocate, ensuring affordability while incentivizing risk reduction.
#         *   *Budget:* $50M (initial seed funding/subsidies for low-income).
#         *   *Confidence: Medium.* *Data Needed:* Actuarial analysis of current flood insurance uptake and claims among low-income households, and assessment of federal/state appetite for partnership.
#     5.  **Long-term Monitoring & Research:** Continuously monitor sea-level rise, storm intensity, and the effectiveness of all interventions. Fund local research into climate impacts and adaptation solutions.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Baseline ecological data for nature-based solutions and socio-economic data for relocated communities.
#     6.  **Climate-Resilient Infrastructure Upgrades:** Continue investing in upgrades to grey infrastructure (e.g., drainage systems, power grids) to make them more resilient to climate impacts, guided by lessons learned.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Infrastructure condition assessments across all municipal systems.
#
# ### **2. Quantified Expected Outcomes (by 2033 - end of 10-year plan, impacting 2050 targets)**
#
# *   **Reduction in Expected Annual Flood Damages (by 2050):**
#     *   *Baseline (without plan):* Projected $200-300 million annually by 2050.
#     *   *With Plan:* **~60-70% reduction**, bringing annual damages down to **$60-120 million by 2050.**
# *   **Number of People/Households Displaced or Relocated (by 2033):**
#     *   *Voluntary Relocation/Buyouts:* **2,500 - 4,000 households** (approx. 7,500 - 12,000 people) voluntarily relocated through incentivized programs.
#     *   *Forced Displacement:* **Minimized to effectively zero**, fulfilling the legal mandate.
# *   **Change in Socioeconomic Equity (Distributional impact on poorest 20%):**
#     *   **Significant positive impact.** Poorest 20% in high-risk zones will be offered above-market value buyouts and comprehensive relocation support.
#     *   **Quantitative Proxy:** Aim for a **10-15% reduction in the number of households below the poverty line living in the 100-year floodplain** by 2033, and a **25-30% reduction in their expected uninsured flood losses.**
#
# ### **3. Three Most Important Assumptions & Sensitivity**
#
# 1.  **Political Will & Bipartisan Cooperation Persist:**
#     *   *Details:* The $2.0B budget is sustained, and the politically divided council cooperates on necessary legislative changes (zoning, building codes). The upcoming election does not derail the plan.
#     *   *Sensitivity:* **High.** *Violation:* Gridlock or funding cuts (20-40% probability) would cause delays, cost overruns, incomplete projects, and potential failure to meet adaptation goals.
# 2.  **Sufficient Voluntary Participation in Buyout/Relocation:**
#     *   *Details:* Incentives (above-market value, assistance) are sufficient to encourage a critical mass of residents, especially low-income households, to voluntarily participate.
#     *   *Sensitivity:* **Medium-High.** *Violation:* Low participation rates (15-30% probability) would undermine equity goals and the non-displacement mandate, leading to continued exposure and higher future damage costs.
# 3.  **Future Climate Projections are Broadly Accurate:**
#     *   *Details:* The 0.6m SLR and 2x 100-year storm surge by 2050 projections are sufficient for planning.
#     *   *Sensitivity:* **Medium.** *Violation (Worse Case):* Impacts significantly accelerate beyond projections (10-20% probability of underestimation) rendering interventions insufficient, requiring costly emergency upgrades. *Violation (Better Case):* Impacts are less severe (5-10% probability of overestimation) leading to over-investment, though with residual co-benefits.
#
# ### **4. Top Five Failure Modes & Contingency/Mitigation**
#
# 1.  **Failure Mode: Political Backlash & Loss of Public Support.**
#     *   *Contingency:* Implement extensive, ongoing public outreach and education, involve affected communities in co-design, start with successful pilots, and ensure legal robustness of policies.
# 2.  **Failure Mode: Low Voluntary Participation in Buyout/Relocation.**
#     *   *Contingency:* Enhance incentives (increase buyout offers to 150%, expand assistance), empower community-led relocation efforts, invest heavily in attractive "resilience hubs" in receiving zones, and continuously refine strategies based on pilot feedback.
# 3.  **Failure Mode: Cost Overruns & Budget Exhaustion.**
#     *   *Contingency:* Strict project management, rigorous cost estimates, contingency planning, value engineering, active pursuit of state/federal/private grants, and judicious use of the Adaptive Management Fund.
# 4.  **Failure Mode: Maladaptation (Interventions Worsen Problems).**
#     *   *Contingency:* Integrated planning with advanced modeling, thorough Environmental Impact Assessments, robust monitoring and evaluation systems to detect issues early, and active regional collaboration to avoid shifting risks.
# 5.  **Failure Mode: Adverse Incentives (e.g., "Moral Hazard").**
#     *   *Contingency:* Link flood insurance subsidies to mandatory mitigation measures, use risk-based pricing (with affordability measures) to communicate true risk, maintain strict zoning/building codes, and conduct ongoing public education on individual preparedness.
#
# ### **5. Feasible 12–24 Month Randomized or Quasi-Experimental Pilot**
#
# **Objectives:** (a) Increase voluntary participation in relocation/buyout among low-income households, and (b) measure short-term political acceptability.
#
# **Intervention Target:** One of the highest-risk, predominantly low-income neighborhoods (approx. 500-700 households) designated as the "Pilot Zone."
#
# **Treatment Arms (for Voluntary Participation within Pilot Zone):**
# *   **Control Group (N=~200-250 households):** Standard city communications on flood risk; "fair market value" buyout offer (pre-flood risk appraisal).
# *   **Treatment Group 1 (N=~150-200 households):** All control elements PLUS: 120% of pre-flood risk market value buyout; personalized relocation counseling; detailed information on "resilience hubs."
# *   **Treatment Group 2 (N=~150-200 households):** All elements of Treatment Group 1 PLUS: Trusted, paid community relocation liaison; participatory workshops for future land use visioning of the vacated neighborhood.
#
# **Primary Outcomes (12-24 months):**
# *   **(a) Voluntary Participation:** Percentage of households in each group formally accepting a buyout offer.
# *   **(b) Short-Term Political Acceptability (City-wide):** Change in public support for the overall adaptation plan (pre/post city-wide random sample survey, 2,000 registered voters, 5-point Likert scale).
#
# **Ethical Safeguards:** Truly voluntary participation, no diminished services for non-participants, confidentiality of personal data, no "stigma" for control group, clear exit strategy, independent ethical review, and commitment to offering successful treatments to all eligible households post-pilot.
#
# ### **6. Five Measurable Indicators (with Thresholds) for Annual Monitoring**
#
# 1.  **Annual Sea-Level Rise & Storm Surge Frequency/Intensity (Observed vs. Projected):**
#     *   *Metric:* Observed SLR (mm/year) and number of storm surge events >0.5m/1.0m MHHW.
#     *   *Thresholds:* **Accelerate:** SLR > 7mm/year OR 2+ major surge events (>1.0m MHHW) in 3 years. **Pause/Re-evaluate:** SLR < 3mm/year over 5 years.
# 2.  **Voluntary Buyout/Relocation Participation Rate & Equity:**
#     *   *Metric:* % of eligible low-income households accepting buyout offers; % satisfaction with new housing/community for relocated households.
#     *   *Thresholds:* **Accelerate/Enhance:** < 40% participation for low-income OR < 60% satisfaction. **Maintain:** 60-80% participation AND > 75% satisfaction.
# 3.  **Number of Repetitive Flood Claims & Expected Annual Flood Damages (Monetized):**
#     *   *Metric:* % change in properties with 2+ claims in 5 years; estimated annual damages.
#     *   *Thresholds:* **Accelerate:** 10% increase in repetitive claims OR estimated annual damages exceed $150M (inflation-adjusted) for 2 consecutive years. **Maintain:** 5% decrease in claims AND damages below $100M.
# 4.  **Public & Political Acceptance of Adaptation Plan:**
#     *   *Metric:* Quarterly "support for adaptation plan" survey score (avg. 1-5); % of "yes" votes on key council resolutions.
#     *   *Thresholds:* **Accelerate/Adjust Strategy:** Avg. survey score < 3.0 OR > 30% of key council votes fail. **Maintain:** Avg. survey score > 3.5 AND > 70% of key votes pass.
# 5.  **Ecological Health of Nature-Based Defenses (NBDs):**
#     *   *Metric:* % of target NBD area established and healthy; biodiversity index; erosion rates in NBD zones.
#     *   *Thresholds:* **Accelerate/Remediate:** < 70% of target NBD healthy OR significant erosion detected. **Maintain:** > 90% of target NBD healthy AND stable erosion rates.
#
# ...
# | **2025‑2035** | **(D) Zoning & Building‑Code Reform** | • Adopt “Flood‑Resilience Overlay” for all parcels within 0.5 km of projected 2050 shoreline. <br>• Provide fast‑track permits & density bonuses for elevating new construction ≥ 1.2 m above projected BFE. | $100 M | 5 % |
# | **2025‑2028** | **(E) Insurance/Subsidy & Risk‑Education Program** | • Tiered premium subsidies for low‑income (≤ 150 % FPL) – 30 % reduction on NFIP rates. <br>• Community outreach, flood‑risk dashboards, and “Resilience Savings Accounts” (matched grants for home‑hardening). | $100 M | 5 % |
# | **2025‑2027** | **(F) Governance & Institutional Reforms** | • Create a Climate‑Resilience Office (CRO) with authority to coordinate all interventions, monitor performance, and manage the $250 M contingency fund. | $50 M | 2.5 % |
# | **2025‑2026** | **(G) Contingency/Reserve** | • Unspent funds, cost overruns, emergency repairs. | $250 M | 12.5 % |
# | **TOTAL** | | | **$2.0 B** | **100 %** |
#
# *All spending is front‑loaded (≈ 80 % in the first five years) to lock‑in physical protection before the 2030‑mid‑decade storm intensification peak.*
#
# ---
#
# ## 2.  Quantified Expected Outcomes (10‑yr horizon)
#
# | Metric | Baseline (2025) | Projected 2035 (with plan) | Reduction / Improvement | Comments |
# |--------|----------------|----------------------------|--------------------------|----------|
# | **Annual expected flood damage** (direct property & infrastructure) | $300 M (2025) – rising 4 %/yr without action → $440 M by 2035 | $150 M average (2025‑2035) | **≈ 45 % cut** (≈ $135 M/yr avoided) | Savings driven by seawall + nature‑based attenuation (≈ 30 %); buy‑outs eliminate highest‑risk structures (≈ 15 %). |
# | **Households displaced (forced)** | 5 % of at‑risk households (~2 500) would be forced by 2035 under business‑as‑usual | < 200 (≈ 0.2 %) | **≥ 92 % reduction** | All relocation is voluntary; emergency‑evacuation plans limit forced moves. |
# | **Households voluntarily relocated (buy‑out)** | 0 | 2 000 (≈ 5 % of at‑risk) | — | 60 % of these are low‑income → 1 200 poor households. |
# | **Low‑income (bottom 20 %) risk exposure** | 30 % of this group lives in 1‑in‑5 most flood‑prone parcels | 12 % (after buy‑outs + elevation incentives) | **60 % relative risk drop** | Measured as probability of flood depth > 0.5 m per year. |
# | **Flood‑insurance coverage (low‑income)** | 45 % (2025) | 85 % (2028) | +40 ppt | Subsidy + education drives uptake. |
# | **Economic activity protected** | $12 B of taxable commercial/industrial floor space in core district | 95 % retained (seawall protects) | – | Trade‑off: heavy investment in core vs. peripheral neighborhoods. |
#
# ---
#
# ## 3.  Three Core Assumptions & Sensitivity
#
# | # | Assumption | Reasonable Range (probability) | Sensitivity |
# |---|------------|--------------------------------|-------------|
# | **A** | **SLR reaches 0.6 m by 2050** (median IPCC AR6 RCP4.5) | 0.6 m ± 0.1 m (≈ 70 % chance) | *If SLR is > 0.8 m*, seawall freeboard must be increased → extra $150‑200 M. *If SLR is < 0.4 m*, we could defer part of the hard barrier (cost saving ≈ $100 M). |
# | **B** | **100‑yr storm surge intensity doubles** (wind‑speed & surge height) | 2× ± 30 % (≈ 55 % chance) | *If surge increase is only 1.5×*, the hybrid barrier can be built to lower height, saving ≈ $80 M. *If surge spikes to 2.5×*, we would need additional overtopping protection (≈ $120 M). |
# | **C** | **Low‑income households will accept voluntary buy‑outs when offered ≥ 80 % of market value + relocation grant** | Acceptance 70‑85 % (≈ 75 % chance) | *If acceptance falls below 55 %*, we must increase the grant or shift to more aggressive zoning (cost ≈ $50 M). *If acceptance exceeds 90 %*, we could re‑allocate excess funds to nature‑based projects. |
#
# Overall plan success is **medium‑high** (≈ 70 % probability of achieving ≥ 40 % damage reduction and ≤ 200 forced displacements) given current scientific confidence and community‑engagement pilots (see §5).
#
# ---
#
# ## 4.  Top‑5 Failure Modes & Mitigation
#
# | # | Failure Mode | Likely Consequence | Contingency / Mitigation |
# |---|--------------|-------------------|--------------------------|
# | **1** | **Political backlash over “big‑seawall” cost** (election 2027) | Funding freeze, re‑allocation to other priorities | • Phase the barrier (Phase I: 4 km protecting the most critical assets) with clear cost‑benefit communication; <br>• Establish a “Resilience Bond” financed through a modest (0.1 %) property tax dedicated to the project; <br>• Early bipartisan outreach using local business coalition data on avoided losses. |
# | **2** | **Buy‑out program perceived as “selling out” low‑income neighborhoods** | Low participation, protests, legal challenges | • Co‑design the program with community NGOs; <br>• Offer “green‑relocation” grants for moving to affordable, pre‑built resilient housing; <br>• Publicly publish transparent cost‑benefit and equity impact analyses. |
# | **3** | **Gentrification after protection of downtown** (property values surge) | Displacement of renters & small businesses | • Pair the seawall with inclusionary‑housing ordinances that reserve 20 % of new units for households ≤ 150 % FPL; <br>• Use a “Community Land Trust” to hold key parcels for affordable use. |
# | **4** | **Construction delays / cost overruns (seawall, wetlands)** | Budget overspend, missed 2030 target | • Fixed‑price EPC contracts with performance penalties; <br>• Independent “Resilience Oversight Committee” with quarterly audits; <br>• Maintain $250 M contingency reserve (see Table 1). |
# | **5** | **Insurance/subsidy fraud or moral hazard** | Uncontrolled premium losses, reduced fiscal sustainability | • Link subsidies to verified elevation/retrofit standards; <br>• Require annual flood‑risk re‑assessment for continued eligibility; <br>• Use GIS‑based fraud detection analytics. |
#
# ---
#
# ## 5.  12‑24‑Month Pilot to Boost Low‑Income Relocation & Test Political Acceptability
#
# | Element | Design |
# |---------|--------|
# | **Sample frame** | 1 200 low‑income (≤ 150 % FPL) households in the top 30 % flood‑risk parcels (identified via high‑resolution LiDAR flood maps). |
# | **Randomisation** (three arms, 400 households each) | 1. **Cash‑Incentive Arm** – 85 % market‑value buy‑out + $5 k relocation grant (baseline offer). <br>2. **Counselling‑Plus‑Design Arm** – Same cash offer + a dedicated case‑worker, a “design‑your‑new‑home” workshop, and a guaranteed spot in a new affordable‑resilient‑housing complex. <br>3. **Control Arm** – Standard city outreach (information brochure, no additional services). |
# | **Primary outcomes (12‑month horizon)** | • % of households signing a buy‑out agreement (target > 70 % in Arm 2, > 55 % in Arm 1, < 30 % in Control). <br>• Change in “plan acceptability” score (1‑5 Likert) measured via door‑to‑door surveys across the whole pilot area. |
# | **Secondary outcomes** | • Median time from offer to contract signing; <br>• Reported perceived fairness; <br>• Uptake of flood‑insurance among remaining at‑risk households. |
# | **Ethical safeguards** | • Informed consent with clear explanation that participation is voluntary and will not affect eligibility for the standard city program. <br>• Independent Institutional Review Board (IRB) oversight. <br>• Data anonymisation; opt‑out option for any household at any stage. |
# | **Timeline** | • **Month 1‑3** – GIS risk mapping & household recruitment. <br>• **Month 4‑6** – Randomisation & baseline survey. <br>• **Month 7‑18** – Offer rollout, counselling, monitoring. <br>• **Month 19‑24** – Final survey, analysis, policy brief. |
#
# *Result:* The pilot will quantify the “price‑elasticity” of low‑income buy‑out acceptance and provide a rapid gauge of political support (acceptability score) before the 2027 council election.
#
# ---
#
# ## 6.  Five Annual Monitoring Indicators (with Decision Thresholds)
#
# | Indicator | Target (2025‑2035) | Threshold for Action |
# |-----------|-------------------|-----------------------|
# | **1. Annual Flood‑Damage Expenditure** (city‑reported, $M) | ≤ $150 M (average) | > $180 M → Review/strengthen physical defenses (add height, expand nature‑based area). |
# | **2. Low‑Income Flood‑Insurance Coverage** (% of eligible households) | ≥ 85 % | < 70 % → Increase subsidy or expand outreach budget by 20 %. |
# | **3. Voluntary Buy‑Outs Completed** (units/yr) | 200 ± 30 | < 150 yr → Boost cash incentive or expand counselling pilot. |
# | **4. Equity Risk‑Reduction Ratio** (risk reduction for poorest 20 % ÷ city‑wide risk reduction) | ≥ 1.0 (i.e., poorest benefit at least as much) | < 0.8 → Re‑allocate funds to targeted retrofits or expand affordable‑housing set‑aside. |
# | **5. Council/Mayor Public‑Support Index** (average score of city‑wide poll, 1‑5) | ≥ 3.5 (≥ 70 % “support”) | < 3.0 → Launch city‑wide communication campaign; consider adjusting financing mechanism. |
#
# Indicators are compiled by the **Climate‑Resilience Office** and presented at the quarterly City Council “Resilience Review”.
#
# ---
#
# ## 7.  Cost‑Benefit Estimate (NPV, 10 yr)
#
# ### Assumptions
# * **Discount rates**: 3 % (social planner) vs. 7 % (municipal finance).
# * **Damage trajectories** (baseline without adaptation):
#   * **Low** – 1 %/yr increase (minimal storm intensification).
#   * **Medium** – 3 %/yr (current IPCC median).
#   * **High** – 6 %/yr (upper‑range storm surge).
# * **Adaptation effect** – 45 % reduction in damages (flat over the horizon).
#
# | Scenario | Discount % | Present Value of Damages (no action) | PV of Damages **with plan** | PV of Adaptation Cost* | **Net Benefit (NPV)** |
# |----------|-----------|--------------------------------------|----------------------------|------------------------|----------------------|
# | Low | 3 % | $3.2 B | $1.8 B | $1.5 B | **+$0.0 B** |
# | Low | 7 % | $2.8 B | $1.6 B | $1.5 B | **+$0.1 B** |
# | Medium | 3 % | $4.9 B | $2.7 B | $1.5 B | **+$0.7 B** |
# | Medium | 7 % | $4.2 B | $2.3 B | $1.5 B | **+$0.3 B** |
# | High | 3 % | $7.9 B | $4.4 B | $1.5
# Competitor: llama3.2
#
# **Prioritized 10-Year Adaptation Plan**
#
# With a $2.0 billion budget, I propose the following interventions:
#
# 1. **Seawall and Dunes System** (2.5B, $1.25B, 2024-2029):
# 	* Construct a 5 km seawall and build a 3 km long dunes system to protect the city center.
# 	* Expected reduction in annual flood damages: $120 million (20% decrease).
# 	* Number of displaced/households relocated: 10,000 (20% decrease).
# 	* Change in socioeconomic equity: Reduction in flood-related economic hardship among the poorest 20%.
# 2. **Smart Grid and Flood-Proofing Zoning** (400M, $200M, 2024-2028):
# 	* Upgrade the city's electrical grid to withstand flooding and install smart sensors to monitor storm surges.
# 	* Implement zoning regulations that require new construction to be built above grade or use flood-proof materials.
# 3. **Relocation/ Buyout Program** (300M, $150M, 2024-2029):
# 	* Establish a voluntary relocation program for low-income households in high-risk flood areas.
# 	* Offer buyouts or relocation packages to encourage voluntary participation.
# 	* Expected increase in voluntary participation: 40% ( increase in program enrollment).
# 4. **Insurance/Subbidy Programs** (400M, $200M, 2024-2028):
# 	* Implement a city-funded insurance program to cover flood-related losses.
# 	* Offer subsidies to households in high-risk flood areas to help mitigate financial burden.
# 5. **Governance Reforms** (200M, $100M, 2025-2029):
# 	* Implement a participatory budgeting process to ensure inclusive decision-making.
# 	* Establish a flood resiliency trust fund to prioritize adaptation investments.
#
# **Assumptions and Sensitivity**
#
# 1. **Sea-Level Rise and Storm Surge Intensity**: High sensitivity (50% impact on plan's success, 1:1 probability range). Assuming 0.6 m sea-level rise and doubling of 100-year storm surge intensity is a reasonable assumption based on current IPCC projections.
# 2. **Economic Growth and Inflation**: Medium sensitivity (30% impact on plan's success, 2:1 probability range). Assuming a 2% annual economic growth rate and moderate inflation (1.5%) is a conservative estimate based on historical data.
# 3. **Citizen Engagement and Participation**: Medium sensitivity (30% impact on plan's success, 2:1 probability range). Assuming high levels of citizen engagement and participation in the adaptation process is crucial for successful implementation.
#
# **Failure Modes and Contingency Planning**
#
# 1. **Political Backlash**: Establish a stakeholder advisory committee to ensure inclusive decision-making.
# 2. **Adverse Incentives**: Implement a revenue neutral, carbon-fund-based financing mechanism to reduce the burden on taxpayers.
# 3. **Insufficient Public Engagement**: Establish community outreach programs to ensure informed decision-making by all stakeholders.
# 4. **Inadequate Funding**: Prioritize interventions with the greatest expected outcomes and implement phase-in financing plans.
# 5. **Low-Intensity Storms**: Implement adaptive management plans to address unexpected storm intensity.
#
# **Pilot Study**
#
# Title: "Flood-Resilient Neighborhoods"
#
# * Sample Frame: 1,500 low-income households in high-risk flood areas.
# * Treatment Arms:
# 	+ Group A: Standard relocation/buyout program.
# 	+ Group B: Enhanced program with community engagement and education components.
# 	+ Group C: Control group with no additional program components.
# * Primary Outcome: Increase in voluntary participation in the relocation/buyout program among low-income households.
# * Ethical Safeguards: Randomized controlled trial with informed consent and anonymized data.
#
# **Performance Monitoring**
#
# 1. Annual Flood Risk Assessment.
# 2. Displacement/Relocation Program Metrics: Enrollment rates, retention rates, and program effectiveness.
# 3. Economic Benefit Categorization: Reduction in flood-related losses, increase in economic productivity, and reduction in poverty rates.
# 4. Social Equity Metrics: Distribution of benefits, reduction in flood-related hardship among vulnerable populations.
# 5. Stakeholder Engagement Indices: Citizen participation rates, stakeholder satisfaction, and community engagement quality.
#
# **Cost-Benefit Analysis**
#
# Scenario 1 (3% discount rate): -$1.3 billion (benefit: - $1.1 billion displacement cost reduction, - $150 million increased economic costs; - $50 million loss of avoided damages).
#
# Scenario 2 (7% discount rate): -2.1 billion (benefit: - $1.6 billion displacement cost reduction, - $200 million increased economic costs; - $80 million loss of avoided damages).
#
# Scenario 3 (Low Climate Damage Trajectory): +$1.5 billion (benefit: +$1.2 billion displacement cost reduction, + $100 million increased economic costs; -$200 million loss of avoided damages).
#
# Scenario 4 (Medium Climate Damage Trajectory): +$2.2 billion (benefit: +$1.8 billion displacement cost reduction, + $150 million increased economic costs; -$300 million loss of avoided damages).
#
# Scenario 5 (High Climate Damage Trajectory): +$3.2 billion (benefit: +$2.6 billion displacement cost reduction, + $200 million increased economic costs; -$400 million loss of avoided damages).
#
# **Confidence Levels**
#
# 1. Seawall and Dunes System: High (90%), 3D lidar data collection within 12 months to increase confidence.
# 2. Relocation/Buyout Program: High (90%), Establish a stakeholder advisory committee to ensure inclusive decision-making.
# 3. Smart Grid and Flood-Proofing Zoning: Medium (60%), Monitor performance and make adjustments as necessary.
# 4. Insurance/Subsidy Programs: Medium (60%), Develop comprehensive actuarial models to ensure risk-sharing mechanisms are in place.
# 5. Governance Reforms: Medium (60%), Implement participatory budgeting and community outreach programs to ensure inclusive decision-making.
#
# Note: A comprehensive, multi-year implementation plan will require ongoing monitoring, adaptation, and fine-tuning to achieve the planned outcomes. This plan provides a starting point for the city to prioritize their adaptations.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Below is a concrete, donor-ready 10-year adaptation plan tailored to a mid-sized coastal city (population ~500,000) facing 0.6 m sea‑level rise and doubling of 100-year surge by 2050. It is structured to fit a legally binding mandate to minimize involuntary displacement, address inequality, and work within a $2.0B 10-year capital budget while navigating a politically divided council and an election in 18 months.
#
# Executive summary
# - Core goal: reduce flood risk and protect critical economic/urban cores while prioritizing voluntary relocation for the neediest, and strengthening governance so investments are defended by evidence and community legitimacy.
# - Core mix of actions: a balanced portfolio of nature-based and hybrid defenses, targeted hard infrastructure upgrades, a voluntary buyout/relocation program with strong protections for low-income households, updated zoning/building codes, risk financing/subsidies to lower insurance barriers, and governance reforms to enable adaptive management.
# - 10-year budget (not-to-exceed $2.0B):
#   - A) Nature-based/hybrid defenses: $700M
#   - B) Hard infrastructure/drainage upgrades: $550M
#   - C) Targeted buyouts/voluntary relocation: $520M
#   - D) Zoning/building-code updates: $140M
#   - E) Insurance subsidies/risk financing: $60M
#   - F) Governance and implementation management: $30M
#   - Total: $2.00B
# - Expected outcomes (rough, defensible):
#   - Reduction in expected annual flood damages by approximately 60–70% in protected zones; net citywide annual damages reduced from roughly $200M today to the low-to-mid $100Ms by 2036 under the high-damage trajectory, with more modest reductions under lower climate-damage trajectories.
#   - Displacement: voluntary relocations of roughly 3,500–6,000 households (roughly 11,000–17,000 people) over the decade; forced relocations kept at 0–5% of total displacement.
#   - Equity: the program prioritizes the lowest-income households; by year 5–7, the share of relocated households from the bottom two quintiles rises to ~60–75% of relocations; poorest 20% see enhanced protection in protected areas and higher uptake in buyouts where appropriate.
# - Key risks, failure modes, and mitigations are identified, along with a pilot to test voluntary relocation incentives and measure political acceptability.
# - Five annual indicators, with decision thresholds, to guide acceleration/pausing/reversals.
# - A concise, scenario-based cost-benefit: two discount rates (3% and 7%) and three climate-damage trajectories (low/medium/high). In high-damage scenarios, the plan yields positive net benefits that justify the spend; in low-damage scenarios, costs dominate monetized benefits but social equity and resilience benefits remain substantial.
# - Three top assumptions, with probability ranges and sensitivity notes, plus confidence levels and data needs to improve certainty.
#
# 1) Interventions, timing, and approximate budget allocations (10-year horizon)
# Assumptions: construction/relocation cycles phased to minimize disruption and align with a single, accountable program office. 18-month election window will be used to build cross-party credibility through phased milestones and transparency.
#
# A. Nature-based and hybrid defenses (soft defenses + living shorelines + green streets + floodplain restoration)
# - What: 18 km of hybrid shorelines, wetland/mloodplain restoration where feasible, urban green infrastructure (bioswales, rain gardens, permeable pavement), and living breakwaters where practicable.
# - Timing: Phase 1 (Years 1–2): design in the highest-risk corridors, begin 2–3 defense micro-projects; Phase 2 (Years 3–6): scale to additional segments; Phase 3 ( Years 7–10): complete citywide coverage in priority zones.
# - Budget: $700M
# - Rationale: reduces wave/run-up exposure in nearshore and low-lying blocks, provides co-benefits (habitat, recreation, water quality).
#
# B. Hard infrastructure and drainage upgrades (seawalls, flood barriers, pumps, upgraded stormwater drainage)
# - What: targeted seawalls along critical economic corridors and high-value neighborhoods; upgraded pump stations; enhanced pumping/discharge capacity; floodproofing of municipal facilities and critical utilities; improvements to drainage networks to reduce urban flood peaks.
# - Timing: Phase 1 (Years 1–2): procure and begin upgrades in 2–3 high-risk zones (downtown/port area and a major neighborhood cluster); Phase 2 (Years 3–6): expand to additional segments; Phase 3 (Years 7–10): complete all prioritized zones; post-construction commissioning and testing.
# - Budget: $550M
# - Rationale: provides essential protection for critical infrastructure and economic centers with a design emphasis on resilience to higher surge.
#
# C. Targeted buyouts and voluntary relocation (incentives, relocation support, housing assistance)
# - What: voluntary buyouts, relocation assistance, replacement housing options, bridging loans, relocation counseling, and community-based housing supports; explicit policy to maximize voluntary relocations of low-income households; target to minimize involuntary displacement below 5%.
# - Timing: Phase 1 (Years 1–2): launch outreach, secure listings of candidate properties, begin first round of buyouts; Phase 2 (Years 3–6): expand to additional neighborhoods; Phase 3 (Years 7–10): complete program in remaining risk zones; ongoing wraparound services.
# - Budget: $520M
# - Rationale: directly reduces exposure and displacement risk, aligns with equity mandate; incentives and housing assistance are essential to make relocation feasible for poor households.
#
# D. Zoning, building-code changes and land-use planning (elevation, flood-proofing, construction standards)
# - What: elevate new construction and retrofit standards to a 100-year+ flood protection baseline; enforce floodproofing, setback and elevation requirements; update critical infrastructure siting and land-use plans to reduce exposure.
# - Timing: Phase 1 (Years 1–2): adopt updated codes; Phase 2 (Years 2–5): rollout enforcement in new developments and major renovations; Phase 3 (Years 6–10): ensure full citywide adoption and compliance checks.
# - Budget: $140M
# - Rationale: reduces long-term vulnerability in new development and retrofits; ensures that new investments are resilient to higher climate risks.
#
# E. Insurance subsidies and risk financing (premium subsidies, public reinsurance, catastrophe risk pooling)
# - What: subsidies to reduce insurance premiums for at-risk households; enhance city-level catastrophe risk pooling and reinsurance capacity; potential municipal catastrophe fund to bridge investment gaps.
# - Timing: Phase 1 (Years 1–2): establish policy framework; Phase 2 (Years 3–5): scale subsidies; Phase 3 (Years 6–10): sustain program with annual reviews.
# - Budget: $60M
# - Rationale: increases affordability and resilience of households, lowers displacement risk by reducing uninsurable exposure.
#
# F. Governance reforms and implementation management (institutional capacity, data systems, performance dashboards, community engagement)
# - What: new adaptation authority or augmented planning office; centralized data integration; transparent performance dashboards; formal public-engagement mechanisms (including a standing citizen oversight body).
# - Timing: Phase 1 (Year 1): establish governance structure; Phase 2 (Year 2): implement data systems; Phase 3 (Year 3–10): continuous improvement and reporting.
# - Budget: $30M
# - Rationale: ensures plan goes from concept to execution with accountability, reduces political volatility through clear metrics and citizen involvement.
#
# Total: $2.00B (across 10 years)
#
# 2) Quantified outcomes (rough, defensible numbers)
# Assumptions for context:
# - Current baseline annual flood damages (citywide) ≈ $200M per year today under existing conditions.
# - Without action, damages rise as climate risks intensify: low trajectory: +10–20% by 2036; medium: +40–60%; high: +100% (relative to today) by 2036.
# - “Annual damages avoided” reflects citywide reductions from both defenses and relocation in protected zones. Because buyouts/elimination of exposure are concentrated in high-risk areas, the plan yields large reductions where risk is highest.
#
# A. Reduction in expected annual flood damages (citywide, by 2036)
# - Low climate trajectory: post-implementation annual damages ≈ $125–$140M (vs. current $200M baseline; ~40–55% reduction in the high-risk zones and partial protections citywide).
# - Medium trajectory: ≈ $160–$180M (vs. $200M baseline; ~10–25% net reduction in exposure citywide, higher in protected zones).
# - High trajectory: ≈ $250–$260M (vs. $200M baseline; net increases in exposed areas are still offset in defended zones; high exposure mitigated more than baseline in critical cores).
#
# Note: These are citywide, “after-action” estimates that reflect a mix of zone-specific results (large reductions where buyouts/defenses are concentrated, moderate reductions elsewhere).
#
# B. Displaced or relocated people/households (voluntary vs. forced)
# - Total households relocated (voluntary): approximately 3,800–6,500 over 10 years.
# - Total people relocated (assuming ~2.8 persons/household): roughly 10,600–18,000 people.
# - Voluntary vs forced: voluntary ~3,600–6,200 households; forced relocations kept at 0–5% of total relocations (i.e., 0–325 households, ~0–900 people if averages hold).
# - Share of relocations from the bottom income quintile: target ~60–75% of relocations from the two poorest quintiles by year 5–7.
#
# C. Change in socioeconomic equity
# - Equity metric (share of flood-protection benefits and relocation benefits captured by the poorest 20%): increase from a baseline where the bottom quintile benefits minimally to a target where roughly 30–40% of total benefit captured by the bottom quintile, rising to ~50–60% by year 7–10 when combined defense benefits and buyouts are scaled.
# - Net improvement in the city’s distributional equity index (qualitative proxy: reduced exposure for poorest quintiles, improved housing stability, and access to relocation options): modest to meaningful improvements (order of magnitude: 0.15–0.25 on a 0–1 scale by decade end).
#
# 3) The three most important assumptions and sensitivity
# Assumption 1: Climate risk trajectory and damages
# - Assessed probabilities (subject to climate forecast uncertainty): Low ~20%, Medium ~50%, High ~30%.
# - Sensitivity: If high-damage trajectory is underestimated (i.e., damages grow faster or more intensely than modeled), the plan’s monetized benefits rise, improving relative NPV; if damages are lower than anticipated, the plan’s monetized benefits are smaller.
# - Data to improve confidence in 12 months: updated city hazard maps, regional climate model projections, and validated flood- and surge-inundation models, plus realized 2025–2026 flood event data.
#
# Assumption 2: Political will and governance effectiveness
# - Assessed probabilities: Robust cross‑party backing ~40–60%; gridlock or watered‑down reforms ~20–40%.
# - Sensitivity: If governance reforms stall (delayed approvals, fragmentation among council factions), the plan’s ability to execute on time and within budget declines, raising financing risk and delaying benefits.
# - Data to improve confidence in 12 months: a credible governance charter, an independent oversight body with public reporting, and a transparent project schedule with milestones and penalties for delays.
#
# Assumption 3: Uptake and effectiveness of voluntary relocation incentives
# - Assessed probabilities: Uptake of voluntary buyouts reaches target among low-income households ~40–70% over a decade, with 0–5% forced displacements.
# - Sensitivity: Lower uptake rates will preserve exposure in buyout target zones and reduce equity gains; higher-than-expected uptake is favorable but may stress housing markets and require additional supply to avoid adverse outcomes like crowding or re-segregation in receiving communities.
# - Data to improve confidence in 12 months: pilot program uptake data, preference surveys, housing market absorption rates for replacement housing, and interim displacement metrics.
#
# Confidence levels and data to improve confidence (for each major recommendation)
# - Nature-based/Hybrid defenses
#   - Confidence: Medium
#   - Data to improve: updated coastal hazard and hydrodynamic models; constructability and maintenance cost data; coastal erosion and habitat restoration performance data for the chosen sites.
# - Hard infrastructure upgrades
#   - Confidence: Medium
#   - Data to improve: detailed risk maps for critical corridors; pump capacity performance tests; cost-to-benefit for each segment under multiple surge scenarios.
# - Targeted buyouts/relocation
#   - Confidence: Medium
#   - Data to improve: baseline household income, housing stock availability in receiving areas, relocation acceptance rates, and long-term housing affordability post-relocation.
# - Zoning/building-code updates
#   - Confidence: High
#   - Data to improve: enforcement capacity metrics; number of buildings upgraded to code; compliance rates; cost implications for builders and homeowners.
# - Insurance subsidies/risk financing
#   - Confidence: Medium
#   - Data to improve: actuarial data on premiums before/after subsidies; city-level catastrophe fund performance; uptake rates among different income groups.
# - Governance reforms
#   - Confidence: High
#   - Data to improve: formal performance dashboards; independent audit results; citizen engagement metrics; timeliness of approvals.
#
# 4) Top five failure modes and concrete contingency/mitigation steps
# 1) Political backlash and gridlock (council/Council-majorities stall plan)
#    - Mitigations: establish an independent adaptation authority with transparent oversight; adopt a small, credible set of prioritized actions (pilot segments) to demonstrate early wins; set a public, time-bound decision calendar; hold regular, cross-partisan briefings; include a citizen advisory panel with equity-focused representation.
#
# 2) Over- or under-estimation of risk and misalignment of incentives (risk model misfit)
#    - Mitigations: require independent risk validation, implement adaptive management with quarterly reviews, continuously update hazard maps and models with new data; implement conservative design margins on critical assets.
#
# 3) Inadequate buyout uptake and inequitable outcomes (displacement risk and inequity)
#    - Mitigations: enhanced relocation incentives, bridging housing programs, targeted outreach in low-income neighborhoods, clear, transparent eligibility criteria, enforce a strong equity-based targeting framework; ensure receiving housing options are available and affordable.
#
# 4) Adverse land-use and development incentives (developers reoccupying risk zones)
#    - Mitigations: revise zoning to restrict new development in high-risk zones; require elevated or floodproofed designs for new construction in nearshore areas; tie insurance subsidies to compliance; implement buyout-backed redevelopment in safe zones.
#
# 5) Funding shortfalls or cost overruns (budget pressure and political backlash)
#    - Mitigations: establish contingency reserves (5–10%), phased funding with milestone-based releases, performance-based payments for contractors, public-private partnerships where appropriate, and a baseline cost-tracking and audit mechanism.
#
# 6) Environmental justice concerns and potential gentrification
#    - Mitigations: ensure outreach and program design are inclusive; targeted protections for long-term residents; integrate affordable replacement housing options and caps on displacement risks; monitor equity metrics annually.
#
# 5) 12–24 month randomized or quasi-experimental pilot (to increase voluntary relocation participation and measure political acceptability)
# - Objective: test mechanisms to increase voluntary relocation uptake among low-income households and gauge short-term political acceptability of the plan.
# - Design: randomized encouragement design (not forcing participation; households are randomly assigned to receive enhanced relocation incentives and outreach vs standard outreach).
# - Sample frame: households in the top 20% flood-prone neighborhoods with incomes at or below 60% of area median income (AMI); target N ≈ 3,000 households (1,000 per arm if 3-arm design).
# - Treatment arms:
#   - Arm 1: Enhanced incentives package (higher buyout offers, moving stipends, bridging loans, guaranteed replacement housing options, rental assistance, and more robust case management).
#   - Arm 2: Community-based outreach (trusted local organizations, community liaisons, culturally appropriate communications, flexible scheduling and in-language materials; integrated social-support services (counselors)).
#   - Arm 3: Control (standard district outreach, baseline buyout terms; conventional process).
# - Randomization approach:
#   - Randomize at the neighborhood block-group level or household level with stratification by initial income level and flood risk.
# - Primary outcomes:
#   - Outcome A: voluntary buyout uptake rate within 24 months.
#   - Outcome B: expressed willingness to relocate (survey-based) and satisfaction with relocation process (post-relocation survey).
# - Secondary outcomes:
#   - Outcome C: time-to-buyout completion; Outcome D: stabilization of housing costs post-relocation; Outcome E: perceived adequacy and fairness of the process.
# - Ethical safeguards:
#   - Informed consent for data collection, voluntary participation, no penalties for opting out; independent IRB oversight; ensure that relocation supports do not infringe on tenant rights; protect privacy and data security; ensure no coercive pressure from program staff.
# - Evaluation design considerations:
#   - Pre/post surveys; administrative data on offers/acceptances; follow-up at 6, 12, 18, and 24 months; differences-in-differences analysis across arms; budget for independent evaluation.
#
# 6) Five measurable indicators (annual) to monitor and decision thresholds
# - Indicator 1: Annual avoided damages (PV or nominal, baseline year 0 = current damages)
#   - Thresholds: if annual avoided damages lag behind target by >20% for two consecutive years, trigger a mid-course adjustment (expansion of protections or more aggressive buyout terms).
# - Indicator 2: Voluntary relocation uptake rate (annual)
#   - Thresholds: target uptake of 5,000–6,500 households over 10 years; if annual uptake <1,000 for two consecutive years, reassess incentives and outreach.
# - Indicator 3: Forced displacement rate
#   - Thresholds: target ≤5% of total displacements; if forced displacements exceed 10% in any year, pause high-risk relocation products and re-focus on voluntary options.
# - Indicator 4: Equity and beneficiary persistence
#   - Thresholds: share of relocations from bottom income quintiles to be ≥60% by year 5; if below 40%, re-target outreach and eligibility to prioritize bottom quintiles and address barriers.
# - Indicator 5: Public acceptability and trust
#   - Thresholds: annual public opinion index showing ≥60% overall support for the plan; if support below 50% for two consecutive years, implement enhanced transparency measures and broaden community engagement (citizen oversight, town halls, independent fact sheets).
#
# 7) Concise, quantitative cost-benefit estimate under two discount rates and three climate-damage trajectories
# Definitions (conservative, defensible approximations):
# - Baseline citywide annual flood damages today: approximately $200M.
# - Climate trajectories by 2036 (no-action reference):
#   - Low: damages rise to about $220–230M/year (net +10–15%);
#   - Medium: damages rise to about $260–300M/year (+30–50%);
#   - High: damages rise to about $400–420M/year (+100%+).
# - Plan’s monetized benefits (PV of avoided damages; discounted):
#   - Low trajectory (3%): PV of benefits ≈ $0.9B; PV of costs ≈ $2.0B -> Net ≈ -$1.1B
#   - Medium trajectory (3%): PV of benefits ≈ $1.6B; PV of costs ≈ $2.0B -> Net ≈ -$0.4B
#   - High trajectory (3%): PV of benefits ≈ $2.4B; PV of costs ≈ $2.0B -> Net ≈ +$0.4B
# - With 7% discount rate (lower PV for both costs and benefits):
#   - Low trajectory (7%): PV benefits ≈ $0.7B; PV costs ≈ $1.6B -> Net ≈ -$0.9B
#   - Medium trajectory (7%): PV benefits ≈ $1.2B; PV costs ≈ $1.6B -> Net ≈ -$0.4B
#   - High trajectory (7%): PV benefits ≈ $1.9B; PV costs ≈ $1.6B -> Net ≈ +$0.3B
# Interpretation:
# - Direct monetized flood-damage reductions alone suggest a negative or near-neutral net present value at 3% discount for low/medium climate trajectories, and a modest positive result only in a high-damage trajectory. At 7%, the plan becomes more favorable only in the high-damage trajectory; in low/medium trajectories the monetized direct benefits do not cover the upfront costs.
# - Important caveats and non-monetized value: social equity gains, reduced involuntary displacement, health benefits from reduced flood exposure, improved urban resilience, and avoided long-term infrastructure depreciation. If these non-market benefits are monetized (or given a high qualitative weight), the plan’s overall value proposition improves, especially under the medium-to-high climate-damage trajectories.
# - Bottom line: the plan’s monetized direct-damages benefits alone do not guarantee positive NPV under all reasonable climate trajectories and discount rates; however, the plan yields important equity, resilience, and health benefits that justify the investment, particularly if non-market benefits are valued in additional analysis and if higher-damage scenarios materialize.
#
# 8) For each major recommendation, level of confidence and the single data piece that would most increase confidence within 12 months
# - Nature-based and hybrid defenses
#   - Confidence: Medium
#   - Data to increase confidence: cost-effective performance data from pilot segments; long-term maintenance costs; hydrodynamic modeling for proposed living shorelines; performance data from comparable cities.
# - Hard infrastructure upgrades
#   - Confidence: Medium
#   - Data to increase confidence: site-specific design flood levels, pump station performance tests, reliability data, and maintenance cost estimates.
# - Targeted buyouts/relocation
#   - Confidence: Medium
#   - Data to increase confidence: uptake rates, replacement housing availability and affordability, tenant rights outcomes, and relocation completion timelines.
# - Zoning/building-code updates
#   - Confidence: High
#   - Data to increase confidence: compliance rates post-implementation, enforcement costs, permits issued for elevated constructions, and case studies from other jurisdictions.
# - Insurance subsidies/risk financing
#   - Confidence: Medium
#   - Data to increase confidence: premium data before/after subsidies, take-up rates by income groups, and city-level catastrophe fund performance.
# - Governance reforms
#   - Confidence: High
#   - Data to increase confidence: independent audit results, dashboard accuracy and timeliness, citizen engagement metrics.
#
# 9) Trade-offs and explicit design choices
# - Trade-off: Protecting economic centers vs. minimizing displacement
#   - Choice: Prioritize protection for critical economic corridors and municipal facilities, but pair with a robust voluntary relocation program for the most exposed, low-income households to minimize involuntary displacement. This reduces fatal risk to the economy while achieving equity objectives.
# - Trade-off: Upfront costs vs. long-term resilience
#   - Choice: Accept front-loaded capital investment in order to reduce long-term annual damages and emergency response costs; use phased funding to reduce political risk and demonstrate early wins.
# - Trade-off: Hard infrastructure vs. nature-based defenses
#   - Choice: A mix that prioritizes hybrid approaches to reduce costs and maximize co-benefits (habitat, recreation, water quality) while still ensuring protection of key assets with select hard infrastructure segments.
# - Trade-off: Public support vs. rapid implementation
#   - Choice: Build cross-party buy-in through transparent governance, targeted pilots (pilot 12–24 months), and clear communication to avoid derailment by short-term politics.
# - Trade-off: Equity focus vs. political feasibility
#   - Choice: Maintain explicit equity commitments (benefitting the poorest households in relocation and protections) even if it complicates implementation timelines; this preserves mandate integrity and reduces long-term social risk.
#
# 10) 12–24 month pilot specifics (described above)
# - Design: randomized encouragement design evaluating enhanced relocation incentives and enhanced outreach vs standard outreach.
# - Sample: ~3,000 low-income households in high-risk zones (1,000 per arm in a 3-arm design).
# - Outcomes: uptake of voluntary buyouts; willingness to relocate; satisfaction with relocation process; time to completion; equity measures in uptake.
# - Safeguards: informed consent; not coercive; privacy protections; independent evaluation; IRB review; ensure replacement housing supply.
#
# 11) Five actionable indicators to monitor annually (thresholds used to accelerate/pause/reverse)
# - Indicator 1: Annual avoided damages (PV or nominal)
#   - Threshold: if annual avoided damages lag target by >20% for two consecutive years, reallocate resources or adjust incentives.
# - Indicator 2: Voluntary relocation uptake rate
#   - Threshold: annual uptake <1,000 households for two consecutive years triggers plan adjustment and targeted outreach.
# - Indicator 3: Forced displacement rate
#   - Threshold: share of forced relocations >10% of total relocations triggers pause on aggressive buyout pacing and re-target strategies.
# - Indicator 4: Equity attainment
#   - Threshold: share of relocations from bottom quintile <40% by year 5 triggers targeted outreach and policy amendments to improve equity.
# - Indicator 5: Public acceptability and legitimacy
#   - Threshold: citywide support below 50% for two consecutive annual surveys triggers enhanced communications and governance reforms.
#
# 12) Final notes on implementation and confidence
# - The plan is deliberately explicit about trade-offs and is designed to be implemented in a politically plausible, phased manner within the 18-month window and within a $2.0B cap.
# - The proposed pilot provides a concrete means to learn what incentives work in practice to maximize voluntary relocations among low-income households and to gauge short-term political acceptability before scaling to full implementation.
# - The plan assumes a robust, independent governance structure and transparent reporting to build trust across a divided council and the community.
# - If non-market benefits and health co-benefits are monetized in a broader economic analysis (beyond the monetized damages), the plan’s overall value proposition strengthens in all climate trajectories.
#
# If you’d like, I can tailor the numbers to your city’s actual current annual flood damages, hazard maps, housing stock, and existing insurance coverage. I can also prepare a one-page executive summary and a draft governance charter for the adaptation authority to help accelerate a council-ready package.
#
# # Response from competitor 2
#
# # 10-Year Coastal Adaptation Plan: Priority-Based Implementation Strategy
#
# ## I. INTERVENTION PORTFOLIO & BUDGET ALLOCATION
#
# ### Phase 1: Immediate Actions (Years 0-3) - $720M
#
# **1. Hybrid Defense for Economic Core ($380M)**
# - **Intervention**: Elevated seawall + tidal marsh restoration along 8 km waterfront downtown/port district
# - **Timing**: Design Y0-1, construction Y1-3
# - **Rationale**: Protects 40% of tax base, employs nature-based buffer where feasible
# - **Expected outcome**: Reduces expected annual damages (EAD) from $180M to $45M in protected zone (~75% reduction for 35,000 jobs, 8,000 residents)
#
# **2. Voluntary Buyout Program - Priority Zones ($200M)**
# - **Intervention**: Purchase 800 properties in highest-risk areas (<2m elevation, repetitive loss history)
# - **Timing**: Rolling enrollment Y0-3, conversion to wetlands Y2-4
# - **Payment structure**: 125% pre-flood fair market value + $50K relocation subsidy + right of first refusal for affordable housing in safer zones
# - **Expected outcome**:
#   - 800 households relocated (est. 2,400 people)
#   - 70% voluntary participation rate (target low-income: 340 households)
#   - Reduces citywide EAD by $28M
#   - Distributional impact: +15% net wealth transfer to participating low-income households vs. status quo erosion
#
# **3. Emergency Building Code Reform ($40M implementation)**
# - **Intervention**: Mandate first-floor elevation +1.2m for new construction/substantial renovation in flood zones; create fast-track permitting + $30M subsidy pool for low-income compliance
# - **Timing**: Ordinance Y0, enforcement Y1+
# - **Expected outcome**: 450 retrofits Y1-10, reducing structure damage 60% per building
#
# **4. Flood Insurance Transition Program ($100M reserve)**
# - **Intervention**: Municipal catastrophe bond + means-tested premium subsidies to prevent NFIP policy lapses
# - **Timing**: Y0-2 setup
# - **Expected outcome**: Maintain 85% insurance coverage (down from 72% without intervention) among bottom income quintile
#
# ### Phase 2: Adaptive Measures (Years 4-7) - $880M
#
# **5. Living Shoreline Expansion ($320M)**
# - **Intervention**: Restore 15 km oyster reefs, salt marshes, and dune systems along eastern residential coast
# - **Timing**: Staged construction Y4-7
# - **Expected outcome**: Attenuate storm surge 20-35 cm, reduce EAD by $52M in adjacent neighborhoods (18,000 residents, 60% below median income)
#
# **6. Strategic Elevation of Critical Infrastructure ($280M)**
# - **Intervention**: Raise 3 sewage treatment plants, 2 power substations, hospital access roads
# - **Timing**: Y4-6
# - **Expected outcome**: Prevent $420M in cascade failures during 100-year event
#
# **7. Affordable Housing Development in Low-Risk Zones ($200M)**
# - **Intervention**: Public-private partnership to build 1,200 units at 60% AMI eligibility on elevated municipal land
# - **Timing**: Y5-8 construction
# - **Expected outcome**: House 600 buyout participants + 600 existing wait-list families, net zero involuntary displacement
#
# **8. Expanded Buyouts - Phase 2 ($80M)**
# - **Intervention**: Additional 250 properties in moderate-risk areas
# - **Timing**: Y5-7
# - **Expected outcome**: 750 people relocated, $9M EAD reduction
#
# ### Phase 3: Resilience Lock-In (Years 8-10) - $400M
#
# **9. Adaptive Traffic & Utility Networks ($220M)**
# - **Intervention**: Reroute 6 arterial roads, elevate water mains, create redundant power loops
# - **Expected outcome**: Reduce post-storm recovery time 40% (economic continuity benefit)
#
# **10. Community Resilience Hubs ($80M)**
# - **Intervention**: Retrofit 12 schools
#
# # Response from competitor 3
#
# Mayor, Members of the City Council,
#
# This memo outlines a prioritized 10-year adaptation plan for our mid-sized coastal city, designed to address the projected 0.6m average sea-level rise and doubling of 100-year storm surge intensity by 2050, within your $2.0 billion capital budget. My recommendations are based on the core principles of minimizing involuntary displacement, addressing socioeconomic inequality, and balancing long-term resilience with the immediate political context.
#
# ### **1. Prioritized 10-Year Adaptation Plan (Budget: $2.0 Billion)**
#
# Our strategy is a "layered defense" approach, blending protective infrastructure, managed retreat, and city-wide resilience building. It's phased to allow for learning, adaptation, and political navigation.
#
# **Phase 1 (Years 1-3: Immediate Action & Foundation - ~$550 Million)**
# *   **Goal:** Secure critical infrastructure, initiate voluntary programs, and establish regulatory and governance frameworks. Focus on politically feasible, visible projects for early wins.
# *   **Interventions:**
#     1.  **Targeted Soft/Nature-Based Defenses (Primary Priority):** Mangrove restoration, dune creation, and living shorelines in 3-5 high-vulnerability coastal segments. Focus on areas with existing ecological potential or where they can augment existing grey infrastructure.
#         *   *Budget:* $150M.
#         *   *Confidence: High.* *Data Needed:* Comprehensive habitat mapping and high-resolution hydrodynamic modeling to optimize placement and design for maximum wave attenuation.
#     2.  **Critical Infrastructure Hardening (Strategic):** Flood-proofing and elevating key municipal services (e.g., wastewater treatment plants, main hospitals, emergency services hubs) and vital transportation arteries serving economic centers.
#         *   *Budget:* $200M.
#         *   *Confidence: High.* *Data Needed:* Detailed vulnerability assessments for specific critical infrastructure assets under 2050 climate scenarios, including cascading failure analysis.
#     3.  **Voluntary Relocation/Buyout Program - Pilot Phase (Targeted, Equity-Focused):** Launch a pilot program (detailed in Section 5) for 500-700 households in 1-2 of the highest-risk, predominantly low-income neighborhoods. Offer above-market value buyouts (120-130% of pre-flood risk value) and comprehensive assistance for relocation/rehousing in safer, designated "receiving zones."
#         *   *Budget:* $100M.
#         *   *Confidence: Medium.* *Data Needed:* Detailed property valuation data, demographic mapping of high-risk areas, and survey data on relocation preferences/barriers for low-income households.
#     4.  **Zoning & Building Code Updates (Initial Draft & Public Consultation):** Develop new zoning ordinances to restrict new construction in the 50-year floodplain and updated building codes requiring elevated foundations and flood-resistant materials in the 100-year floodplain. Identify and zone initial "receiving zones" for relocated populations.
#         *   *Budget:* $30M (staffing, consultants, extensive public engagement).
#         *   *Confidence: High.* *Data Needed:* Legal review of existing zoning authority and potential eminent domain implications for receiving zones.
#     5.  **Governance Reform - Climate Resilience Office & Stakeholder Task Force:** Establish a dedicated Climate Resilience Office to coordinate efforts and a multi-stakeholder task force (community reps, businesses, environmental groups) to provide ongoing advice and build consensus.
#         *   *Budget:* $20M (initial staffing, office setup).
#         *   *Confidence: High.* *Data Needed:* Best practices from other cities on effective multi-stakeholder governance models for climate adaptation.
#     6.  **Data & Modeling Refinement:** Invest in high-resolution flood modeling, socioeconomic vulnerability mapping, and ecosystem service valuation to inform future interventions.
#         *   *Budget:* $30M.
#         *   *Confidence: High.* *Data Needed:* Existing LiDAR data and bathymetry data for the entire coastal zone.
#     7.  **Public Awareness & Education Campaign:** Launch a city-wide campaign to inform residents about climate risks, the plan, and available resources, fostering community resilience.
#         *   *Budget:* $20M.
#         *   *Confidence: High.* *Data Needed:* Public perception surveys on climate change risks and preferred adaptation strategies.
#
# **Phase 2 (Years 4-7: Scaling Up & Integrated Solutions - ~$850 Million)**
# *   **Goal:** Expand successful pilot programs, implement regulatory changes, and invest in larger-scale, strategically critical infrastructure.
# *   **Interventions:**
#     1.  **Expanded Voluntary Relocation/Buyout Program:** Scale up the program, incorporating lessons learned from the pilot. Continue offering strong incentives for low-income households and expand to other high-risk, non-critical areas. Develop "resilience hubs" in receiving zones with enhanced public services (schools, clinics, community centers).
#         *   *Budget:* $350M.
#         *   *Confidence: Medium.* *Data Needed:* Longitudinal data from the pilot program on participant satisfaction, re-housing success, and community integration.
#     2.  **Major Hard Infrastructure Projects (Strategic Seawalls/Levees):** Construct targeted seawalls or flood barriers to protect specific, high-value economic districts or large dense populations that cannot reasonably be relocated and have clear cost-benefit justification. These will be integrated with nature-based features where possible.
#         *   *Budget:* $300M.
#         *   *Confidence: Medium.* *Data Needed:* Detailed engineering designs and cost-benefit analysis for specific hard infrastructure proposals, including long-term maintenance costs and residual risk assessments.
#     3.  **City-Wide Building Code & Zoning Enforcement:** Implement and rigorously enforce the new zoning ordinances and building codes. Provide subsidies and financial incentives for existing homeowners (especially low-income) to retrofit properties to meet new standards.
#         *   *Budget:* $100M (for subsidies and enforcement).
#         *   *Confidence: High.* *Data Needed:* Baseline data on current building code compliance rates, particularly in vulnerable areas.
#     4.  **Flood-Resilient Green Infrastructure:** Expand green infrastructure projects (e.g., permeable surfaces, bioswales, urban wetlands) throughout the city to manage stormwater, reduce urban heat island effect, and provide flood protection.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Detailed hydrologic modeling to identify optimal locations for green infrastructure to maximize stormwater retention and flood reduction benefits.
#
# **Phase 3 (Years 8-10: Long-Term Resilience & Adaptive Management - ~$600 Million)**
# *   **Goal:** Integrate adaptation into all city planning, continue strategic protection, and prepare for future challenges.
# *   **Interventions:**
#     1.  **Continued Voluntary Relocation/Buyout & Redevelopment:** Sustain the program, strategically acquiring additional high-risk properties and transforming vacated land into nature-based defenses, open space, or buffer zones.
#         *   *Budget:* $200M.
#         *   *Confidence: Medium.* *Data Needed:* Public perception and economic impact studies on the long-term transformation of vacated land and receiving zones.
#     2.  **Regional Collaboration & Early Warning Systems:** Invest in regional partnerships for adaptation strategies (e.g., shared flood models, emergency response protocols) and develop advanced local early warning systems for storm surge and flooding.
#         *   *Budget:* $50M.
#         *   *Confidence: High.* *Data Needed:* Inventory of existing regional agreements and emergency communication protocols.
#     3.  **Adaptive Management Fund:** Establish a dedicated fund for unforeseen adaptation needs, research and development of new technologies, and to scale up or pivot interventions based on monitoring data and evolving climate projections.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Detailed analysis of historical disaster relief spending and potential future funding gaps.
#     4.  **Insurance/Subsidy Program Development:** Collaborate with state and federal partners to develop a specialized flood insurance subsidy program for low-to-moderate income households in remaining high-risk zones who cannot or choose not to relocate, ensuring affordability while incentivizing risk reduction.
#         *   *Budget:* $50M (initial seed funding/subsidies for low-income).
#         *   *Confidence: Medium.* *Data Needed:* Actuarial analysis of current flood insurance uptake and claims among low-income households, and assessment of federal/state appetite for partnership.
#     5.  **Long-term Monitoring & Research:** Continuously monitor sea-level rise, storm intensity, and the effectiveness of all interventions. Fund local research into climate impacts and adaptation solutions.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Baseline ecological data for nature-based solutions and socio-economic data for relocated communities.
#     6.  **Climate-Resilient Infrastructure Upgrades:** Continue investing in upgrades to grey infrastructure (e.g., drainage systems, power grids) to make them more resilient to climate impacts, guided by lessons learned.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Infrastructure condition assessments across all municipal systems.
#
# ### **2. Quantified Expected Outcomes (by 2033 - end of 10-year plan, impacting 2050 targets)**
#
# *   **Reduction in Expected Annual Flood Damages (by 2050):**
#     *   *Baseline (without plan):* Projected $200-300 million annually by 2050.
#     *   *With Plan:* **~60-70% reduction**, bringing annual damages down to **$60-120 million by 2050.**
# *   **Number of People/Households Displaced or Relocated (by 2033):**
#     *   *Voluntary Relocation/Buyouts:* **2,500 - 4,000 households** (approx. 7,500 - 12,000 people) voluntarily relocated through incentivized programs.
#     *   *Forced Displacement:* **Minimized to effectively zero**, fulfilling the legal mandate.
# *   **Change in Socioeconomic Equity (Distributional impact on poorest 20%):**
#     *   **Significant positive impact.** Poorest 20% in high-risk zones will be offered above-market value buyouts and comprehensive relocation support.
#     *   **Quantitative Proxy:** Aim for a **10-15% reduction in the number of households below the poverty line living in the 100-year floodplain** by 2033, and a **25-30% reduction in their expected uninsured flood losses.**
#
# ### **3. Three Most Important Assumptions & Sensitivity**
#
# 1.  **Political Will & Bipartisan Cooperation Persist:**
#     *   *Details:* The $2.0B budget is sustained, and the politically divided council cooperates on necessary legislative changes (zoning, building codes). The upcoming election does not derail the plan.
#     *   *Sensitivity:* **High.** *Violation:* Gridlock or funding cuts (20-40% probability) would cause delays, cost overruns, incomplete projects, and potential failure to meet adaptation goals.
# 2.  **Sufficient Voluntary Participation in Buyout/Relocation:**
#     *   *Details:* Incentives (above-market value, assistance) are sufficient to encourage a critical mass of residents, especially low-income households, to voluntarily participate.
#     *   *Sensitivity:* **Medium-High.** *Violation:* Low participation rates (15-30% probability) would undermine equity goals and the non-displacement mandate, leading to continued exposure and higher future damage costs.
# 3.  **Future Climate Projections are Broadly Accurate:**
#     *   *Details:* The 0.6m SLR and 2x 100-year storm surge by 2050 projections are sufficient for planning.
#     *   *Sensitivity:* **Medium.** *Violation (Worse Case):* Impacts significantly accelerate beyond projections (10-20% probability of underestimation) rendering interventions insufficient, requiring costly emergency upgrades. *Violation (Better Case):* Impacts are less severe (5-10% probability of overestimation) leading to over-investment, though with residual co-benefits.
#
# ### **4. Top Five Failure Modes & Contingency/Mitigation**
#
# 1.  **Failure Mode: Political Backlash & Loss of Public Support.**
#     *   *Contingency:* Implement extensive, ongoing public outreach and education, involve affected communities in co-design, start with successful pilots, and ensure legal robustness of policies.
# 2.  **Failure Mode: Low Voluntary Participation in Buyout/Relocation.**
#     *   *Contingency:* Enhance incentives (increase buyout offers to 150%, expand assistance), empower community-led relocation efforts, invest heavily in attractive "resilience hubs" in receiving zones, and continuously refine strategies based on pilot feedback.
# 3.  **Failure Mode: Cost Overruns & Budget Exhaustion.**
#     *   *Contingency:* Strict project management, rigorous cost estimates, contingency planning, value engineering, active pursuit of state/federal/private grants, and judicious use of the Adaptive Management Fund.
# 4.  **Failure Mode: Maladaptation (Interventions Worsen Problems).**
#     *   *Contingency:* Integrated planning with advanced modeling, thorough Environmental Impact Assessments, robust monitoring and evaluation systems to detect issues early, and active regional collaboration to avoid shifting risks.
# 5.  **Failure Mode: Adverse Incentives (e.g., "Moral Hazard").**
#     *   *Contingency:* Link flood insurance subsidies to mandatory mitigation measures, use risk-based pricing (with affordability measures) to communicate true risk, maintain strict zoning/building codes, and conduct ongoing public education on individual preparedness.
#
# ### **5. Feasible 12–24 Month Randomized or Quasi-Experimental Pilot**
#
# **Objectives:** (a) Increase voluntary participation in relocation/buyout among low-income households, and (b) measure short-term political acceptability.
#
# **Intervention Target:** One of the highest-risk, predominantly low-income neighborhoods (approx. 500-700 households) designated as the "Pilot Zone."
#
# **Treatment Arms (for Voluntary Participation within Pilot Zone):**
# *   **Control Group (N=~200-250 households):** Standard city communications on flood risk; "fair market value" buyout offer (pre-flood risk appraisal).
# *   **Treatment Group 1 (N=~150-200 households):** All control elements PLUS: 120% of pre-flood risk market value buyout; personalized relocation counseling; detailed information on "resilience hubs."
# *   **Treatment Group 2 (N=~150-200 households):** All elements of Treatment Group 1 PLUS: Trusted, paid community relocation liaison; participatory workshops for future land use visioning of the vacated neighborhood.
#
# **Primary Outcomes (12-24 months):**
# *   **(a) Voluntary Participation:** Percentage of households in each group formally accepting a buyout offer.
# *   **(b) Short-Term Political Acceptability (City-wide):** Change in public support for the overall adaptation plan (pre/post city-wide random sample survey, 2,000 registered voters, 5-point Likert scale).
#
# **Ethical Safeguards:** Truly voluntary participation, no diminished services for non-participants, confidentiality of personal data, no "stigma" for control group, clear exit strategy, independent ethical review, and commitment to offering successful treatments to all eligible households post-pilot.
#
# ### **6. Five Measurable Indicators (with Thresholds) for Annual Monitoring**
#
# 1.  **Annual Sea-Level Rise & Storm Surge Frequency/Intensity (Observed vs. Projected):**
#     *   *Metric:* Observed SLR (mm/year) and number of storm surge events >0.5m/1.0m MHHW.
#     *   *Thresholds:* **Accelerate:** SLR > 7mm/year OR 2+ major surge events (>1.0m MHHW) in 3 years. **Pause/Re-evaluate:** SLR < 3mm/year over 5 years.
# 2.  **Voluntary Buyout/Relocation Participation Rate & Equity:**
#     *   *Metric:* % of eligible low-income households accepting buyout offers; % satisfaction with new housing/community for relocated households.
#     *   *Thresholds:* **Accelerate/Enhance:** < 40% participation for low-income OR < 60% satisfaction. **Maintain:** 60-80% participation AND > 75% satisfaction.
# 3.  **Number of Repetitive Flood Claims & Expected Annual Flood Damages (Monetized):**
#     *   *Metric:* % change in properties with 2+ claims in 5 years; estimated annual damages.
#     *   *Thresholds:* **Accelerate:** 10% increase in repetitive claims OR estimated annual damages exceed $150M (inflation-adjusted) for 2 consecutive years. **Maintain:** 5% decrease in claims AND damages below $100M.
# 4.  **Public & Political Acceptance of Adaptation Plan:**
#     *   *Metric:* Quarterly "support for adaptation plan" survey score (avg. 1-5); % of "yes" votes on key council resolutions.
#     *   *Thresholds:* **Accelerate/Adjust Strategy:** Avg. survey score < 3.0 OR > 30% of key council votes fail. **Maintain:** Avg. survey score > 3.5 AND > 70% of key votes pass.
# 5.  **Ecological Health of Nature-Based Defenses (NBDs):**
#     *   *Metric:* % of target NBD area established and healthy; biodiversity index; erosion rates in NBD zones.
#     *   *Thresholds:* **Accelerate/Remediate:** < 70% of target NBD healthy OR significant erosion detected. **Maintain:** > 90% of target NBD healthy AND stable erosion rates.
#
# ...
# | **2025‑2035** | **(D) Zoning & Building‑Code Reform** | • Adopt “Flood‑Resilience Overlay” for all parcels within 0.5 km of projected 2050 shoreline. <br>• Provide fast‑track permits & density bonuses for elevating new construction ≥ 1.2 m above projected BFE. | $100 M | 5 % |
# | **2025‑2028** | **(E) Insurance/Subsidy & Risk‑Education Program** | • Tiered premium subsidies for low‑income (≤ 150 % FPL) – 30 % reduction on NFIP rates. <br>• Community outreach, flood‑risk dashboards, and “Resilience Savings Accounts” (matched grants for home‑hardening). | $100 M | 5 % |
# | **2025‑2027** | **(F) Governance & Institutional Reforms** | • Create a Climate‑Resilience Office (CRO) with authority to coordinate all interventions, monitor performance, and manage the $250 M contingency fund. | $50 M | 2.5 % |
# | **2025‑2026** | **(G) Contingency/Reserve** | • Unspent funds, cost overruns, emergency repairs. | $250 M | 12.5 % |
# | **TOTAL** | | | **$2.0 B** | **100 %** |
#
# *All spending is front‑loaded (≈ 80 % in the first five years) to lock‑in physical protection before the 2030‑mid‑decade storm intensification peak.*
#
# ---
#
# ## 2.  Quantified Expected Outcomes (10‑yr horizon)
#
# | Metric | Baseline (2025) | Projected 2035 (with plan) | Reduction / Improvement | Comments |
# |--------|----------------|----------------------------|--------------------------|----------|
# | **Annual expected flood damage** (direct property & infrastructure) | $300 M (2025) – rising 4 %/yr without action → $440 M by 2035 | $150 M average (2025‑2035) | **≈ 45 % cut** (≈ $135 M/yr avoided) | Savings driven by seawall + nature‑based attenuation (≈ 30 %); buy‑outs eliminate highest‑risk structures (≈ 15 %). |
# | **Households displaced (forced)** | 5 % of at‑risk households (~2 500) would be forced by 2035 under business‑as‑usual | < 200 (≈ 0.2 %) | **≥ 92 % reduction** | All relocation is voluntary; emergency‑evacuation plans limit forced moves. |
# | **Households voluntarily relocated (buy‑out)** | 0 | 2 000 (≈ 5 % of at‑risk) | — | 60 % of these are low‑income → 1 200 poor households. |
# | **Low‑income (bottom 20 %) risk exposure** | 30 % of this group lives in 1‑in‑5 most flood‑prone parcels | 12 % (after buy‑outs + elevation incentives) | **60 % relative risk drop** | Measured as probability of flood depth > 0.5 m per year. |
# | **Flood‑insurance coverage (low‑income)** | 45 % (2025) | 85 % (2028) | +40 ppt | Subsidy + education drives uptake. |
# | **Economic activity protected** | $12 B of taxable commercial/industrial floor space in core district | 95 % retained (seawall protects) | – | Trade‑off: heavy investment in core vs. peripheral neighborhoods. |
#
# ---
#
# ## 3.  Three Core Assumptions & Sensitivity
#
# | # | Assumption | Reasonable Range (probability) | Sensitivity |
# |---|------------|--------------------------------|-------------|
# | **A** | **SLR reaches 0.6 m by 2050** (median IPCC AR6 RCP4.5) | 0.6 m ± 0.1 m (≈ 70 % chance) | *If SLR is > 0.8 m*, seawall freeboard must be increased → extra $150‑200 M. *If SLR is < 0.4 m*, we could defer part of the hard barrier (cost saving ≈ $100 M). |
# | **B** | **100‑yr storm surge intensity doubles** (wind‑speed & surge height) | 2× ± 30 % (≈ 55 % chance) | *If surge increase is only 1.5×*, the hybrid barrier can be built to lower height, saving ≈ $80 M. *If surge spikes to 2.5×*, we would need additional overtopping protection (≈ $120 M). |
# | **C** | **Low‑income households will accept voluntary buy‑outs when offered ≥ 80 % of market value + relocation grant** | Acceptance 70‑85 % (≈ 75 % chance) | *If acceptance falls below 55 %*, we must increase the grant or shift to more aggressive zoning (cost ≈ $50 M). *If acceptance exceeds 90 %*, we could re‑allocate excess funds to nature‑based projects. |
#
# Overall plan success is **medium‑high** (≈ 70 % probability of achieving ≥ 40 % damage reduction and ≤ 200 forced displacements) given current scientific confidence and community‑engagement pilots (see §5).
#
# ---
#
# ## 4.  Top‑5 Failure Modes & Mitigation
#
# | # | Failure Mode | Likely Consequence | Contingency / Mitigation |
# |---|--------------|-------------------|--------------------------|
# | **1** | **Political backlash over “big‑seawall” cost** (election 2027) | Funding freeze, re‑allocation to other priorities | • Phase the barrier (Phase I: 4 km protecting the most critical assets) with clear cost‑benefit communication; <br>• Establish a “Resilience Bond” financed through a modest (0.1 %) property tax dedicated to the project; <br>• Early bipartisan outreach using local business coalition data on avoided losses. |
# | **2** | **Buy‑out program perceived as “selling out” low‑income neighborhoods** | Low participation, protests, legal challenges | • Co‑design the program with community NGOs; <br>• Offer “green‑relocation” grants for moving to affordable, pre‑built resilient housing; <br>• Publicly publish transparent cost‑benefit and equity impact analyses. |
# | **3** | **Gentrification after protection of downtown** (property values surge) | Displacement of renters & small businesses | • Pair the seawall with inclusionary‑housing ordinances that reserve 20 % of new units for households ≤ 150 % FPL; <br>• Use a “Community Land Trust” to hold key parcels for affordable use. |
# | **4** | **Construction delays / cost overruns (seawall, wetlands)** | Budget overspend, missed 2030 target | • Fixed‑price EPC contracts with performance penalties; <br>• Independent “Resilience Oversight Committee” with quarterly audits; <br>• Maintain $250 M contingency reserve (see Table 1). |
# | **5** | **Insurance/subsidy fraud or moral hazard** | Uncontrolled premium losses, reduced fiscal sustainability | • Link subsidies to verified elevation/retrofit standards; <br>• Require annual flood‑risk re‑assessment for continued eligibility; <br>• Use GIS‑based fraud detection analytics. |
#
# ---
#
# ## 5.  12‑24‑Month Pilot to Boost Low‑Income Relocation & Test Political Acceptability
#
# | Element | Design |
# |---------|--------|
# | **Sample frame** | 1 200 low‑income (≤ 150 % FPL) households in the top 30 % flood‑risk parcels (identified via high‑resolution LiDAR flood maps). |
# | **Randomisation** (three arms, 400 households each) | 1. **Cash‑Incentive Arm** – 85 % market‑value buy‑out + $5 k relocation grant (baseline offer). <br>2. **Counselling‑Plus‑Design Arm** – Same cash offer + a dedicated case‑worker, a “design‑your‑new‑home” workshop, and a guaranteed spot in a new affordable‑resilient‑housing complex. <br>3. **Control Arm** – Standard city outreach (information brochure, no additional services). |
# | **Primary outcomes (12‑month horizon)** | • % of households signing a buy‑out agreement (target > 70 % in Arm 2, > 55 % in Arm 1, < 30 % in Control). <br>• Change in “plan acceptability” score (1‑5 Likert) measured via door‑to‑door surveys across the whole pilot area. |
# | **Secondary outcomes** | • Median time from offer to contract signing; <br>• Reported perceived fairness; <br>• Uptake of flood‑insurance among remaining at‑risk households. |
# | **Ethical safeguards** | • Informed consent with clear explanation that participation is voluntary and will not affect eligibility for the standard city program. <br>• Independent Institutional Review Board (IRB) oversight. <br>• Data anonymisation; opt‑out option for any household at any stage. |
# | **Timeline** | • **Month 1‑3** – GIS risk mapping & household recruitment. <br>• **Month 4‑6** – Randomisation & baseline survey. <br>• **Month 7‑18** – Offer rollout, counselling, monitoring. <br>• **Month 19‑24** – Final survey, analysis, policy brief. |
#
# *Result:* The pilot will quantify the “price‑elasticity” of low‑income buy‑out acceptance and provide a rapid gauge of political support (acceptability score) before the 2027 council election.
#
# ---
#
# ## 6.  Five Annual Monitoring Indicators (with Decision Thresholds)
#
# | Indicator | Target (2025‑2035) | Threshold for Action |
# |-----------|-------------------|-----------------------|
# | **1. Annual Flood‑Damage Expenditure** (city‑reported, $M) | ≤ $150 M (average) | > $180 M → Review/strengthen physical defenses (add height, expand nature‑based area). |
# | **2. Low‑Income Flood‑Insurance Coverage** (% of eligible households) | ≥ 85 % | < 70 % → Increase subsidy or expand outreach budget by 20 %. |
# | **3. Voluntary Buy‑Outs Completed** (units/yr) | 200 ± 30 | < 150 yr → Boost cash incentive or expand counselling pilot. |
# | **4. Equity Risk‑Reduction Ratio** (risk reduction for poorest 20 % ÷ city‑wide risk reduction) | ≥ 1.0 (i.e., poorest benefit at least as much) | < 0.8 → Re‑allocate funds to targeted retrofits or expand affordable‑housing set‑aside. |
# | **5. Council/Mayor Public‑Support Index** (average score of city‑wide poll, 1‑5) | ≥ 3.5 (≥ 70 % “support”) | < 3.0 → Launch city‑wide communication campaign; consider adjusting financing mechanism. |
#
# Indicators are compiled by the **Climate‑Resilience Office** and presented at the quarterly City Council “Resilience Review”.
#
# ---
#
# ## 7.  Cost‑Benefit Estimate (NPV, 10 yr)
#
# ### Assumptions
# * **Discount rates**: 3 % (social planner) vs. 7 % (municipal finance).
# * **Damage trajectories** (baseline without adaptation):
#   * **Low** – 1 %/yr increase (minimal storm intensification).
#   * **Medium** – 3 %/yr (current IPCC median).
#   * **High** – 6 %/yr (upper‑range storm surge).
# * **Adaptation effect** – 45 % reduction in damages (flat over the horizon).
#
# | Scenario | Discount % | Present Value of Damages (no action) | PV of Damages **with plan** | PV of Adaptation Cost* | **Net Benefit (NPV)** |
# |----------|-----------|--------------------------------------|----------------------------|------------------------|----------------------|
# | Low | 3 % | $3.2 B | $1.8 B | $1.5 B | **+$0.0 B** |
# | Low | 7 % | $2.8 B | $1.6 B | $1.5 B | **+$0.1 B** |
# | Medium | 3 % | $4.9 B | $2.7 B | $1.5 B | **+$0.7 B** |
# | Medium | 7 % | $4.2 B | $2.3 B | $1.5 B | **+$0.3 B** |
# | High | 3 % | $7.9 B | $4.4 B | $1.5
#
# # Response from competitor 6
#
# **Prioritized 10-Year Adaptation Plan**
#
# With a $2.0 billion budget, I propose the following interventions:
#
# 1. **Seawall and Dunes System** (2.5B, $1.25B, 2024-2029):
# 	* Construct a 5 km seawall and build a 3 km long dunes system to protect the city center.
# 	* Expected reduction in annual flood damages: $120 million (20% decrease).
# 	* Number of displaced/households relocated: 10,000 (20% decrease).
# 	* Change in socioeconomic equity: Reduction in flood-related economic hardship among the poorest 20%.
# 2. **Smart Grid and Flood-Proofing Zoning** (400M, $200M, 2024-2028):
# 	* Upgrade the city's electrical grid to withstand flooding and install smart sensors to monitor storm surges.
# 	* Implement zoning regulations that require new construction to be built above grade or use flood-proof materials.
# 3. **Relocation/ Buyout Program** (300M, $150M, 2024-2029):
# 	* Establish a voluntary relocation program for low-income households in high-risk flood areas.
# 	* Offer buyouts or relocation packages to encourage voluntary participation.
# 	* Expected increase in voluntary participation: 40% ( increase in program enrollment).
# 4. **Insurance/Subbidy Programs** (400M, $200M, 2024-2028):
# 	* Implement a city-funded insurance program to cover flood-related losses.
# 	* Offer subsidies to households in high-risk flood areas to help mitigate financial burden.
# 5. **Governance Reforms** (200M, $100M, 2025-2029):
# 	* Implement a participatory budgeting process to ensure inclusive decision-making.
# 	* Establish a flood resiliency trust fund to prioritize adaptation investments.
#
# **Assumptions and Sensitivity**
#
# 1. **Sea-Level Rise and Storm Surge Intensity**: High sensitivity (50% impact on plan's success, 1:1 probability range). Assuming 0.6 m sea-level rise and doubling of 100-year storm surge intensity is a reasonable assumption based on current IPCC projections.
# 2. **Economic Growth and Inflation**: Medium sensitivity (30% impact on plan's success, 2:1 probability range). Assuming a 2% annual economic growth rate and moderate inflation (1.5%) is a conservative estimate based on historical data.
# 3. **Citizen Engagement and Participation**: Medium sensitivity (30% impact on plan's success, 2:1 probability range). Assuming high levels of citizen engagement and participation in the adaptation process is crucial for successful implementation.
#
# **Failure Modes and Contingency Planning**
#
# 1. **Political Backlash**: Establish a stakeholder advisory committee to ensure inclusive decision-making.
# 2. **Adverse Incentives**: Implement a revenue neutral, carbon-fund-based financing mechanism to reduce the burden on taxpayers.
# 3. **Insufficient Public Engagement**: Establish community outreach programs to ensure informed decision-making by all stakeholders.
# 4. **Inadequate Funding**: Prioritize interventions with the greatest expected outcomes and implement phase-in financing plans.
# 5. **Low-Intensity Storms**: Implement adaptive management plans to address unexpected storm intensity.
#
# **Pilot Study**
#
# Title: "Flood-Resilient Neighborhoods"
#
# * Sample Frame: 1,500 low-income households in high-risk flood areas.
# * Treatment Arms:
# 	+ Group A: Standard relocation/buyout program.
# 	+ Group B: Enhanced program with community engagement and education components.
# 	+ Group C: Control group with no additional program components.
# * Primary Outcome: Increase in voluntary participation in the relocation/buyout program among low-income households.
# * Ethical Safeguards: Randomized controlled trial with informed consent and anonymized data.
#
# **Performance Monitoring**
#
# 1. Annual Flood Risk Assessment.
# 2. Displacement/Relocation Program Metrics: Enrollment rates, retention rates, and program effectiveness.
# 3. Economic Benefit Categorization: Reduction in flood-related losses, increase in economic productivity, and reduction in poverty rates.
# 4. Social Equity Metrics: Distribution of benefits, reduction in flood-related hardship among vulnerable populations.
# 5. Stakeholder Engagement Indices: Citizen participation rates, stakeholder satisfaction, and community engagement quality.
#
# **Cost-Benefit Analysis**
#
# Scenario 1 (3% discount rate): -$1.3 billion (benefit: - $1.1 billion displacement cost reduction, - $150 million increased economic costs; - $50 million loss of avoided damages).
#
# Scenario 2 (7% discount rate): -2.1 billion (benefit: - $1.6 billion displacement cost reduction, - $200 million increased economic costs; - $80 million loss of avoided damages).
#
# Scenario 3 (Low Climate Damage Trajectory): +$1.5 billion (benefit: +$1.2 billion displacement cost reduction, + $100 million increased economic costs; -$200 million loss of avoided damages).
#
# Scenario 4 (Medium Climate Damage Trajectory): +$2.2 billion (benefit: +$1.8 billion displacement cost reduction, + $150 million increased economic costs; -$300 million loss of avoided damages).
#
# Scenario 5 (High Climate Damage Trajectory): +$3.2 billion (benefit: +$2.6 billion displacement cost reduction, + $200 million increased economic costs; -$400 million loss of avoided damages).
#
# **Confidence Levels**
#
# 1. Seawall and Dunes System: High (90%), 3D lidar data collection within 12 months to increase confidence.
# 2. Relocation/Buyout Program: High (90%), Establish a stakeholder advisory committee to ensure inclusive decision-making.
# 3. Smart Grid and Flood-Proofing Zoning: Medium (60%), Monitor performance and make adjustments as necessary.
# 4. Insurance/Subsidy Programs: Medium (60%), Develop comprehensive actuarial models to ensure risk-sharing mechanisms are in place.
# 5. Governance Reforms: Medium (60%), Implement participatory budgeting and community outreach programs to ensure inclusive decision-making.
#
# Note: A comprehensive, multi-year implementation plan will require ongoing monitoring, adaptation, and fine-tuning to achieve the planned outcomes. This plan provides a starting point for the city to prioritize their adaptations.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 6 competitors.
# Each model has been given this question:
#
# You are an independent advisor to the mayor of a mid-sized coastal city (population 500,000) that faces a projected 0.6 m average sea-level rise and doubling of 100-year storm surge intensity by 2050. The city has a 10-year capital budget of $2.0 billion for adaptation, a legally binding mandate to minimize involuntary displacement, substantial socioeconomic inequality (20% of households are below the poverty line), and an election in 18 months with a politically divided council. You may choose any combination of interventions (hard infrastructure such as seawalls, soft/nature-based defenses, targeted buyouts and voluntary relocation, zoning and building-code changes, insurance/subsidy programs, or governance reforms).
#
# Produce a prioritized 10-year adaptation plan that:
# - Specifies which interventions to implement, their timing, and an approximate budget allocation (add up to ≤ $2.0B),
# - Quantifies expected outcomes in rough, defensible numbers: reduction in expected annual flood damages, number of people/households displaced or relocated (voluntary vs. forced), and change in socioeconomic equity (e.g., distributional impact on poorest 20%),
# - Lists the three most important assumptions you are making and how sensitive your plan’s success is to violations of each (give probability ranges where possible),
# - Identifies the top five failure modes (including political backlash and adverse incentives) and concrete contingency/mitigation steps for each,
# - Describes a feasible 12–24 month randomized or quasi-experimental pilot (sample frame, treatment arms, primary outcome, and ethical safeguards) designed to (a) increase voluntary participation in a relocation/buyout program among low-income households, and (b) measure short-term political acceptability of the plan,
# - Gives five measurable indicators (with thresholds) the city should monitor annually to decide whether to accelerate, pause, or reverse specific interventions,
# - Provides a concise, quantitative estimate of overall plan cost-benefit under two discount-rate scenarios (3% and 7%) and three plausible climate-damage trajectories (low/medium/high), and
# - For each major recommendation, state your level of confidence (high/medium/low) and the single piece of data that would most increase your confidence if obtained within 12 months.
#
# Be explicit about trade-offs you accept (e.g., protecting economic centers vs. minimizing displacement), avoid vague platitudes, and keep your answer focused and actionable.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Below is a concrete, donor-ready 10-year adaptation plan tailored to a mid-sized coastal city (population ~500,000) facing 0.6 m sea‑level rise and doubling of 100-year surge by 2050. It is structured to fit a legally binding mandate to minimize involuntary displacement, address inequality, and work within a $2.0B 10-year capital budget while navigating a politically divided council and an election in 18 months.
#
# Executive summary
# - Core goal: reduce flood risk and protect critical economic/urban cores while prioritizing voluntary relocation for the neediest, and strengthening governance so investments are defended by evidence and community legitimacy.
# - Core mix of actions: a balanced portfolio of nature-based and hybrid defenses, targeted hard infrastructure upgrades, a voluntary buyout/relocation program with strong protections for low-income households, updated zoning/building codes, risk financing/subsidies to lower insurance barriers, and governance reforms to enable adaptive management.
# - 10-year budget (not-to-exceed $2.0B):
#   - A) Nature-based/hybrid defenses: $700M
#   - B) Hard infrastructure/drainage upgrades: $550M
#   - C) Targeted buyouts/voluntary relocation: $520M
#   - D) Zoning/building-code updates: $140M
#   - E) Insurance subsidies/risk financing: $60M
#   - F) Governance and implementation management: $30M
#   - Total: $2.00B
# - Expected outcomes (rough, defensible):
#   - Reduction in expected annual flood damages by approximately 60–70% in protected zones; net citywide annual damages reduced from roughly $200M today to the low-to-mid $100Ms by 2036 under the high-damage trajectory, with more modest reductions under lower climate-damage trajectories.
#   - Displacement: voluntary relocations of roughly 3,500–6,000 households (roughly 11,000–17,000 people) over the decade; forced relocations kept at 0–5% of total displacement.
#   - Equity: the program prioritizes the lowest-income households; by year 5–7, the share of relocated households from the bottom two quintiles rises to ~60–75% of relocations; poorest 20% see enhanced protection in protected areas and higher uptake in buyouts where appropriate.
# - Key risks, failure modes, and mitigations are identified, along with a pilot to test voluntary relocation incentives and measure political acceptability.
# - Five annual indicators, with decision thresholds, to guide acceleration/pausing/reversals.
# - A concise, scenario-based cost-benefit: two discount rates (3% and 7%) and three climate-damage trajectories (low/medium/high). In high-damage scenarios, the plan yields positive net benefits that justify the spend; in low-damage scenarios, costs dominate monetized benefits but social equity and resilience benefits remain substantial.
# - Three top assumptions, with probability ranges and sensitivity notes, plus confidence levels and data needs to improve certainty.
#
# 1) Interventions, timing, and approximate budget allocations (10-year horizon)
# Assumptions: construction/relocation cycles phased to minimize disruption and align with a single, accountable program office. 18-month election window will be used to build cross-party credibility through phased milestones and transparency.
#
# A. Nature-based and hybrid defenses (soft defenses + living shorelines + green streets + floodplain restoration)
# - What: 18 km of hybrid shorelines, wetland/mloodplain restoration where feasible, urban green infrastructure (bioswales, rain gardens, permeable pavement), and living breakwaters where practicable.
# - Timing: Phase 1 (Years 1–2): design in the highest-risk corridors, begin 2–3 defense micro-projects; Phase 2 (Years 3–6): scale to additional segments; Phase 3 ( Years 7–10): complete citywide coverage in priority zones.
# - Budget: $700M
# - Rationale: reduces wave/run-up exposure in nearshore and low-lying blocks, provides co-benefits (habitat, recreation, water quality).
#
# B. Hard infrastructure and drainage upgrades (seawalls, flood barriers, pumps, upgraded stormwater drainage)
# - What: targeted seawalls along critical economic corridors and high-value neighborhoods; upgraded pump stations; enhanced pumping/discharge capacity; floodproofing of municipal facilities and critical utilities; improvements to drainage networks to reduce urban flood peaks.
# - Timing: Phase 1 (Years 1–2): procure and begin upgrades in 2–3 high-risk zones (downtown/port area and a major neighborhood cluster); Phase 2 (Years 3–6): expand to additional segments; Phase 3 (Years 7–10): complete all prioritized zones; post-construction commissioning and testing.
# - Budget: $550M
# - Rationale: provides essential protection for critical infrastructure and economic centers with a design emphasis on resilience to higher surge.
#
# C. Targeted buyouts and voluntary relocation (incentives, relocation support, housing assistance)
# - What: voluntary buyouts, relocation assistance, replacement housing options, bridging loans, relocation counseling, and community-based housing supports; explicit policy to maximize voluntary relocations of low-income households; target to minimize involuntary displacement below 5%.
# - Timing: Phase 1 (Years 1–2): launch outreach, secure listings of candidate properties, begin first round of buyouts; Phase 2 (Years 3–6): expand to additional neighborhoods; Phase 3 (Years 7–10): complete program in remaining risk zones; ongoing wraparound services.
# - Budget: $520M
# - Rationale: directly reduces exposure and displacement risk, aligns with equity mandate; incentives and housing assistance are essential to make relocation feasible for poor households.
#
# D. Zoning, building-code changes and land-use planning (elevation, flood-proofing, construction standards)
# - What: elevate new construction and retrofit standards to a 100-year+ flood protection baseline; enforce floodproofing, setback and elevation requirements; update critical infrastructure siting and land-use plans to reduce exposure.
# - Timing: Phase 1 (Years 1–2): adopt updated codes; Phase 2 (Years 2–5): rollout enforcement in new developments and major renovations; Phase 3 (Years 6–10): ensure full citywide adoption and compliance checks.
# - Budget: $140M
# - Rationale: reduces long-term vulnerability in new development and retrofits; ensures that new investments are resilient to higher climate risks.
#
# E. Insurance subsidies and risk financing (premium subsidies, public reinsurance, catastrophe risk pooling)
# - What: subsidies to reduce insurance premiums for at-risk households; enhance city-level catastrophe risk pooling and reinsurance capacity; potential municipal catastrophe fund to bridge investment gaps.
# - Timing: Phase 1 (Years 1–2): establish policy framework; Phase 2 (Years 3–5): scale subsidies; Phase 3 (Years 6–10): sustain program with annual reviews.
# - Budget: $60M
# - Rationale: increases affordability and resilience of households, lowers displacement risk by reducing uninsurable exposure.
#
# F. Governance reforms and implementation management (institutional capacity, data systems, performance dashboards, community engagement)
# - What: new adaptation authority or augmented planning office; centralized data integration; transparent performance dashboards; formal public-engagement mechanisms (including a standing citizen oversight body).
# - Timing: Phase 1 (Year 1): establish governance structure; Phase 2 (Year 2): implement data systems; Phase 3 (Year 3–10): continuous improvement and reporting.
# - Budget: $30M
# - Rationale: ensures plan goes from concept to execution with accountability, reduces political volatility through clear metrics and citizen involvement.
#
# Total: $2.00B (across 10 years)
#
# 2) Quantified outcomes (rough, defensible numbers)
# Assumptions for context:
# - Current baseline annual flood damages (citywide) ≈ $200M per year today under existing conditions.
# - Without action, damages rise as climate risks intensify: low trajectory: +10–20% by 2036; medium: +40–60%; high: +100% (relative to today) by 2036.
# - “Annual damages avoided” reflects citywide reductions from both defenses and relocation in protected zones. Because buyouts/elimination of exposure are concentrated in high-risk areas, the plan yields large reductions where risk is highest.
#
# A. Reduction in expected annual flood damages (citywide, by 2036)
# - Low climate trajectory: post-implementation annual damages ≈ $125–$140M (vs. current $200M baseline; ~40–55% reduction in the high-risk zones and partial protections citywide).
# - Medium trajectory: ≈ $160–$180M (vs. $200M baseline; ~10–25% net reduction in exposure citywide, higher in protected zones).
# - High trajectory: ≈ $250–$260M (vs. $200M baseline; net increases in exposed areas are still offset in defended zones; high exposure mitigated more than baseline in critical cores).
#
# Note: These are citywide, “after-action” estimates that reflect a mix of zone-specific results (large reductions where buyouts/defenses are concentrated, moderate reductions elsewhere).
#
# B. Displaced or relocated people/households (voluntary vs. forced)
# - Total households relocated (voluntary): approximately 3,800–6,500 over 10 years.
# - Total people relocated (assuming ~2.8 persons/household): roughly 10,600–18,000 people.
# - Voluntary vs forced: voluntary ~3,600–6,200 households; forced relocations kept at 0–5% of total relocations (i.e., 0–325 households, ~0–900 people if averages hold).
# - Share of relocations from the bottom income quintile: target ~60–75% of relocations from the two poorest quintiles by year 5–7.
#
# C. Change in socioeconomic equity
# - Equity metric (share of flood-protection benefits and relocation benefits captured by the poorest 20%): increase from a baseline where the bottom quintile benefits minimally to a target where roughly 30–40% of total benefit captured by the bottom quintile, rising to ~50–60% by year 7–10 when combined defense benefits and buyouts are scaled.
# - Net improvement in the city’s distributional equity index (qualitative proxy: reduced exposure for poorest quintiles, improved housing stability, and access to relocation options): modest to meaningful improvements (order of magnitude: 0.15–0.25 on a 0–1 scale by decade end).
#
# 3) The three most important assumptions and sensitivity
# Assumption 1: Climate risk trajectory and damages
# - Assessed probabilities (subject to climate forecast uncertainty): Low ~20%, Medium ~50%, High ~30%.
# - Sensitivity: If high-damage trajectory is underestimated (i.e., damages grow faster or more intensely than modeled), the plan’s monetized benefits rise, improving relative NPV; if damages are lower than anticipated, the plan’s monetized benefits are smaller.
# - Data to improve confidence in 12 months: updated city hazard maps, regional climate model projections, and validated flood- and surge-inundation models, plus realized 2025–2026 flood event data.
#
# Assumption 2: Political will and governance effectiveness
# - Assessed probabilities: Robust cross‑party backing ~40–60%; gridlock or watered‑down reforms ~20–40%.
# - Sensitivity: If governance reforms stall (delayed approvals, fragmentation among council factions), the plan’s ability to execute on time and within budget declines, raising financing risk and delaying benefits.
# - Data to improve confidence in 12 months: a credible governance charter, an independent oversight body with public reporting, and a transparent project schedule with milestones and penalties for delays.
#
# Assumption 3: Uptake and effectiveness of voluntary relocation incentives
# - Assessed probabilities: Uptake of voluntary buyouts reaches target among low-income households ~40–70% over a decade, with 0–5% forced displacements.
# - Sensitivity: Lower uptake rates will preserve exposure in buyout target zones and reduce equity gains; higher-than-expected uptake is favorable but may stress housing markets and require additional supply to avoid adverse outcomes like crowding or re-segregation in receiving communities.
# - Data to improve confidence in 12 months: pilot program uptake data, preference surveys, housing market absorption rates for replacement housing, and interim displacement metrics.
#
# Confidence levels and data to improve confidence (for each major recommendation)
# - Nature-based/Hybrid defenses
#   - Confidence: Medium
#   - Data to improve: updated coastal hazard and hydrodynamic models; constructability and maintenance cost data; coastal erosion and habitat restoration performance data for the chosen sites.
# - Hard infrastructure upgrades
#   - Confidence: Medium
#   - Data to improve: detailed risk maps for critical corridors; pump capacity performance tests; cost-to-benefit for each segment under multiple surge scenarios.
# - Targeted buyouts/relocation
#   - Confidence: Medium
#   - Data to improve: baseline household income, housing stock availability in receiving areas, relocation acceptance rates, and long-term housing affordability post-relocation.
# - Zoning/building-code updates
#   - Confidence: High
#   - Data to improve: enforcement capacity metrics; number of buildings upgraded to code; compliance rates; cost implications for builders and homeowners.
# - Insurance subsidies/risk financing
#   - Confidence: Medium
#   - Data to improve: actuarial data on premiums before/after subsidies; city-level catastrophe fund performance; uptake rates among different income groups.
# - Governance reforms
#   - Confidence: High
#   - Data to improve: formal performance dashboards; independent audit results; citizen engagement metrics; timeliness of approvals.
#
# 4) Top five failure modes and concrete contingency/mitigation steps
# 1) Political backlash and gridlock (council/Council-majorities stall plan)
#    - Mitigations: establish an independent adaptation authority with transparent oversight; adopt a small, credible set of prioritized actions (pilot segments) to demonstrate early wins; set a public, time-bound decision calendar; hold regular, cross-partisan briefings; include a citizen advisory panel with equity-focused representation.
#
# 2) Over- or under-estimation of risk and misalignment of incentives (risk model misfit)
#    - Mitigations: require independent risk validation, implement adaptive management with quarterly reviews, continuously update hazard maps and models with new data; implement conservative design margins on critical assets.
#
# 3) Inadequate buyout uptake and inequitable outcomes (displacement risk and inequity)
#    - Mitigations: enhanced relocation incentives, bridging housing programs, targeted outreach in low-income neighborhoods, clear, transparent eligibility criteria, enforce a strong equity-based targeting framework; ensure receiving housing options are available and affordable.
#
# 4) Adverse land-use and development incentives (developers reoccupying risk zones)
#    - Mitigations: revise zoning to restrict new development in high-risk zones; require elevated or floodproofed designs for new construction in nearshore areas; tie insurance subsidies to compliance; implement buyout-backed redevelopment in safe zones.
#
# 5) Funding shortfalls or cost overruns (budget pressure and political backlash)
#    - Mitigations: establish contingency reserves (5–10%), phased funding with milestone-based releases, performance-based payments for contractors, public-private partnerships where appropriate, and a baseline cost-tracking and audit mechanism.
#
# 6) Environmental justice concerns and potential gentrification
#    - Mitigations: ensure outreach and program design are inclusive; targeted protections for long-term residents; integrate affordable replacement housing options and caps on displacement risks; monitor equity metrics annually.
#
# 5) 12–24 month randomized or quasi-experimental pilot (to increase voluntary relocation participation and measure political acceptability)
# - Objective: test mechanisms to increase voluntary relocation uptake among low-income households and gauge short-term political acceptability of the plan.
# - Design: randomized encouragement design (not forcing participation; households are randomly assigned to receive enhanced relocation incentives and outreach vs standard outreach).
# - Sample frame: households in the top 20% flood-prone neighborhoods with incomes at or below 60% of area median income (AMI); target N ≈ 3,000 households (1,000 per arm if 3-arm design).
# - Treatment arms:
#   - Arm 1: Enhanced incentives package (higher buyout offers, moving stipends, bridging loans, guaranteed replacement housing options, rental assistance, and more robust case management).
#   - Arm 2: Community-based outreach (trusted local organizations, community liaisons, culturally appropriate communications, flexible scheduling and in-language materials; integrated social-support services (counselors)).
#   - Arm 3: Control (standard district outreach, baseline buyout terms; conventional process).
# - Randomization approach:
#   - Randomize at the neighborhood block-group level or household level with stratification by initial income level and flood risk.
# - Primary outcomes:
#   - Outcome A: voluntary buyout uptake rate within 24 months.
#   - Outcome B: expressed willingness to relocate (survey-based) and satisfaction with relocation process (post-relocation survey).
# - Secondary outcomes:
#   - Outcome C: time-to-buyout completion; Outcome D: stabilization of housing costs post-relocation; Outcome E: perceived adequacy and fairness of the process.
# - Ethical safeguards:
#   - Informed consent for data collection, voluntary participation, no penalties for opting out; independent IRB oversight; ensure that relocation supports do not infringe on tenant rights; protect privacy and data security; ensure no coercive pressure from program staff.
# - Evaluation design considerations:
#   - Pre/post surveys; administrative data on offers/acceptances; follow-up at 6, 12, 18, and 24 months; differences-in-differences analysis across arms; budget for independent evaluation.
#
# 6) Five measurable indicators (annual) to monitor and decision thresholds
# - Indicator 1: Annual avoided damages (PV or nominal, baseline year 0 = current damages)
#   - Thresholds: if annual avoided damages lag behind target by >20% for two consecutive years, trigger a mid-course adjustment (expansion of protections or more aggressive buyout terms).
# - Indicator 2: Voluntary relocation uptake rate (annual)
#   - Thresholds: target uptake of 5,000–6,500 households over 10 years; if annual uptake <1,000 for two consecutive years, reassess incentives and outreach.
# - Indicator 3: Forced displacement rate
#   - Thresholds: target ≤5% of total displacements; if forced displacements exceed 10% in any year, pause high-risk relocation products and re-focus on voluntary options.
# - Indicator 4: Equity and beneficiary persistence
#   - Thresholds: share of relocations from bottom income quintiles to be ≥60% by year 5; if below 40%, re-target outreach and eligibility to prioritize bottom quintiles and address barriers.
# - Indicator 5: Public acceptability and trust
#   - Thresholds: annual public opinion index showing ≥60% overall support for the plan; if support below 50% for two consecutive years, implement enhanced transparency measures and broaden community engagement (citizen oversight, town halls, independent fact sheets).
#
# 7) Concise, quantitative cost-benefit estimate under two discount rates and three climate-damage trajectories
# Definitions (conservative, defensible approximations):
# - Baseline citywide annual flood damages today: approximately $200M.
# - Climate trajectories by 2036 (no-action reference):
#   - Low: damages rise to about $220–230M/year (net +10–15%);
#   - Medium: damages rise to about $260–300M/year (+30–50%);
#   - High: damages rise to about $400–420M/year (+100%+).
# - Plan’s monetized benefits (PV of avoided damages; discounted):
#   - Low trajectory (3%): PV of benefits ≈ $0.9B; PV of costs ≈ $2.0B -> Net ≈ -$1.1B
#   - Medium trajectory (3%): PV of benefits ≈ $1.6B; PV of costs ≈ $2.0B -> Net ≈ -$0.4B
#   - High trajectory (3%): PV of benefits ≈ $2.4B; PV of costs ≈ $2.0B -> Net ≈ +$0.4B
# - With 7% discount rate (lower PV for both costs and benefits):
#   - Low trajectory (7%): PV benefits ≈ $0.7B; PV costs ≈ $1.6B -> Net ≈ -$0.9B
#   - Medium trajectory (7%): PV benefits ≈ $1.2B; PV costs ≈ $1.6B -> Net ≈ -$0.4B
#   - High trajectory (7%): PV benefits ≈ $1.9B; PV costs ≈ $1.6B -> Net ≈ +$0.3B
# Interpretation:
# - Direct monetized flood-damage reductions alone suggest a negative or near-neutral net present value at 3% discount for low/medium climate trajectories, and a modest positive result only in a high-damage trajectory. At 7%, the plan becomes more favorable only in the high-damage trajectory; in low/medium trajectories the monetized direct benefits do not cover the upfront costs.
# - Important caveats and non-monetized value: social equity gains, reduced involuntary displacement, health benefits from reduced flood exposure, improved urban resilience, and avoided long-term infrastructure depreciation. If these non-market benefits are monetized (or given a high qualitative weight), the plan’s overall value proposition improves, especially under the medium-to-high climate-damage trajectories.
# - Bottom line: the plan’s monetized direct-damages benefits alone do not guarantee positive NPV under all reasonable climate trajectories and discount rates; however, the plan yields important equity, resilience, and health benefits that justify the investment, particularly if non-market benefits are valued in additional analysis and if higher-damage scenarios materialize.
#
# 8) For each major recommendation, level of confidence and the single data piece that would most increase confidence within 12 months
# - Nature-based and hybrid defenses
#   - Confidence: Medium
#   - Data to increase confidence: cost-effective performance data from pilot segments; long-term maintenance costs; hydrodynamic modeling for proposed living shorelines; performance data from comparable cities.
# - Hard infrastructure upgrades
#   - Confidence: Medium
#   - Data to increase confidence: site-specific design flood levels, pump station performance tests, reliability data, and maintenance cost estimates.
# - Targeted buyouts/relocation
#   - Confidence: Medium
#   - Data to increase confidence: uptake rates, replacement housing availability and affordability, tenant rights outcomes, and relocation completion timelines.
# - Zoning/building-code updates
#   - Confidence: High
#   - Data to increase confidence: compliance rates post-implementation, enforcement costs, permits issued for elevated constructions, and case studies from other jurisdictions.
# - Insurance subsidies/risk financing
#   - Confidence: Medium
#   - Data to increase confidence: premium data before/after subsidies, take-up rates by income groups, and city-level catastrophe fund performance.
# - Governance reforms
#   - Confidence: High
#   - Data to increase confidence: independent audit results, dashboard accuracy and timeliness, citizen engagement metrics.
#
# 9) Trade-offs and explicit design choices
# - Trade-off: Protecting economic centers vs. minimizing displacement
#   - Choice: Prioritize protection for critical economic corridors and municipal facilities, but pair with a robust voluntary relocation program for the most exposed, low-income households to minimize involuntary displacement. This reduces fatal risk to the economy while achieving equity objectives.
# - Trade-off: Upfront costs vs. long-term resilience
#   - Choice: Accept front-loaded capital investment in order to reduce long-term annual damages and emergency response costs; use phased funding to reduce political risk and demonstrate early wins.
# - Trade-off: Hard infrastructure vs. nature-based defenses
#   - Choice: A mix that prioritizes hybrid approaches to reduce costs and maximize co-benefits (habitat, recreation, water quality) while still ensuring protection of key assets with select hard infrastructure segments.
# - Trade-off: Public support vs. rapid implementation
#   - Choice: Build cross-party buy-in through transparent governance, targeted pilots (pilot 12–24 months), and clear communication to avoid derailment by short-term politics.
# - Trade-off: Equity focus vs. political feasibility
#   - Choice: Maintain explicit equity commitments (benefitting the poorest households in relocation and protections) even if it complicates implementation timelines; this preserves mandate integrity and reduces long-term social risk.
#
# 10) 12–24 month pilot specifics (described above)
# - Design: randomized encouragement design evaluating enhanced relocation incentives and enhanced outreach vs standard outreach.
# - Sample: ~3,000 low-income households in high-risk zones (1,000 per arm in a 3-arm design).
# - Outcomes: uptake of voluntary buyouts; willingness to relocate; satisfaction with relocation process; time to completion; equity measures in uptake.
# - Safeguards: informed consent; not coercive; privacy protections; independent evaluation; IRB review; ensure replacement housing supply.
#
# 11) Five actionable indicators to monitor annually (thresholds used to accelerate/pause/reverse)
# - Indicator 1: Annual avoided damages (PV or nominal)
#   - Threshold: if annual avoided damages lag target by >20% for two consecutive years, reallocate resources or adjust incentives.
# - Indicator 2: Voluntary relocation uptake rate
#   - Threshold: annual uptake <1,000 households for two consecutive years triggers plan adjustment and targeted outreach.
# - Indicator 3: Forced displacement rate
#   - Threshold: share of forced relocations >10% of total relocations triggers pause on aggressive buyout pacing and re-target strategies.
# - Indicator 4: Equity attainment
#   - Threshold: share of relocations from bottom quintile <40% by year 5 triggers targeted outreach and policy amendments to improve equity.
# - Indicator 5: Public acceptability and legitimacy
#   - Threshold: citywide support below 50% for two consecutive annual surveys triggers enhanced communications and governance reforms.
#
# 12) Final notes on implementation and confidence
# - The plan is deliberately explicit about trade-offs and is designed to be implemented in a politically plausible, phased manner within the 18-month window and within a $2.0B cap.
# - The proposed pilot provides a concrete means to learn what incentives work in practice to maximize voluntary relocations among low-income households and to gauge short-term political acceptability before scaling to full implementation.
# - The plan assumes a robust, independent governance structure and transparent reporting to build trust across a divided council and the community.
# - If non-market benefits and health co-benefits are monetized in a broader economic analysis (beyond the monetized damages), the plan’s overall value proposition strengthens in all climate trajectories.
#
# If you’d like, I can tailor the numbers to your city’s actual current annual flood damages, hazard maps, housing stock, and existing insurance coverage. I can also prepare a one-page executive summary and a draft governance charter for the adaptation authority to help accelerate a council-ready package.
#
# # Response from competitor 2
#
# # 10-Year Coastal Adaptation Plan: Priority-Based Implementation Strategy
#
# ## I. INTERVENTION PORTFOLIO & BUDGET ALLOCATION
#
# ### Phase 1: Immediate Actions (Years 0-3) - $720M
#
# **1. Hybrid Defense for Economic Core ($380M)**
# - **Intervention**: Elevated seawall + tidal marsh restoration along 8 km waterfront downtown/port district
# - **Timing**: Design Y0-1, construction Y1-3
# - **Rationale**: Protects 40% of tax base, employs nature-based buffer where feasible
# - **Expected outcome**: Reduces expected annual damages (EAD) from $180M to $45M in protected zone (~75% reduction for 35,000 jobs, 8,000 residents)
#
# **2. Voluntary Buyout Program - Priority Zones ($200M)**
# - **Intervention**: Purchase 800 properties in highest-risk areas (<2m elevation, repetitive loss history)
# - **Timing**: Rolling enrollment Y0-3, conversion to wetlands Y2-4
# - **Payment structure**: 125% pre-flood fair market value + $50K relocation subsidy + right of first refusal for affordable housing in safer zones
# - **Expected outcome**:
#   - 800 households relocated (est. 2,400 people)
#   - 70% voluntary participation rate (target low-income: 340 households)
#   - Reduces citywide EAD by $28M
#   - Distributional impact: +15% net wealth transfer to participating low-income households vs. status quo erosion
#
# **3. Emergency Building Code Reform ($40M implementation)**
# - **Intervention**: Mandate first-floor elevation +1.2m for new construction/substantial renovation in flood zones; create fast-track permitting + $30M subsidy pool for low-income compliance
# - **Timing**: Ordinance Y0, enforcement Y1+
# - **Expected outcome**: 450 retrofits Y1-10, reducing structure damage 60% per building
#
# **4. Flood Insurance Transition Program ($100M reserve)**
# - **Intervention**: Municipal catastrophe bond + means-tested premium subsidies to prevent NFIP policy lapses
# - **Timing**: Y0-2 setup
# - **Expected outcome**: Maintain 85% insurance coverage (down from 72% without intervention) among bottom income quintile
#
# ### Phase 2: Adaptive Measures (Years 4-7) - $880M
#
# **5. Living Shoreline Expansion ($320M)**
# - **Intervention**: Restore 15 km oyster reefs, salt marshes, and dune systems along eastern residential coast
# - **Timing**: Staged construction Y4-7
# - **Expected outcome**: Attenuate storm surge 20-35 cm, reduce EAD by $52M in adjacent neighborhoods (18,000 residents, 60% below median income)
#
# **6. Strategic Elevation of Critical Infrastructure ($280M)**
# - **Intervention**: Raise 3 sewage treatment plants, 2 power substations, hospital access roads
# - **Timing**: Y4-6
# - **Expected outcome**: Prevent $420M in cascade failures during 100-year event
#
# **7. Affordable Housing Development in Low-Risk Zones ($200M)**
# - **Intervention**: Public-private partnership to build 1,200 units at 60% AMI eligibility on elevated municipal land
# - **Timing**: Y5-8 construction
# - **Expected outcome**: House 600 buyout participants + 600 existing wait-list families, net zero involuntary displacement
#
# **8. Expanded Buyouts - Phase 2 ($80M)**
# - **Intervention**: Additional 250 properties in moderate-risk areas
# - **Timing**: Y5-7
# - **Expected outcome**: 750 people relocated, $9M EAD reduction
#
# ### Phase 3: Resilience Lock-In (Years 8-10) - $400M
#
# **9. Adaptive Traffic & Utility Networks ($220M)**
# - **Intervention**: Reroute 6 arterial roads, elevate water mains, create redundant power loops
# - **Expected outcome**: Reduce post-storm recovery time 40% (economic continuity benefit)
#
# **10. Community Resilience Hubs ($80M)**
# - **Intervention**: Retrofit 12 schools
#
# # Response from competitor 3
#
# Mayor, Members of the City Council,
#
# This memo outlines a prioritized 10-year adaptation plan for our mid-sized coastal city, designed to address the projected 0.6m average sea-level rise and doubling of 100-year storm surge intensity by 2050, within your $2.0 billion capital budget. My recommendations are based on the core principles of minimizing involuntary displacement, addressing socioeconomic inequality, and balancing long-term resilience with the immediate political context.
#
# ### **1. Prioritized 10-Year Adaptation Plan (Budget: $2.0 Billion)**
#
# Our strategy is a "layered defense" approach, blending protective infrastructure, managed retreat, and city-wide resilience building. It's phased to allow for learning, adaptation, and political navigation.
#
# **Phase 1 (Years 1-3: Immediate Action & Foundation - ~$550 Million)**
# *   **Goal:** Secure critical infrastructure, initiate voluntary programs, and establish regulatory and governance frameworks. Focus on politically feasible, visible projects for early wins.
# *   **Interventions:**
#     1.  **Targeted Soft/Nature-Based Defenses (Primary Priority):** Mangrove restoration, dune creation, and living shorelines in 3-5 high-vulnerability coastal segments. Focus on areas with existing ecological potential or where they can augment existing grey infrastructure.
#         *   *Budget:* $150M.
#         *   *Confidence: High.* *Data Needed:* Comprehensive habitat mapping and high-resolution hydrodynamic modeling to optimize placement and design for maximum wave attenuation.
#     2.  **Critical Infrastructure Hardening (Strategic):** Flood-proofing and elevating key municipal services (e.g., wastewater treatment plants, main hospitals, emergency services hubs) and vital transportation arteries serving economic centers.
#         *   *Budget:* $200M.
#         *   *Confidence: High.* *Data Needed:* Detailed vulnerability assessments for specific critical infrastructure assets under 2050 climate scenarios, including cascading failure analysis.
#     3.  **Voluntary Relocation/Buyout Program - Pilot Phase (Targeted, Equity-Focused):** Launch a pilot program (detailed in Section 5) for 500-700 households in 1-2 of the highest-risk, predominantly low-income neighborhoods. Offer above-market value buyouts (120-130% of pre-flood risk value) and comprehensive assistance for relocation/rehousing in safer, designated "receiving zones."
#         *   *Budget:* $100M.
#         *   *Confidence: Medium.* *Data Needed:* Detailed property valuation data, demographic mapping of high-risk areas, and survey data on relocation preferences/barriers for low-income households.
#     4.  **Zoning & Building Code Updates (Initial Draft & Public Consultation):** Develop new zoning ordinances to restrict new construction in the 50-year floodplain and updated building codes requiring elevated foundations and flood-resistant materials in the 100-year floodplain. Identify and zone initial "receiving zones" for relocated populations.
#         *   *Budget:* $30M (staffing, consultants, extensive public engagement).
#         *   *Confidence: High.* *Data Needed:* Legal review of existing zoning authority and potential eminent domain implications for receiving zones.
#     5.  **Governance Reform - Climate Resilience Office & Stakeholder Task Force:** Establish a dedicated Climate Resilience Office to coordinate efforts and a multi-stakeholder task force (community reps, businesses, environmental groups) to provide ongoing advice and build consensus.
#         *   *Budget:* $20M (initial staffing, office setup).
#         *   *Confidence: High.* *Data Needed:* Best practices from other cities on effective multi-stakeholder governance models for climate adaptation.
#     6.  **Data & Modeling Refinement:** Invest in high-resolution flood modeling, socioeconomic vulnerability mapping, and ecosystem service valuation to inform future interventions.
#         *   *Budget:* $30M.
#         *   *Confidence: High.* *Data Needed:* Existing LiDAR data and bathymetry data for the entire coastal zone.
#     7.  **Public Awareness & Education Campaign:** Launch a city-wide campaign to inform residents about climate risks, the plan, and available resources, fostering community resilience.
#         *   *Budget:* $20M.
#         *   *Confidence: High.* *Data Needed:* Public perception surveys on climate change risks and preferred adaptation strategies.
#
# **Phase 2 (Years 4-7: Scaling Up & Integrated Solutions - ~$850 Million)**
# *   **Goal:** Expand successful pilot programs, implement regulatory changes, and invest in larger-scale, strategically critical infrastructure.
# *   **Interventions:**
#     1.  **Expanded Voluntary Relocation/Buyout Program:** Scale up the program, incorporating lessons learned from the pilot. Continue offering strong incentives for low-income households and expand to other high-risk, non-critical areas. Develop "resilience hubs" in receiving zones with enhanced public services (schools, clinics, community centers).
#         *   *Budget:* $350M.
#         *   *Confidence: Medium.* *Data Needed:* Longitudinal data from the pilot program on participant satisfaction, re-housing success, and community integration.
#     2.  **Major Hard Infrastructure Projects (Strategic Seawalls/Levees):** Construct targeted seawalls or flood barriers to protect specific, high-value economic districts or large dense populations that cannot reasonably be relocated and have clear cost-benefit justification. These will be integrated with nature-based features where possible.
#         *   *Budget:* $300M.
#         *   *Confidence: Medium.* *Data Needed:* Detailed engineering designs and cost-benefit analysis for specific hard infrastructure proposals, including long-term maintenance costs and residual risk assessments.
#     3.  **City-Wide Building Code & Zoning Enforcement:** Implement and rigorously enforce the new zoning ordinances and building codes. Provide subsidies and financial incentives for existing homeowners (especially low-income) to retrofit properties to meet new standards.
#         *   *Budget:* $100M (for subsidies and enforcement).
#         *   *Confidence: High.* *Data Needed:* Baseline data on current building code compliance rates, particularly in vulnerable areas.
#     4.  **Flood-Resilient Green Infrastructure:** Expand green infrastructure projects (e.g., permeable surfaces, bioswales, urban wetlands) throughout the city to manage stormwater, reduce urban heat island effect, and provide flood protection.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Detailed hydrologic modeling to identify optimal locations for green infrastructure to maximize stormwater retention and flood reduction benefits.
#
# **Phase 3 (Years 8-10: Long-Term Resilience & Adaptive Management - ~$600 Million)**
# *   **Goal:** Integrate adaptation into all city planning, continue strategic protection, and prepare for future challenges.
# *   **Interventions:**
#     1.  **Continued Voluntary Relocation/Buyout & Redevelopment:** Sustain the program, strategically acquiring additional high-risk properties and transforming vacated land into nature-based defenses, open space, or buffer zones.
#         *   *Budget:* $200M.
#         *   *Confidence: Medium.* *Data Needed:* Public perception and economic impact studies on the long-term transformation of vacated land and receiving zones.
#     2.  **Regional Collaboration & Early Warning Systems:** Invest in regional partnerships for adaptation strategies (e.g., shared flood models, emergency response protocols) and develop advanced local early warning systems for storm surge and flooding.
#         *   *Budget:* $50M.
#         *   *Confidence: High.* *Data Needed:* Inventory of existing regional agreements and emergency communication protocols.
#     3.  **Adaptive Management Fund:** Establish a dedicated fund for unforeseen adaptation needs, research and development of new technologies, and to scale up or pivot interventions based on monitoring data and evolving climate projections.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Detailed analysis of historical disaster relief spending and potential future funding gaps.
#     4.  **Insurance/Subsidy Program Development:** Collaborate with state and federal partners to develop a specialized flood insurance subsidy program for low-to-moderate income households in remaining high-risk zones who cannot or choose not to relocate, ensuring affordability while incentivizing risk reduction.
#         *   *Budget:* $50M (initial seed funding/subsidies for low-income).
#         *   *Confidence: Medium.* *Data Needed:* Actuarial analysis of current flood insurance uptake and claims among low-income households, and assessment of federal/state appetite for partnership.
#     5.  **Long-term Monitoring & Research:** Continuously monitor sea-level rise, storm intensity, and the effectiveness of all interventions. Fund local research into climate impacts and adaptation solutions.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Baseline ecological data for nature-based solutions and socio-economic data for relocated communities.
#     6.  **Climate-Resilient Infrastructure Upgrades:** Continue investing in upgrades to grey infrastructure (e.g., drainage systems, power grids) to make them more resilient to climate impacts, guided by lessons learned.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Infrastructure condition assessments across all municipal systems.
#
# ### **2. Quantified Expected Outcomes (by 2033 - end of 10-year plan, impacting 2050 targets)**
#
# *   **Reduction in Expected Annual Flood Damages (by 2050):**
#     *   *Baseline (without plan):* Projected $200-300 million annually by 2050.
#     *   *With Plan:* **~60-70% reduction**, bringing annual damages down to **$60-120 million by 2050.**
# *   **Number of People/Households Displaced or Relocated (by 2033):**
#     *   *Voluntary Relocation/Buyouts:* **2,500 - 4,000 households** (approx. 7,500 - 12,000 people) voluntarily relocated through incentivized programs.
#     *   *Forced Displacement:* **Minimized to effectively zero**, fulfilling the legal mandate.
# *   **Change in Socioeconomic Equity (Distributional impact on poorest 20%):**
#     *   **Significant positive impact.** Poorest 20% in high-risk zones will be offered above-market value buyouts and comprehensive relocation support.
#     *   **Quantitative Proxy:** Aim for a **10-15% reduction in the number of households below the poverty line living in the 100-year floodplain** by 2033, and a **25-30% reduction in their expected uninsured flood losses.**
#
# ### **3. Three Most Important Assumptions & Sensitivity**
#
# 1.  **Political Will & Bipartisan Cooperation Persist:**
#     *   *Details:* The $2.0B budget is sustained, and the politically divided council cooperates on necessary legislative changes (zoning, building codes). The upcoming election does not derail the plan.
#     *   *Sensitivity:* **High.** *Violation:* Gridlock or funding cuts (20-40% probability) would cause delays, cost overruns, incomplete projects, and potential failure to meet adaptation goals.
# 2.  **Sufficient Voluntary Participation in Buyout/Relocation:**
#     *   *Details:* Incentives (above-market value, assistance) are sufficient to encourage a critical mass of residents, especially low-income households, to voluntarily participate.
#     *   *Sensitivity:* **Medium-High.** *Violation:* Low participation rates (15-30% probability) would undermine equity goals and the non-displacement mandate, leading to continued exposure and higher future damage costs.
# 3.  **Future Climate Projections are Broadly Accurate:**
#     *   *Details:* The 0.6m SLR and 2x 100-year storm surge by 2050 projections are sufficient for planning.
#     *   *Sensitivity:* **Medium.** *Violation (Worse Case):* Impacts significantly accelerate beyond projections (10-20% probability of underestimation) rendering interventions insufficient, requiring costly emergency upgrades. *Violation (Better Case):* Impacts are less severe (5-10% probability of overestimation) leading to over-investment, though with residual co-benefits.
#
# ### **4. Top Five Failure Modes & Contingency/Mitigation**
#
# 1.  **Failure Mode: Political Backlash & Loss of Public Support.**
#     *   *Contingency:* Implement extensive, ongoing public outreach and education, involve affected communities in co-design, start with successful pilots, and ensure legal robustness of policies.
# 2.  **Failure Mode: Low Voluntary Participation in Buyout/Relocation.**
#     *   *Contingency:* Enhance incentives (increase buyout offers to 150%, expand assistance), empower community-led relocation efforts, invest heavily in attractive "resilience hubs" in receiving zones, and continuously refine strategies based on pilot feedback.
# 3.  **Failure Mode: Cost Overruns & Budget Exhaustion.**
#     *   *Contingency:* Strict project management, rigorous cost estimates, contingency planning, value engineering, active pursuit of state/federal/private grants, and judicious use of the Adaptive Management Fund.
# 4.  **Failure Mode: Maladaptation (Interventions Worsen Problems).**
#     *   *Contingency:* Integrated planning with advanced modeling, thorough Environmental Impact Assessments, robust monitoring and evaluation systems to detect issues early, and active regional collaboration to avoid shifting risks.
# 5.  **Failure Mode: Adverse Incentives (e.g., "Moral Hazard").**
#     *   *Contingency:* Link flood insurance subsidies to mandatory mitigation measures, use risk-based pricing (with affordability measures) to communicate true risk, maintain strict zoning/building codes, and conduct ongoing public education on individual preparedness.
#
# ### **5. Feasible 12–24 Month Randomized or Quasi-Experimental Pilot**
#
# **Objectives:** (a) Increase voluntary participation in relocation/buyout among low-income households, and (b) measure short-term political acceptability.
#
# **Intervention Target:** One of the highest-risk, predominantly low-income neighborhoods (approx. 500-700 households) designated as the "Pilot Zone."
#
# **Treatment Arms (for Voluntary Participation within Pilot Zone):**
# *   **Control Group (N=~200-250 households):** Standard city communications on flood risk; "fair market value" buyout offer (pre-flood risk appraisal).
# ...
# | **2025‑2028** | **(E) Insurance/Subsidy & Risk‑Education Program** | • Tiered premium subsidies for low‑income (≤ 150 % FPL) – 30 % reduction on NFIP rates. <br>• Community outreach, flood‑risk dashboards, and “Resilience Savings Accounts” (matched grants for home‑hardening). | $100 M | 5 % |
# | **2025‑2027** | **(F) Governance & Institutional Reforms** | • Create a Climate‑Resilience Office (CRO) with authority to coordinate all interventions, monitor performance, and manage the $250 M contingency fund. | $50 M | 2.5 % |
# | **2025‑2026** | **(G) Contingency/Reserve** | • Unspent funds, cost overruns, emergency repairs. | $250 M | 12.5 % |
# | **TOTAL** | | | **$2.0 B** | **100 %** |
#
# *All spending is front‑loaded (≈ 80 % in the first five years) to lock‑in physical protection before the 2030‑mid‑decade storm intensification peak.*
#
# ---
#
# ## 2.  Quantified Expected Outcomes (10‑yr horizon)
#
# | Metric | Baseline (2025) | Projected 2035 (with plan) | Reduction / Improvement | Comments |
# |--------|----------------|----------------------------|--------------------------|----------|
# | **Annual expected flood damage** (direct property & infrastructure) | $300 M (2025) – rising 4 %/yr without action → $440 M by 2035 | $150 M average (2025‑2035) | **≈ 45 % cut** (≈ $135 M/yr avoided) | Savings driven by seawall + nature‑based attenuation (≈ 30 %); buy‑outs eliminate highest‑risk structures (≈ 15 %). |
# | **Households displaced (forced)** | 5 % of at‑risk households (~2 500) would be forced by 2035 under business‑as‑usual | < 200 (≈ 0.2 %) | **≥ 92 % reduction** | All relocation is voluntary; emergency‑evacuation plans limit forced moves. |
# | **Households voluntarily relocated (buy‑out)** | 0 | 2 000 (≈ 5 % of at‑risk) | — | 60 % of these are low‑income → 1 200 poor households. |
# | **Low‑income (bottom 20 %) risk exposure** | 30 % of this group lives in 1‑in‑5 most flood‑prone parcels | 12 % (after buy‑outs + elevation incentives) | **60 % relative risk drop** | Measured as probability of flood depth > 0.5 m per year. |
# | **Flood‑insurance coverage (low‑income)** | 45 % (2025) | 85 % (2028) | +40 ppt | Subsidy + education drives uptake. |
# | **Economic activity protected** | $12 B of taxable commercial/industrial floor space in core district | 95 % retained (seawall protects) | – | Trade‑off: heavy investment in core vs. peripheral neighborhoods. |
#
# ---
#
# ## 3.  Three Core Assumptions & Sensitivity
#
# | # | Assumption | Reasonable Range (probability) | Sensitivity |
# |---|------------|--------------------------------|-------------|
# | **A** | **SLR reaches 0.6 m by 2050** (median IPCC AR6 RCP4.5) | 0.6 m ± 0.1 m (≈ 70 % chance) | *If SLR is > 0.8 m*, seawall freeboard must be increased → extra $150‑200 M. *If SLR is < 0.4 m*, we could defer part of the hard barrier (cost saving ≈ $100 M). |
# | **B** | **100‑yr storm surge intensity doubles** (wind‑speed & surge height) | 2× ± 30 % (≈ 55 % chance) | *If surge increase is only 1.5×*, the hybrid barrier can be built to lower height, saving ≈ $80 M. *If surge spikes to 2.5×*, we would need additional overtopping protection (≈ $120 M). |
# | **C** | **Low‑income households will accept voluntary buy‑outs when offered ≥ 80 % of market value + relocation grant** | Acceptance 70‑85 % (≈ 75 % chance) | *If acceptance falls below 55 %*, we must increase the grant or shift to more aggressive zoning (cost ≈ $50 M). *If acceptance exceeds 90 %*, we could re‑allocate excess funds to nature‑based projects. |
#
# Overall plan success is **medium‑high** (≈ 70 % probability of achieving ≥ 40 % damage reduction and ≤ 200 forced displacements) given current scientific confidence and community‑engagement pilots (see §5).
#
# ---
#
# ## 4.  Top‑5 Failure Modes & Mitigation
#
# | # | Failure Mode | Likely Consequence | Contingency / Mitigation |
# |---|--------------|-------------------|--------------------------|
# | **1** | **Political backlash over “big‑seawall” cost** (election 2027) | Funding freeze, re‑allocation to other priorities | • Phase the barrier (Phase I: 4 km protecting the most critical assets) with clear cost‑benefit communication; <br>• Establish a “Resilience Bond” financed through a modest (0.1 %) property tax dedicated to the project; <br>• Early bipartisan outreach using local business coalition data on avoided losses. |
# | **2** | **Buy‑out program perceived as “selling out” low‑income neighborhoods** | Low participation, protests, legal challenges | • Co‑design the program with community NGOs; <br>• Offer “green‑relocation” grants for moving to affordable, pre‑built resilient housing; <br>• Publicly publish transparent cost‑benefit and equity impact analyses. |
# | **3** | **Gentrification after protection of downtown** (property values surge) | Displacement of renters & small businesses | • Pair the seawall with inclusionary‑housing ordinances that reserve 20 % of new units for households ≤ 150 % FPL; <br>• Use a “Community Land Trust” to hold key parcels for affordable use. |
# | **4** | **Construction delays / cost overruns (seawall, wetlands)** | Budget overspend, missed 2030 target | • Fixed‑price EPC contracts with performance penalties; <br>• Independent “Resilience Oversight Committee” with quarterly audits; <br>• Maintain $250 M contingency reserve (see Table 1). |
# | **5** | **Insurance/subsidy fraud or moral hazard** | Uncontrolled premium losses, reduced fiscal sustainability | • Link subsidies to verified elevation/retrofit standards; <br>• Require annual flood‑risk re‑assessment for continued eligibility; <br>• Use GIS‑based fraud detection analytics. |
#
# ---
#
# ## 5.  12‑24‑Month Pilot to Boost Low‑Income Relocation & Test Political Acceptability
#
# | Element | Design |
# |---------|--------|
# | **Sample frame** | 1 200 low‑income (≤ 150 % FPL) households in the top 30 % flood‑risk parcels (identified via high‑resolution LiDAR flood maps). |
# | **Randomisation** (three arms, 400 households each) | 1. **Cash‑Incentive Arm** – 85 % market‑value buy‑out + $5 k relocation grant (baseline offer). <br>2. **Counselling‑Plus‑Design Arm** – Same cash offer + a dedicated case‑worker, a “design‑your‑new‑home” workshop, and a guaranteed spot in a new affordable‑resilient‑housing complex. <br>3. **Control Arm** – Standard city outreach (information brochure, no additional services). |
# | **Primary outcomes (12‑month horizon)** | • % of households signing a buy‑out agreement (target > 70 % in Arm 2, > 55 % in Arm 1, < 30 % in Control). <br>• Change in “plan acceptability” score (1‑5 Likert) measured via door‑to‑door surveys across the whole pilot area. |
# | **Secondary outcomes** | • Median time from offer to contract signing; <br>• Reported perceived fairness; <br>• Uptake of flood‑insurance among remaining at‑risk households. |
# | **Ethical safeguards** | • Informed consent with clear explanation that participation is voluntary and will not affect eligibility for the standard city program. <br>• Independent Institutional Review Board (IRB) oversight. <br>• Data anonymisation; opt‑out option for any household at any stage. |
# | **Timeline** | • **Month 1‑3** – GIS risk mapping & household recruitment. <br>• **Month 4‑6** – Randomisation & baseline survey. <br>• **Month 7‑18** – Offer rollout, counselling, monitoring. <br>• **Month 19‑24** – Final survey, analysis, policy brief. |
#
# *Result:* The pilot will quantify the “price‑elasticity” of low‑income buy‑out acceptance and provide a rapid gauge of political support (acceptability score) before the 2027 council election.
#
# ---
#
# ## 6.  Five Annual Monitoring Indicators (with Decision Thresholds)
#
# | Indicator | Target (2025‑2035) | Threshold for Action |
# |-----------|-------------------|-----------------------|
# | **1. Annual Flood‑Damage Expenditure** (city‑reported, $M) | ≤ $150 M (average) | > $180 M → Review/strengthen physical defenses (add height, expand nature‑based area). |
# | **2. Low‑Income Flood‑Insurance Coverage** (% of eligible households) | ≥ 85 % | < 70 % → Increase subsidy or expand outreach budget by 20 %. |
# | **3. Voluntary Buy‑Outs Completed** (units/yr) | 200 ± 30 | < 150 yr → Boost cash incentive or expand counselling pilot. |
# | **4. Equity Risk‑Reduction Ratio** (risk reduction for poorest 20 % ÷ city‑wide risk reduction) | ≥ 1.0 (i.e., poorest benefit at least as much) | < 0.8 → Re‑allocate funds to targeted retrofits or expand affordable‑housing set‑aside. |
# | **5. Council/Mayor Public‑Support Index** (average score of city‑wide poll, 1‑5) | ≥ 3.5 (≥ 70 % “support”) | < 3.0 → Launch city‑wide communication campaign; consider adjusting financing mechanism. |
#
# Indicators are compiled by the **Climate‑Resilience Office** and presented at the quarterly City Council “Resilience Review”.
#
# ---
#
# ## 7.  Cost‑Benefit Estimate (NPV, 10 yr)
#
# ### Assumptions
# * **Discount rates**: 3 % (social planner) vs. 7 % (municipal finance).
# * **Damage trajectories** (baseline without adaptation):
#   * **Low** – 1 %/yr increase (minimal storm intensification).
#   * **Medium** – 3 %/yr (current IPCC median).
#   * **High** – 6 %/yr (upper‑range storm surge).
# * **Adaptation effect** – 45 % reduction in damages (flat over the horizon).
#
# | Scenario | Discount % | Present Value of Damages (no action) | PV of Damages **with plan** | PV of Adaptation Cost* | **Net Benefit (NPV)** |
# |----------|-----------|--------------------------------------|----------------------------|------------------------|----------------------|
# | Low | 3 % | $3.2 B | $1.8 B | $1.5 B | **+$0.0 B** |
# | Low | 7 % | $2.8 B | $1.6 B | $1.5 B | **+$0.1 B** |
# | Medium | 3 % | $4.9 B | $2.7 B | $1.5 B | **+$0.7 B** |
# | Medium | 7 % | $4.2 B | $2.3 B | $1.5 B | **+$0.3 B** |
# | High | 3 % | $7.9 B | $4.4 B | $1.5
#
# # Response from competitor 6
#
# **Prioritized 10-Year Adaptation Plan**
#
# With a $2.0 billion budget, I propose the following interventions:
#
# 1. **Seawall and Dunes System** (2.5B, $1.25B, 2024-2029):
# 	* Construct a 5 km seawall and build a 3 km long dunes system to protect the city center.
# 	* Expected reduction in annual flood damages: $120 million (20% decrease).
# 	* Number of displaced/households relocated: 10,000 (20% decrease).
# 	* Change in socioeconomic equity: Reduction in flood-related economic hardship among the poorest 20%.
# 2. **Smart Grid and Flood-Proofing Zoning** (400M, $200M, 2024-2028):
# 	* Upgrade the city's electrical grid to withstand flooding and install smart sensors to monitor storm surges.
# 	* Implement zoning regulations that require new construction to be built above grade or use flood-proof materials.
# 3. **Relocation/ Buyout Program** (300M, $150M, 2024-2029):
# 	* Establish a voluntary relocation program for low-income households in high-risk flood areas.
# 	* Offer buyouts or relocation packages to encourage voluntary participation.
# 	* Expected increase in voluntary participation: 40% ( increase in program enrollment).
# 4. **Insurance/Subbidy Programs** (400M, $200M, 2024-2028):
# 	* Implement a city-funded insurance program to cover flood-related losses.
# 	* Offer subsidies to households in high-risk flood areas to help mitigate financial burden.
# 5. **Governance Reforms** (200M, $100M, 2025-2029):
# 	* Implement a participatory budgeting process to ensure inclusive decision-making.
# 	* Establish a flood resiliency trust fund to prioritize adaptation investments.
#
# **Assumptions and Sensitivity**
#
# 1. **Sea-Level Rise and Storm Surge Intensity**: High sensitivity (50% impact on plan's success, 1:1 probability range). Assuming 0.6 m sea-level rise and doubling of 100-year storm surge intensity is a reasonable assumption based on current IPCC projections.
# 2. **Economic Growth and Inflation**: Medium sensitivity (30% impact on plan's success, 2:1 probability range). Assuming a 2% annual economic growth rate and moderate inflation (1.5%) is a conservative estimate based on historical data.
# 3. **Citizen Engagement and Participation**: Medium sensitivity (30% impact on plan's success, 2:1 probability range). Assuming high levels of citizen engagement and participation in the adaptation process is crucial for successful implementation.
#
# **Failure Modes and Contingency Planning**
#
# 1. **Political Backlash**: Establish a stakeholder advisory committee to ensure inclusive decision-making.
# 2. **Adverse Incentives**: Implement a revenue neutral, carbon-fund-based financing mechanism to reduce the burden on taxpayers.
# 3. **Insufficient Public Engagement**: Establish community outreach programs to ensure informed decision-making by all stakeholders.
# 4. **Inadequate Funding**: Prioritize interventions with the greatest expected outcomes and implement phase-in financing plans.
# 5. **Low-Intensity Storms**: Implement adaptive management plans to address unexpected storm intensity.
#
# **Pilot Study**
#
# Title: "Flood-Resilient Neighborhoods"
#
# * Sample Frame: 1,500 low-income households in high-risk flood areas.
# * Treatment Arms:
# 	+ Group A: Standard relocation/buyout program.
# 	+ Group B: Enhanced program with community engagement and education components.
# 	+ Group C: Control group with no additional program components.
# * Primary Outcome: Increase in voluntary participation in the relocation/buyout program among low-income households.
# * Ethical Safeguards: Randomized controlled trial with informed consent and anonymized data.
#
# **Performance Monitoring**
#
# 1. Annual Flood Risk Assessment.
# 2. Displacement/Relocation Program Metrics: Enrollment rates, retention rates, and program effectiveness.
# 3. Economic Benefit Categorization: Reduction in flood-related losses, increase in economic productivity, and reduction in poverty rates.
# 4. Social Equity Metrics: Distribution of benefits, reduction in flood-related hardship among vulnerable populations.
# 5. Stakeholder Engagement Indices: Citizen participation rates, stakeholder satisfaction, and community engagement quality.
#
# **Cost-Benefit Analysis**
#
# Scenario 1 (3% discount rate): -$1.3 billion (benefit: - $1.1 billion displacement cost reduction, - $150 million increased economic costs; - $50 million loss of avoided damages).
#
# Scenario 2 (7% discount rate): -2.1 billion (benefit: - $1.6 billion displacement cost reduction, - $200 million increased economic costs; - $80 million loss of avoided damages).
#
# Scenario 3 (Low Climate Damage Trajectory): +$1.5 billion (benefit: +$1.2 billion displacement cost reduction, + $100 million increased economic costs; -$200 million loss of avoided damages).
#
# Scenario 4 (Medium Climate Damage Trajectory): +$2.2 billion (benefit: +$1.8 billion displacement cost reduction, + $150 million increased economic costs; -$300 million loss of avoided damages).
#
# Scenario 5 (High Climate Damage Trajectory): +$3.2 billion (benefit: +$2.6 billion displacement cost reduction, + $200 million increased economic costs; -$400 million loss of avoided damages).
#
# **Confidence Levels**
#
# 1. Seawall and Dunes System: High (90%), 3D lidar data collection within 12 months to increase confidence.
# 2. Relocation/Buyout Program: High (90%), Establish a stakeholder advisory committee to ensure inclusive decision-making.
# 3. Smart Grid and Flood-Proofing Zoning: Medium (60%), Monitor performance and make adjustments as necessary.
# 4. Insurance/Subsidy Programs: Medium (60%), Develop comprehensive actuarial models to ensure risk-sharing mechanisms are in place.
# 5. Governance Reforms: Medium (60%), Implement participatory budgeting and community outreach programs to ensure inclusive decision-making.
#
# Note: A comprehensive, multi-year implementation plan will require ongoing monitoring, adaptation, and fine-tuning to achieve the planned outcomes. This plan provides a starting point for the city to prioritize their adaptations.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1", "3", "4", "5", "2", "6"]}

# %%
reviewer = f"""You are the peer reviewer of a competition result between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

The judge ranked the competitors as follows:

{results}

Now respond with either simply "I agree", nothing else, or "I disagree" with your comments on why the judge got it wrong. Provide comments only when you disagree."""

# %%
print(reviewer)
# Out:
# You are the peer reviewer of a competition result between 6 competitors.
# Each model has been given this question:
#
# You are an independent advisor to the mayor of a mid-sized coastal city (population 500,000) that faces a projected 0.6 m average sea-level rise and doubling of 100-year storm surge intensity by 2050. The city has a 10-year capital budget of $2.0 billion for adaptation, a legally binding mandate to minimize involuntary displacement, substantial socioeconomic inequality (20% of households are below the poverty line), and an election in 18 months with a politically divided council. You may choose any combination of interventions (hard infrastructure such as seawalls, soft/nature-based defenses, targeted buyouts and voluntary relocation, zoning and building-code changes, insurance/subsidy programs, or governance reforms).
#
# Produce a prioritized 10-year adaptation plan that:
# - Specifies which interventions to implement, their timing, and an approximate budget allocation (add up to ≤ $2.0B),
# - Quantifies expected outcomes in rough, defensible numbers: reduction in expected annual flood damages, number of people/households displaced or relocated (voluntary vs. forced), and change in socioeconomic equity (e.g., distributional impact on poorest 20%),
# - Lists the three most important assumptions you are making and how sensitive your plan’s success is to violations of each (give probability ranges where possible),
# - Identifies the top five failure modes (including political backlash and adverse incentives) and concrete contingency/mitigation steps for each,
# - Describes a feasible 12–24 month randomized or quasi-experimental pilot (sample frame, treatment arms, primary outcome, and ethical safeguards) designed to (a) increase voluntary participation in a relocation/buyout program among low-income households, and (b) measure short-term political acceptability of the plan,
# - Gives five measurable indicators (with thresholds) the city should monitor annually to decide whether to accelerate, pause, or reverse specific interventions,
# - Provides a concise, quantitative estimate of overall plan cost-benefit under two discount-rate scenarios (3% and 7%) and three plausible climate-damage trajectories (low/medium/high), and
# - For each major recommendation, state your level of confidence (high/medium/low) and the single piece of data that would most increase your confidence if obtained within 12 months.
#
# Be explicit about trade-offs you accept (e.g., protecting economic centers vs. minimizing displacement), avoid vague platitudes, and keep your answer focused and actionable.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Below is a concrete, donor-ready 10-year adaptation plan tailored to a mid-sized coastal city (population ~500,000) facing 0.6 m sea‑level rise and doubling of 100-year surge by 2050. It is structured to fit a legally binding mandate to minimize involuntary displacement, address inequality, and work within a $2.0B 10-year capital budget while navigating a politically divided council and an election in 18 months.
#
# Executive summary
# - Core goal: reduce flood risk and protect critical economic/urban cores while prioritizing voluntary relocation for the neediest, and strengthening governance so investments are defended by evidence and community legitimacy.
# - Core mix of actions: a balanced portfolio of nature-based and hybrid defenses, targeted hard infrastructure upgrades, a voluntary buyout/relocation program with strong protections for low-income households, updated zoning/building codes, risk financing/subsidies to lower insurance barriers, and governance reforms to enable adaptive management.
# - 10-year budget (not-to-exceed $2.0B):
#   - A) Nature-based/hybrid defenses: $700M
#   - B) Hard infrastructure/drainage upgrades: $550M
#   - C) Targeted buyouts/voluntary relocation: $520M
#   - D) Zoning/building-code updates: $140M
#   - E) Insurance subsidies/risk financing: $60M
#   - F) Governance and implementation management: $30M
#   - Total: $2.00B
# - Expected outcomes (rough, defensible):
#   - Reduction in expected annual flood damages by approximately 60–70% in protected zones; net citywide annual damages reduced from roughly $200M today to the low-to-mid $100Ms by 2036 under the high-damage trajectory, with more modest reductions under lower climate-damage trajectories.
#   - Displacement: voluntary relocations of roughly 3,500–6,000 households (roughly 11,000–17,000 people) over the decade; forced relocations kept at 0–5% of total displacement.
#   - Equity: the program prioritizes the lowest-income households; by year 5–7, the share of relocated households from the bottom two quintiles rises to ~60–75% of relocations; poorest 20% see enhanced protection in protected areas and higher uptake in buyouts where appropriate.
# - Key risks, failure modes, and mitigations are identified, along with a pilot to test voluntary relocation incentives and measure political acceptability.
# - Five annual indicators, with decision thresholds, to guide acceleration/pausing/reversals.
# - A concise, scenario-based cost-benefit: two discount rates (3% and 7%) and three climate-damage trajectories (low/medium/high). In high-damage scenarios, the plan yields positive net benefits that justify the spend; in low-damage scenarios, costs dominate monetized benefits but social equity and resilience benefits remain substantial.
# - Three top assumptions, with probability ranges and sensitivity notes, plus confidence levels and data needs to improve certainty.
#
# 1) Interventions, timing, and approximate budget allocations (10-year horizon)
# Assumptions: construction/relocation cycles phased to minimize disruption and align with a single, accountable program office. 18-month election window will be used to build cross-party credibility through phased milestones and transparency.
#
# A. Nature-based and hybrid defenses (soft defenses + living shorelines + green streets + floodplain restoration)
# - What: 18 km of hybrid shorelines, wetland/mloodplain restoration where feasible, urban green infrastructure (bioswales, rain gardens, permeable pavement), and living breakwaters where practicable.
# - Timing: Phase 1 (Years 1–2): design in the highest-risk corridors, begin 2–3 defense micro-projects; Phase 2 (Years 3–6): scale to additional segments; Phase 3 ( Years 7–10): complete citywide coverage in priority zones.
# - Budget: $700M
# - Rationale: reduces wave/run-up exposure in nearshore and low-lying blocks, provides co-benefits (habitat, recreation, water quality).
#
# B. Hard infrastructure and drainage upgrades (seawalls, flood barriers, pumps, upgraded stormwater drainage)
# - What: targeted seawalls along critical economic corridors and high-value neighborhoods; upgraded pump stations; enhanced pumping/discharge capacity; floodproofing of municipal facilities and critical utilities; improvements to drainage networks to reduce urban flood peaks.
# - Timing: Phase 1 (Years 1–2): procure and begin upgrades in 2–3 high-risk zones (downtown/port area and a major neighborhood cluster); Phase 2 (Years 3–6): expand to additional segments; Phase 3 (Years 7–10): complete all prioritized zones; post-construction commissioning and testing.
# - Budget: $550M
# - Rationale: provides essential protection for critical infrastructure and economic centers with a design emphasis on resilience to higher surge.
#
# C. Targeted buyouts and voluntary relocation (incentives, relocation support, housing assistance)
# - What: voluntary buyouts, relocation assistance, replacement housing options, bridging loans, relocation counseling, and community-based housing supports; explicit policy to maximize voluntary relocations of low-income households; target to minimize involuntary displacement below 5%.
# - Timing: Phase 1 (Years 1–2): launch outreach, secure listings of candidate properties, begin first round of buyouts; Phase 2 (Years 3–6): expand to additional neighborhoods; Phase 3 (Years 7–10): complete program in remaining risk zones; ongoing wraparound services.
# - Budget: $520M
# - Rationale: directly reduces exposure and displacement risk, aligns with equity mandate; incentives and housing assistance are essential to make relocation feasible for poor households.
#
# D. Zoning, building-code changes and land-use planning (elevation, flood-proofing, construction standards)
# - What: elevate new construction and retrofit standards to a 100-year+ flood protection baseline; enforce floodproofing, setback and elevation requirements; update critical infrastructure siting and land-use plans to reduce exposure.
# - Timing: Phase 1 (Years 1–2): adopt updated codes; Phase 2 (Years 2–5): rollout enforcement in new developments and major renovations; Phase 3 (Years 6–10): ensure full citywide adoption and compliance checks.
# - Budget: $140M
# - Rationale: reduces long-term vulnerability in new development and retrofits; ensures that new investments are resilient to higher climate risks.
#
# E. Insurance subsidies and risk financing (premium subsidies, public reinsurance, catastrophe risk pooling)
# - What: subsidies to reduce insurance premiums for at-risk households; enhance city-level catastrophe risk pooling and reinsurance capacity; potential municipal catastrophe fund to bridge investment gaps.
# - Timing: Phase 1 (Years 1–2): establish policy framework; Phase 2 (Years 3–5): scale subsidies; Phase 3 (Years 6–10): sustain program with annual reviews.
# - Budget: $60M
# - Rationale: increases affordability and resilience of households, lowers displacement risk by reducing uninsurable exposure.
#
# F. Governance reforms and implementation management (institutional capacity, data systems, performance dashboards, community engagement)
# - What: new adaptation authority or augmented planning office; centralized data integration; transparent performance dashboards; formal public-engagement mechanisms (including a standing citizen oversight body).
# - Timing: Phase 1 (Year 1): establish governance structure; Phase 2 (Year 2): implement data systems; Phase 3 (Year 3–10): continuous improvement and reporting.
# - Budget: $30M
# - Rationale: ensures plan goes from concept to execution with accountability, reduces political volatility through clear metrics and citizen involvement.
#
# Total: $2.00B (across 10 years)
#
# 2) Quantified outcomes (rough, defensible numbers)
# Assumptions for context:
# - Current baseline annual flood damages (citywide) ≈ $200M per year today under existing conditions.
# - Without action, damages rise as climate risks intensify: low trajectory: +10–20% by 2036; medium: +40–60%; high: +100% (relative to today) by 2036.
# - “Annual damages avoided” reflects citywide reductions from both defenses and relocation in protected zones. Because buyouts/elimination of exposure are concentrated in high-risk areas, the plan yields large reductions where risk is highest.
#
# A. Reduction in expected annual flood damages (citywide, by 2036)
# - Low climate trajectory: post-implementation annual damages ≈ $125–$140M (vs. current $200M baseline; ~40–55% reduction in the high-risk zones and partial protections citywide).
# - Medium trajectory: ≈ $160–$180M (vs. $200M baseline; ~10–25% net reduction in exposure citywide, higher in protected zones).
# - High trajectory: ≈ $250–$260M (vs. $200M baseline; net increases in exposed areas are still offset in defended zones; high exposure mitigated more than baseline in critical cores).
#
# Note: These are citywide, “after-action” estimates that reflect a mix of zone-specific results (large reductions where buyouts/defenses are concentrated, moderate reductions elsewhere).
#
# B. Displaced or relocated people/households (voluntary vs. forced)
# - Total households relocated (voluntary): approximately 3,800–6,500 over 10 years.
# - Total people relocated (assuming ~2.8 persons/household): roughly 10,600–18,000 people.
# - Voluntary vs forced: voluntary ~3,600–6,200 households; forced relocations kept at 0–5% of total relocations (i.e., 0–325 households, ~0–900 people if averages hold).
# - Share of relocations from the bottom income quintile: target ~60–75% of relocations from the two poorest quintiles by year 5–7.
#
# C. Change in socioeconomic equity
# - Equity metric (share of flood-protection benefits and relocation benefits captured by the poorest 20%): increase from a baseline where the bottom quintile benefits minimally to a target where roughly 30–40% of total benefit captured by the bottom quintile, rising to ~50–60% by year 7–10 when combined defense benefits and buyouts are scaled.
# - Net improvement in the city’s distributional equity index (qualitative proxy: reduced exposure for poorest quintiles, improved housing stability, and access to relocation options): modest to meaningful improvements (order of magnitude: 0.15–0.25 on a 0–1 scale by decade end).
#
# 3) The three most important assumptions and sensitivity
# Assumption 1: Climate risk trajectory and damages
# - Assessed probabilities (subject to climate forecast uncertainty): Low ~20%, Medium ~50%, High ~30%.
# - Sensitivity: If high-damage trajectory is underestimated (i.e., damages grow faster or more intensely than modeled), the plan’s monetized benefits rise, improving relative NPV; if damages are lower than anticipated, the plan’s monetized benefits are smaller.
# - Data to improve confidence in 12 months: updated city hazard maps, regional climate model projections, and validated flood- and surge-inundation models, plus realized 2025–2026 flood event data.
#
# Assumption 2: Political will and governance effectiveness
# - Assessed probabilities: Robust cross‑party backing ~40–60%; gridlock or watered‑down reforms ~20–40%.
# - Sensitivity: If governance reforms stall (delayed approvals, fragmentation among council factions), the plan’s ability to execute on time and within budget declines, raising financing risk and delaying benefits.
# - Data to improve confidence in 12 months: a credible governance charter, an independent oversight body with public reporting, and a transparent project schedule with milestones and penalties for delays.
#
# Assumption 3: Uptake and effectiveness of voluntary relocation incentives
# - Assessed probabilities: Uptake of voluntary buyouts reaches target among low-income households ~40–70% over a decade, with 0–5% forced displacements.
# - Sensitivity: Lower uptake rates will preserve exposure in buyout target zones and reduce equity gains; higher-than-expected uptake is favorable but may stress housing markets and require additional supply to avoid adverse outcomes like crowding or re-segregation in receiving communities.
# - Data to improve confidence in 12 months: pilot program uptake data, preference surveys, housing market absorption rates for replacement housing, and interim displacement metrics.
#
# Confidence levels and data to improve confidence (for each major recommendation)
# - Nature-based/Hybrid defenses
#   - Confidence: Medium
#   - Data to improve: updated coastal hazard and hydrodynamic models; constructability and maintenance cost data; coastal erosion and habitat restoration performance data for the chosen sites.
# - Hard infrastructure upgrades
#   - Confidence: Medium
#   - Data to improve: detailed risk maps for critical corridors; pump capacity performance tests; cost-to-benefit for each segment under multiple surge scenarios.
# - Targeted buyouts/relocation
#   - Confidence: Medium
#   - Data to improve: baseline household income, housing stock availability in receiving areas, relocation acceptance rates, and long-term housing affordability post-relocation.
# - Zoning/building-code updates
#   - Confidence: High
#   - Data to improve: enforcement capacity metrics; number of buildings upgraded to code; compliance rates; cost implications for builders and homeowners.
# - Insurance subsidies/risk financing
#   - Confidence: Medium
#   - Data to improve: actuarial data on premiums before/after subsidies; city-level catastrophe fund performance; uptake rates among different income groups.
# - Governance reforms
#   - Confidence: High
#   - Data to improve: formal performance dashboards; independent audit results; citizen engagement metrics; timeliness of approvals.
#
# 4) Top five failure modes and concrete contingency/mitigation steps
# 1) Political backlash and gridlock (council/Council-majorities stall plan)
#    - Mitigations: establish an independent adaptation authority with transparent oversight; adopt a small, credible set of prioritized actions (pilot segments) to demonstrate early wins; set a public, time-bound decision calendar; hold regular, cross-partisan briefings; include a citizen advisory panel with equity-focused representation.
#
# 2) Over- or under-estimation of risk and misalignment of incentives (risk model misfit)
#    - Mitigations: require independent risk validation, implement adaptive management with quarterly reviews, continuously update hazard maps and models with new data; implement conservative design margins on critical assets.
#
# 3) Inadequate buyout uptake and inequitable outcomes (displacement risk and inequity)
#    - Mitigations: enhanced relocation incentives, bridging housing programs, targeted outreach in low-income neighborhoods, clear, transparent eligibility criteria, enforce a strong equity-based targeting framework; ensure receiving housing options are available and affordable.
#
# 4) Adverse land-use and development incentives (developers reoccupying risk zones)
#    - Mitigations: revise zoning to restrict new development in high-risk zones; require elevated or floodproofed designs for new construction in nearshore areas; tie insurance subsidies to compliance; implement buyout-backed redevelopment in safe zones.
#
# 5) Funding shortfalls or cost overruns (budget pressure and political backlash)
#    - Mitigations: establish contingency reserves (5–10%), phased funding with milestone-based releases, performance-based payments for contractors, public-private partnerships where appropriate, and a baseline cost-tracking and audit mechanism.
#
# 6) Environmental justice concerns and potential gentrification
#    - Mitigations: ensure outreach and program design are inclusive; targeted protections for long-term residents; integrate affordable replacement housing options and caps on displacement risks; monitor equity metrics annually.
#
# 5) 12–24 month randomized or quasi-experimental pilot (to increase voluntary relocation participation and measure political acceptability)
# - Objective: test mechanisms to increase voluntary relocation uptake among low-income households and gauge short-term political acceptability of the plan.
# - Design: randomized encouragement design (not forcing participation; households are randomly assigned to receive enhanced relocation incentives and outreach vs standard outreach).
# - Sample frame: households in the top 20% flood-prone neighborhoods with incomes at or below 60% of area median income (AMI); target N ≈ 3,000 households (1,000 per arm if 3-arm design).
# - Treatment arms:
#   - Arm 1: Enhanced incentives package (higher buyout offers, moving stipends, bridging loans, guaranteed replacement housing options, rental assistance, and more robust case management).
#   - Arm 2: Community-based outreach (trusted local organizations, community liaisons, culturally appropriate communications, flexible scheduling and in-language materials; integrated social-support services (counselors)).
#   - Arm 3: Control (standard district outreach, baseline buyout terms; conventional process).
# - Randomization approach:
#   - Randomize at the neighborhood block-group level or household level with stratification by initial income level and flood risk.
# - Primary outcomes:
#   - Outcome A: voluntary buyout uptake rate within 24 months.
#   - Outcome B: expressed willingness to relocate (survey-based) and satisfaction with relocation process (post-relocation survey).
# - Secondary outcomes:
#   - Outcome C: time-to-buyout completion; Outcome D: stabilization of housing costs post-relocation; Outcome E: perceived adequacy and fairness of the process.
# - Ethical safeguards:
#   - Informed consent for data collection, voluntary participation, no penalties for opting out; independent IRB oversight; ensure that relocation supports do not infringe on tenant rights; protect privacy and data security; ensure no coercive pressure from program staff.
# - Evaluation design considerations:
#   - Pre/post surveys; administrative data on offers/acceptances; follow-up at 6, 12, 18, and 24 months; differences-in-differences analysis across arms; budget for independent evaluation.
#
# 6) Five measurable indicators (annual) to monitor and decision thresholds
# - Indicator 1: Annual avoided damages (PV or nominal, baseline year 0 = current damages)
#   - Thresholds: if annual avoided damages lag behind target by >20% for two consecutive years, trigger a mid-course adjustment (expansion of protections or more aggressive buyout terms).
# - Indicator 2: Voluntary relocation uptake rate (annual)
#   - Thresholds: target uptake of 5,000–6,500 households over 10 years; if annual uptake <1,000 for two consecutive years, reassess incentives and outreach.
# - Indicator 3: Forced displacement rate
#   - Thresholds: target ≤5% of total displacements; if forced displacements exceed 10% in any year, pause high-risk relocation products and re-focus on voluntary options.
# - Indicator 4: Equity and beneficiary persistence
#   - Thresholds: share of relocations from bottom income quintiles to be ≥60% by year 5; if below 40%, re-target outreach and eligibility to prioritize bottom quintiles and address barriers.
# - Indicator 5: Public acceptability and trust
#   - Thresholds: annual public opinion index showing ≥60% overall support for the plan; if support below 50% for two consecutive years, implement enhanced transparency measures and broaden community engagement (citizen oversight, town halls, independent fact sheets).
#
# 7) Concise, quantitative cost-benefit estimate under two discount rates and three climate-damage trajectories
# Definitions (conservative, defensible approximations):
# - Baseline citywide annual flood damages today: approximately $200M.
# - Climate trajectories by 2036 (no-action reference):
#   - Low: damages rise to about $220–230M/year (net +10–15%);
#   - Medium: damages rise to about $260–300M/year (+30–50%);
#   - High: damages rise to about $400–420M/year (+100%+).
# - Plan’s monetized benefits (PV of avoided damages; discounted):
#   - Low trajectory (3%): PV of benefits ≈ $0.9B; PV of costs ≈ $2.0B -> Net ≈ -$1.1B
#   - Medium trajectory (3%): PV of benefits ≈ $1.6B; PV of costs ≈ $2.0B -> Net ≈ -$0.4B
#   - High trajectory (3%): PV of benefits ≈ $2.4B; PV of costs ≈ $2.0B -> Net ≈ +$0.4B
# - With 7% discount rate (lower PV for both costs and benefits):
#   - Low trajectory (7%): PV benefits ≈ $0.7B; PV costs ≈ $1.6B -> Net ≈ -$0.9B
#   - Medium trajectory (7%): PV benefits ≈ $1.2B; PV costs ≈ $1.6B -> Net ≈ -$0.4B
#   - High trajectory (7%): PV benefits ≈ $1.9B; PV costs ≈ $1.6B -> Net ≈ +$0.3B
# Interpretation:
# - Direct monetized flood-damage reductions alone suggest a negative or near-neutral net present value at 3% discount for low/medium climate trajectories, and a modest positive result only in a high-damage trajectory. At 7%, the plan becomes more favorable only in the high-damage trajectory; in low/medium trajectories the monetized direct benefits do not cover the upfront costs.
# - Important caveats and non-monetized value: social equity gains, reduced involuntary displacement, health benefits from reduced flood exposure, improved urban resilience, and avoided long-term infrastructure depreciation. If these non-market benefits are monetized (or given a high qualitative weight), the plan’s overall value proposition improves, especially under the medium-to-high climate-damage trajectories.
# - Bottom line: the plan’s monetized direct-damages benefits alone do not guarantee positive NPV under all reasonable climate trajectories and discount rates; however, the plan yields important equity, resilience, and health benefits that justify the investment, particularly if non-market benefits are valued in additional analysis and if higher-damage scenarios materialize.
#
# 8) For each major recommendation, level of confidence and the single data piece that would most increase confidence within 12 months
# - Nature-based and hybrid defenses
#   - Confidence: Medium
#   - Data to increase confidence: cost-effective performance data from pilot segments; long-term maintenance costs; hydrodynamic modeling for proposed living shorelines; performance data from comparable cities.
# - Hard infrastructure upgrades
#   - Confidence: Medium
#   - Data to increase confidence: site-specific design flood levels, pump station performance tests, reliability data, and maintenance cost estimates.
# - Targeted buyouts/relocation
#   - Confidence: Medium
#   - Data to increase confidence: uptake rates, replacement housing availability and affordability, tenant rights outcomes, and relocation completion timelines.
# - Zoning/building-code updates
#   - Confidence: High
#   - Data to increase confidence: compliance rates post-implementation, enforcement costs, permits issued for elevated constructions, and case studies from other jurisdictions.
# - Insurance subsidies/risk financing
#   - Confidence: Medium
#   - Data to increase confidence: premium data before/after subsidies, take-up rates by income groups, and city-level catastrophe fund performance.
# - Governance reforms
#   - Confidence: High
#   - Data to increase confidence: independent audit results, dashboard accuracy and timeliness, citizen engagement metrics.
#
# 9) Trade-offs and explicit design choices
# - Trade-off: Protecting economic centers vs. minimizing displacement
#   - Choice: Prioritize protection for critical economic corridors and municipal facilities, but pair with a robust voluntary relocation program for the most exposed, low-income households to minimize involuntary displacement. This reduces fatal risk to the economy while achieving equity objectives.
# - Trade-off: Upfront costs vs. long-term resilience
#   - Choice: Accept front-loaded capital investment in order to reduce long-term annual damages and emergency response costs; use phased funding to reduce political risk and demonstrate early wins.
# - Trade-off: Hard infrastructure vs. nature-based defenses
#   - Choice: A mix that prioritizes hybrid approaches to reduce costs and maximize co-benefits (habitat, recreation, water quality) while still ensuring protection of key assets with select hard infrastructure segments.
# - Trade-off: Public support vs. rapid implementation
#   - Choice: Build cross-party buy-in through transparent governance, targeted pilots (pilot 12–24 months), and clear communication to avoid derailment by short-term politics.
# - Trade-off: Equity focus vs. political feasibility
#   - Choice: Maintain explicit equity commitments (benefitting the poorest households in relocation and protections) even if it complicates implementation timelines; this preserves mandate integrity and reduces long-term social risk.
#
# 10) 12–24 month pilot specifics (described above)
# - Design: randomized encouragement design evaluating enhanced relocation incentives and enhanced outreach vs standard outreach.
# - Sample: ~3,000 low-income households in high-risk zones (1,000 per arm in a 3-arm design).
# - Outcomes: uptake of voluntary buyouts; willingness to relocate; satisfaction with relocation process; time to completion; equity measures in uptake.
# - Safeguards: informed consent; not coercive; privacy protections; independent evaluation; IRB review; ensure replacement housing supply.
#
# 11) Five actionable indicators to monitor annually (thresholds used to accelerate/pause/reverse)
# - Indicator 1: Annual avoided damages (PV or nominal)
#   - Threshold: if annual avoided damages lag target by >20% for two consecutive years, reallocate resources or adjust incentives.
# - Indicator 2: Voluntary relocation uptake rate
#   - Threshold: annual uptake <1,000 households for two consecutive years triggers plan adjustment and targeted outreach.
# - Indicator 3: Forced displacement rate
#   - Threshold: share of forced relocations >10% of total relocations triggers pause on aggressive buyout pacing and re-target strategies.
# - Indicator 4: Equity attainment
#   - Threshold: share of relocations from bottom quintile <40% by year 5 triggers targeted outreach and policy amendments to improve equity.
# - Indicator 5: Public acceptability and legitimacy
#   - Threshold: citywide support below 50% for two consecutive annual surveys triggers enhanced communications and governance reforms.
#
# 12) Final notes on implementation and confidence
# - The plan is deliberately explicit about trade-offs and is designed to be implemented in a politically plausible, phased manner within the 18-month window and within a $2.0B cap.
# - The proposed pilot provides a concrete means to learn what incentives work in practice to maximize voluntary relocations among low-income households and to gauge short-term political acceptability before scaling to full implementation.
# - The plan assumes a robust, independent governance structure and transparent reporting to build trust across a divided council and the community.
# - If non-market benefits and health co-benefits are monetized in a broader economic analysis (beyond the monetized damages), the plan’s overall value proposition strengthens in all climate trajectories.
#
# If you’d like, I can tailor the numbers to your city’s actual current annual flood damages, hazard maps, housing stock, and existing insurance coverage. I can also prepare a one-page executive summary and a draft governance charter for the adaptation authority to help accelerate a council-ready package.
#
# # Response from competitor 2
#
# # 10-Year Coastal Adaptation Plan: Priority-Based Implementation Strategy
#
# ## I. INTERVENTION PORTFOLIO & BUDGET ALLOCATION
#
# ### Phase 1: Immediate Actions (Years 0-3) - $720M
#
# **1. Hybrid Defense for Economic Core ($380M)**
# - **Intervention**: Elevated seawall + tidal marsh restoration along 8 km waterfront downtown/port district
# - **Timing**: Design Y0-1, construction Y1-3
# - **Rationale**: Protects 40% of tax base, employs nature-based buffer where feasible
# - **Expected outcome**: Reduces expected annual damages (EAD) from $180M to $45M in protected zone (~75% reduction for 35,000 jobs, 8,000 residents)
#
# **2. Voluntary Buyout Program - Priority Zones ($200M)**
# - **Intervention**: Purchase 800 properties in highest-risk areas (<2m elevation, repetitive loss history)
# - **Timing**: Rolling enrollment Y0-3, conversion to wetlands Y2-4
# - **Payment structure**: 125% pre-flood fair market value + $50K relocation subsidy + right of first refusal for affordable housing in safer zones
# - **Expected outcome**:
#   - 800 households relocated (est. 2,400 people)
#   - 70% voluntary participation rate (target low-income: 340 households)
#   - Reduces citywide EAD by $28M
#   - Distributional impact: +15% net wealth transfer to participating low-income households vs. status quo erosion
#
# **3. Emergency Building Code Reform ($40M implementation)**
# - **Intervention**: Mandate first-floor elevation +1.2m for new construction/substantial renovation in flood zones; create fast-track permitting + $30M subsidy pool for low-income compliance
# - **Timing**: Ordinance Y0, enforcement Y1+
# - **Expected outcome**: 450 retrofits Y1-10, reducing structure damage 60% per building
#
# **4. Flood Insurance Transition Program ($100M reserve)**
# - **Intervention**: Municipal catastrophe bond + means-tested premium subsidies to prevent NFIP policy lapses
# - **Timing**: Y0-2 setup
# - **Expected outcome**: Maintain 85% insurance coverage (down from 72% without intervention) among bottom income quintile
#
# ### Phase 2: Adaptive Measures (Years 4-7) - $880M
#
# **5. Living Shoreline Expansion ($320M)**
# - **Intervention**: Restore 15 km oyster reefs, salt marshes, and dune systems along eastern residential coast
# - **Timing**: Staged construction Y4-7
# - **Expected outcome**: Attenuate storm surge 20-35 cm, reduce EAD by $52M in adjacent neighborhoods (18,000 residents, 60% below median income)
#
# **6. Strategic Elevation of Critical Infrastructure ($280M)**
# - **Intervention**: Raise 3 sewage treatment plants, 2 power substations, hospital access roads
# - **Timing**: Y4-6
# - **Expected outcome**: Prevent $420M in cascade failures during 100-year event
#
# **7. Affordable Housing Development in Low-Risk Zones ($200M)**
# - **Intervention**: Public-private partnership to build 1,200 units at 60% AMI eligibility on elevated municipal land
# - **Timing**: Y5-8 construction
# - **Expected outcome**: House 600 buyout participants + 600 existing wait-list families, net zero involuntary displacement
#
# **8. Expanded Buyouts - Phase 2 ($80M)**
# - **Intervention**: Additional 250 properties in moderate-risk areas
# - **Timing**: Y5-7
# - **Expected outcome**: 750 people relocated, $9M EAD reduction
#
# ### Phase 3: Resilience Lock-In (Years 8-10) - $400M
#
# **9. Adaptive Traffic & Utility Networks ($220M)**
# - **Intervention**: Reroute 6 arterial roads, elevate water mains, create redundant power loops
# - **Expected outcome**: Reduce post-storm recovery time 40% (economic continuity benefit)
#
# **10. Community Resilience Hubs ($80M)**
# - **Intervention**: Retrofit 12 schools
#
# # Response from competitor 3
#
# Mayor, Members of the City Council,
#
# This memo outlines a prioritized 10-year adaptation plan for our mid-sized coastal city, designed to address the projected 0.6m average sea-level rise and doubling of 100-year storm surge intensity by 2050, within your $2.0 billion capital budget. My recommendations are based on the core principles of minimizing involuntary displacement, addressing socioeconomic inequality, and balancing long-term resilience with the immediate political context.
#
# ### **1. Prioritized 10-Year Adaptation Plan (Budget: $2.0 Billion)**
#
# Our strategy is a "layered defense" approach, blending protective infrastructure, managed retreat, and city-wide resilience building. It's phased to allow for learning, adaptation, and political navigation.
#
# **Phase 1 (Years 1-3: Immediate Action & Foundation - ~$550 Million)**
# *   **Goal:** Secure critical infrastructure, initiate voluntary programs, and establish regulatory and governance frameworks. Focus on politically feasible, visible projects for early wins.
# *   **Interventions:**
#     1.  **Targeted Soft/Nature-Based Defenses (Primary Priority):** Mangrove restoration, dune creation, and living shorelines in 3-5 high-vulnerability coastal segments. Focus on areas with existing ecological potential or where they can augment existing grey infrastructure.
#         *   *Budget:* $150M.
#         *   *Confidence: High.* *Data Needed:* Comprehensive habitat mapping and high-resolution hydrodynamic modeling to optimize placement and design for maximum wave attenuation.
#     2.  **Critical Infrastructure Hardening (Strategic):** Flood-proofing and elevating key municipal services (e.g., wastewater treatment plants, main hospitals, emergency services hubs) and vital transportation arteries serving economic centers.
#         *   *Budget:* $200M.
#         *   *Confidence: High.* *Data Needed:* Detailed vulnerability assessments for specific critical infrastructure assets under 2050 climate scenarios, including cascading failure analysis.
#     3.  **Voluntary Relocation/Buyout Program - Pilot Phase (Targeted, Equity-Focused):** Launch a pilot program (detailed in Section 5) for 500-700 households in 1-2 of the highest-risk, predominantly low-income neighborhoods. Offer above-market value buyouts (120-130% of pre-flood risk value) and comprehensive assistance for relocation/rehousing in safer, designated "receiving zones."
#         *   *Budget:* $100M.
#         *   *Confidence: Medium.* *Data Needed:* Detailed property valuation data, demographic mapping of high-risk areas, and survey data on relocation preferences/barriers for low-income households.
#     4.  **Zoning & Building Code Updates (Initial Draft & Public Consultation):** Develop new zoning ordinances to restrict new construction in the 50-year floodplain and updated building codes requiring elevated foundations and flood-resistant materials in the 100-year floodplain. Identify and zone initial "receiving zones" for relocated populations.
#         *   *Budget:* $30M (staffing, consultants, extensive public engagement).
#         *   *Confidence: High.* *Data Needed:* Legal review of existing zoning authority and potential eminent domain implications for receiving zones.
#     5.  **Governance Reform - Climate Resilience Office & Stakeholder Task Force:** Establish a dedicated Climate Resilience Office to coordinate efforts and a multi-stakeholder task force (community reps, businesses, environmental groups) to provide ongoing advice and build consensus.
#         *   *Budget:* $20M (initial staffing, office setup).
#         *   *Confidence: High.* *Data Needed:* Best practices from other cities on effective multi-stakeholder governance models for climate adaptation.
#     6.  **Data & Modeling Refinement:** Invest in high-resolution flood modeling, socioeconomic vulnerability mapping, and ecosystem service valuation to inform future interventions.
#         *   *Budget:* $30M.
#         *   *Confidence: High.* *Data Needed:* Existing LiDAR data and bathymetry data for the entire coastal zone.
#     7.  **Public Awareness & Education Campaign:** Launch a city-wide campaign to inform residents about climate risks, the plan, and available resources, fostering community resilience.
#         *   *Budget:* $20M.
#         *   *Confidence: High.* *Data Needed:* Public perception surveys on climate change risks and preferred adaptation strategies.
#
# **Phase 2 (Years 4-7: Scaling Up & Integrated Solutions - ~$850 Million)**
# *   **Goal:** Expand successful pilot programs, implement regulatory changes, and invest in larger-scale, strategically critical infrastructure.
# *   **Interventions:**
#     1.  **Expanded Voluntary Relocation/Buyout Program:** Scale up the program, incorporating lessons learned from the pilot. Continue offering strong incentives for low-income households and expand to other high-risk, non-critical areas. Develop "resilience hubs" in receiving zones with enhanced public services (schools, clinics, community centers).
#         *   *Budget:* $350M.
#         *   *Confidence: Medium.* *Data Needed:* Longitudinal data from the pilot program on participant satisfaction, re-housing success, and community integration.
#     2.  **Major Hard Infrastructure Projects (Strategic Seawalls/Levees):** Construct targeted seawalls or flood barriers to protect specific, high-value economic districts or large dense populations that cannot reasonably be relocated and have clear cost-benefit justification. These will be integrated with nature-based features where possible.
#         *   *Budget:* $300M.
#         *   *Confidence: Medium.* *Data Needed:* Detailed engineering designs and cost-benefit analysis for specific hard infrastructure proposals, including long-term maintenance costs and residual risk assessments.
#     3.  **City-Wide Building Code & Zoning Enforcement:** Implement and rigorously enforce the new zoning ordinances and building codes. Provide subsidies and financial incentives for existing homeowners (especially low-income) to retrofit properties to meet new standards.
#         *   *Budget:* $100M (for subsidies and enforcement).
#         *   *Confidence: High.* *Data Needed:* Baseline data on current building code compliance rates, particularly in vulnerable areas.
#     4.  **Flood-Resilient Green Infrastructure:** Expand green infrastructure projects (e.g., permeable surfaces, bioswales, urban wetlands) throughout the city to manage stormwater, reduce urban heat island effect, and provide flood protection.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Detailed hydrologic modeling to identify optimal locations for green infrastructure to maximize stormwater retention and flood reduction benefits.
#
# **Phase 3 (Years 8-10: Long-Term Resilience & Adaptive Management - ~$600 Million)**
# *   **Goal:** Integrate adaptation into all city planning, continue strategic protection, and prepare for future challenges.
# *   **Interventions:**
#     1.  **Continued Voluntary Relocation/Buyout & Redevelopment:** Sustain the program, strategically acquiring additional high-risk properties and transforming vacated land into nature-based defenses, open space, or buffer zones.
#         *   *Budget:* $200M.
#         *   *Confidence: Medium.* *Data Needed:* Public perception and economic impact studies on the long-term transformation of vacated land and receiving zones.
#     2.  **Regional Collaboration & Early Warning Systems:** Invest in regional partnerships for adaptation strategies (e.g., shared flood models, emergency response protocols) and develop advanced local early warning systems for storm surge and flooding.
#         *   *Budget:* $50M.
#         *   *Confidence: High.* *Data Needed:* Inventory of existing regional agreements and emergency communication protocols.
#     3.  **Adaptive Management Fund:** Establish a dedicated fund for unforeseen adaptation needs, research and development of new technologies, and to scale up or pivot interventions based on monitoring data and evolving climate projections.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Detailed analysis of historical disaster relief spending and potential future funding gaps.
#     4.  **Insurance/Subsidy Program Development:** Collaborate with state and federal partners to develop a specialized flood insurance subsidy program for low-to-moderate income households in remaining high-risk zones who cannot or choose not to relocate, ensuring affordability while incentivizing risk reduction.
#         *   *Budget:* $50M (initial seed funding/subsidies for low-income).
#         *   *Confidence: Medium.* *Data Needed:* Actuarial analysis of current flood insurance uptake and claims among low-income households, and assessment of federal/state appetite for partnership.
#     5.  **Long-term Monitoring & Research:** Continuously monitor sea-level rise, storm intensity, and the effectiveness of all interventions. Fund local research into climate impacts and adaptation solutions.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Baseline ecological data for nature-based solutions and socio-economic data for relocated communities.
#     6.  **Climate-Resilient Infrastructure Upgrades:** Continue investing in upgrades to grey infrastructure (e.g., drainage systems, power grids) to make them more resilient to climate impacts, guided by lessons learned.
#         *   *Budget:* $100M.
#         *   *Confidence: High.* *Data Needed:* Infrastructure condition assessments across all municipal systems.
#
# ### **2. Quantified Expected Outcomes (by 2033 - end of 10-year plan, impacting 2050 targets)**
#
# *   **Reduction in Expected Annual Flood Damages (by 2050):**
#     *   *Baseline (without plan):* Projected $200-300 million annually by 2050.
#     *   *With Plan:* **~60-70% reduction**, bringing annual damages down to **$60-120 million by 2050.**
# *   **Number of People/Households Displaced or Relocated (by 2033):**
#     *   *Voluntary Relocation/Buyouts:* **2,500 - 4,000 households** (approx. 7,500 - 12,000 people) voluntarily relocated through incentivized programs.
#     *   *Forced Displacement:* **Minimized to effectively zero**, fulfilling the legal mandate.
# *   **Change in Socioeconomic Equity (Distributional impact on poorest 20%):**
#     *   **Significant positive impact.** Poorest 20% in high-risk zones will be offered above-market value buyouts and comprehensive relocation support.
#     *   **Quantitative Proxy:** Aim for a **10-15% reduction in the number of households below the poverty line living in the 100-year floodplain** by 2033, and a **25-30% reduction in their expected uninsured flood losses.**
#
# ### **3. Three Most Important Assumptions & Sensitivity**
#
# 1.  **Political Will & Bipartisan Cooperation Persist:**
#     *   *Details:* The $2.0B budget is sustained, and the politically divided council cooperates on necessary legislative changes (zoning, building codes). The upcoming election does not derail the plan.
#     *   *Sensitivity:* **High.** *Violation:* Gridlock or funding cuts (20-40% probability) would cause delays, cost overruns, incomplete projects, and potential failure to meet adaptation goals.
# 2.  **Sufficient Voluntary Participation in Buyout/Relocation:**
#     *   *Details:* Incentives (above-market value, assistance) are sufficient to encourage a critical mass of residents, especially low-income households, to voluntarily participate.
#     *   *Sensitivity:* **Medium-High.** *Violation:* Low participation rates (15-30% probability) would undermine equity goals and the non-displacement mandate, leading to continued exposure and higher future damage costs.
# 3.  **Future Climate Projections are Broadly Accurate:**
#     *   *Details:* The 0.6m SLR and 2x 100-year storm surge by 2050 projections are sufficient for planning.
#     *   *Sensitivity:* **Medium.** *Violation (Worse Case):* Impacts significantly accelerate beyond projections (10-20% probability of underestimation) rendering interventions insufficient, requiring costly emergency upgrades. *Violation (Better Case):* Impacts are less severe (5-10% probability of overestimation) leading to over-investment, though with residual co-benefits.
#
# ### **4. Top Five Failure Modes & Contingency/Mitigation**
#
# 1.  **Failure Mode: Political Backlash & Loss of Public Support.**
#     *   *Contingency:* Implement extensive, ongoing public outreach and education, involve affected communities in co-design, start with successful pilots, and ensure legal robustness of policies.
# 2.  **Failure Mode: Low Voluntary Participation in Buyout/Relocation.**
#     *   *Contingency:* Enhance incentives (increase buyout offers to 150%, expand assistance), empower community-led relocation efforts, invest heavily in attractive "resilience hubs" in receiving zones, and continuously refine strategies based on pilot feedback.
# 3.  **Failure Mode: Cost Overruns & Budget Exhaustion.**
#     *   *Contingency:* Strict project management, rigorous cost estimates, contingency planning, value engineering, active pursuit of state/federal/private grants, and judicious use of the Adaptive Management Fund.
# 4.  **Failure Mode: Maladaptation (Interventions Worsen Problems).**
#     *   *Contingency:* Integrated planning with advanced modeling, thorough Environmental Impact Assessments, robust monitoring and evaluation systems to detect issues early, and active regional collaboration to avoid shifting risks.
# 5.  **Failure Mode: Adverse Incentives (e.g., "Moral Hazard").**
#     *   *Contingency:* Link flood insurance subsidies to mandatory mitigation measures, use risk-based pricing (with affordability measures) to communicate true risk, maintain strict zoning/building codes, and conduct ongoing public education on individual preparedness.
#
# ### **5. Feasible 12–24 Month Randomized or Quasi-Experimental Pilot**
#
# **Objectives:** (a) Increase voluntary participation in relocation/buyout among low-income households, and (b) measure short-term political acceptability.
#
# **Intervention Target:** One of the highest-risk, predominantly low-income neighborhoods (approx. 500-700 households) designated as the "Pilot Zone."
#
# **Treatment Arms (for Voluntary Participation within Pilot Zone):**
# *   **Control Group (N=~200-250 households):** Standard city communications on flood risk; "fair market value" buyout offer (pre-flood risk appraisal).
# ...
# | **2025‑2028** | **(E) Insurance/Subsidy & Risk‑Education Program** | • Tiered premium subsidies for low‑income (≤ 150 % FPL) – 30 % reduction on NFIP rates. <br>• Community outreach, flood‑risk dashboards, and “Resilience Savings Accounts” (matched grants for home‑hardening). | $100 M | 5 % |
# | **2025‑2027** | **(F) Governance & Institutional Reforms** | • Create a Climate‑Resilience Office (CRO) with authority to coordinate all interventions, monitor performance, and manage the $250 M contingency fund. | $50 M | 2.5 % |
# | **2025‑2026** | **(G) Contingency/Reserve** | • Unspent funds, cost overruns, emergency repairs. | $250 M | 12.5 % |
# | **TOTAL** | | | **$2.0 B** | **100 %** |
#
# *All spending is front‑loaded (≈ 80 % in the first five years) to lock‑in physical protection before the 2030‑mid‑decade storm intensification peak.*
#
# ---
#
# ## 2.  Quantified Expected Outcomes (10‑yr horizon)
#
# | Metric | Baseline (2025) | Projected 2035 (with plan) | Reduction / Improvement | Comments |
# |--------|----------------|----------------------------|--------------------------|----------|
# | **Annual expected flood damage** (direct property & infrastructure) | $300 M (2025) – rising 4 %/yr without action → $440 M by 2035 | $150 M average (2025‑2035) | **≈ 45 % cut** (≈ $135 M/yr avoided) | Savings driven by seawall + nature‑based attenuation (≈ 30 %); buy‑outs eliminate highest‑risk structures (≈ 15 %). |
# | **Households displaced (forced)** | 5 % of at‑risk households (~2 500) would be forced by 2035 under business‑as‑usual | < 200 (≈ 0.2 %) | **≥ 92 % reduction** | All relocation is voluntary; emergency‑evacuation plans limit forced moves. |
# | **Households voluntarily relocated (buy‑out)** | 0 | 2 000 (≈ 5 % of at‑risk) | — | 60 % of these are low‑income → 1 200 poor households. |
# | **Low‑income (bottom 20 %) risk exposure** | 30 % of this group lives in 1‑in‑5 most flood‑prone parcels | 12 % (after buy‑outs + elevation incentives) | **60 % relative risk drop** | Measured as probability of flood depth > 0.5 m per year. |
# | **Flood‑insurance coverage (low‑income)** | 45 % (2025) | 85 % (2028) | +40 ppt | Subsidy + education drives uptake. |
# | **Economic activity protected** | $12 B of taxable commercial/industrial floor space in core district | 95 % retained (seawall protects) | – | Trade‑off: heavy investment in core vs. peripheral neighborhoods. |
#
# ---
#
# ## 3.  Three Core Assumptions & Sensitivity
#
# | # | Assumption | Reasonable Range (probability) | Sensitivity |
# |---|------------|--------------------------------|-------------|
# | **A** | **SLR reaches 0.6 m by 2050** (median IPCC AR6 RCP4.5) | 0.6 m ± 0.1 m (≈ 70 % chance) | *If SLR is > 0.8 m*, seawall freeboard must be increased → extra $150‑200 M. *If SLR is < 0.4 m*, we could defer part of the hard barrier (cost saving ≈ $100 M). |
# | **B** | **100‑yr storm surge intensity doubles** (wind‑speed & surge height) | 2× ± 30 % (≈ 55 % chance) | *If surge increase is only 1.5×*, the hybrid barrier can be built to lower height, saving ≈ $80 M. *If surge spikes to 2.5×*, we would need additional overtopping protection (≈ $120 M). |
# | **C** | **Low‑income households will accept voluntary buy‑outs when offered ≥ 80 % of market value + relocation grant** | Acceptance 70‑85 % (≈ 75 % chance) | *If acceptance falls below 55 %*, we must increase the grant or shift to more aggressive zoning (cost ≈ $50 M). *If acceptance exceeds 90 %*, we could re‑allocate excess funds to nature‑based projects. |
#
# Overall plan success is **medium‑high** (≈ 70 % probability of achieving ≥ 40 % damage reduction and ≤ 200 forced displacements) given current scientific confidence and community‑engagement pilots (see §5).
#
# ---
#
# ## 4.  Top‑5 Failure Modes & Mitigation
#
# | # | Failure Mode | Likely Consequence | Contingency / Mitigation |
# |---|--------------|-------------------|--------------------------|
# | **1** | **Political backlash over “big‑seawall” cost** (election 2027) | Funding freeze, re‑allocation to other priorities | • Phase the barrier (Phase I: 4 km protecting the most critical assets) with clear cost‑benefit communication; <br>• Establish a “Resilience Bond” financed through a modest (0.1 %) property tax dedicated to the project; <br>• Early bipartisan outreach using local business coalition data on avoided losses. |
# | **2** | **Buy‑out program perceived as “selling out” low‑income neighborhoods** | Low participation, protests, legal challenges | • Co‑design the program with community NGOs; <br>• Offer “green‑relocation” grants for moving to affordable, pre‑built resilient housing; <br>• Publicly publish transparent cost‑benefit and equity impact analyses. |
# | **3** | **Gentrification after protection of downtown** (property values surge) | Displacement of renters & small businesses | • Pair the seawall with inclusionary‑housing ordinances that reserve 20 % of new units for households ≤ 150 % FPL; <br>• Use a “Community Land Trust” to hold key parcels for affordable use. |
# | **4** | **Construction delays / cost overruns (seawall, wetlands)** | Budget overspend, missed 2030 target | • Fixed‑price EPC contracts with performance penalties; <br>• Independent “Resilience Oversight Committee” with quarterly audits; <br>• Maintain $250 M contingency reserve (see Table 1). |
# | **5** | **Insurance/subsidy fraud or moral hazard** | Uncontrolled premium losses, reduced fiscal sustainability | • Link subsidies to verified elevation/retrofit standards; <br>• Require annual flood‑risk re‑assessment for continued eligibility; <br>• Use GIS‑based fraud detection analytics. |
#
# ---
#
# ## 5.  12‑24‑Month Pilot to Boost Low‑Income Relocation & Test Political Acceptability
#
# | Element | Design |
# |---------|--------|
# | **Sample frame** | 1 200 low‑income (≤ 150 % FPL) households in the top 30 % flood‑risk parcels (identified via high‑resolution LiDAR flood maps). |
# | **Randomisation** (three arms, 400 households each) | 1. **Cash‑Incentive Arm** – 85 % market‑value buy‑out + $5 k relocation grant (baseline offer). <br>2. **Counselling‑Plus‑Design Arm** – Same cash offer + a dedicated case‑worker, a “design‑your‑new‑home” workshop, and a guaranteed spot in a new affordable‑resilient‑housing complex. <br>3. **Control Arm** – Standard city outreach (information brochure, no additional services). |
# | **Primary outcomes (12‑month horizon)** | • % of households signing a buy‑out agreement (target > 70 % in Arm 2, > 55 % in Arm 1, < 30 % in Control). <br>• Change in “plan acceptability” score (1‑5 Likert) measured via door‑to‑door surveys across the whole pilot area. |
# | **Secondary outcomes** | • Median time from offer to contract signing; <br>• Reported perceived fairness; <br>• Uptake of flood‑insurance among remaining at‑risk households. |
# | **Ethical safeguards** | • Informed consent with clear explanation that participation is voluntary and will not affect eligibility for the standard city program. <br>• Independent Institutional Review Board (IRB) oversight. <br>• Data anonymisation; opt‑out option for any household at any stage. |
# | **Timeline** | • **Month 1‑3** – GIS risk mapping & household recruitment. <br>• **Month 4‑6** – Randomisation & baseline survey. <br>• **Month 7‑18** – Offer rollout, counselling, monitoring. <br>• **Month 19‑24** – Final survey, analysis, policy brief. |
#
# *Result:* The pilot will quantify the “price‑elasticity” of low‑income buy‑out acceptance and provide a rapid gauge of political support (acceptability score) before the 2027 council election.
#
# ---
#
# ## 6.  Five Annual Monitoring Indicators (with Decision Thresholds)
#
# | Indicator | Target (2025‑2035) | Threshold for Action |
# |-----------|-------------------|-----------------------|
# | **1. Annual Flood‑Damage Expenditure** (city‑reported, $M) | ≤ $150 M (average) | > $180 M → Review/strengthen physical defenses (add height, expand nature‑based area). |
# | **2. Low‑Income Flood‑Insurance Coverage** (% of eligible households) | ≥ 85 % | < 70 % → Increase subsidy or expand outreach budget by 20 %. |
# | **3. Voluntary Buy‑Outs Completed** (units/yr) | 200 ± 30 | < 150 yr → Boost cash incentive or expand counselling pilot. |
# | **4. Equity Risk‑Reduction Ratio** (risk reduction for poorest 20 % ÷ city‑wide risk reduction) | ≥ 1.0 (i.e., poorest benefit at least as much) | < 0.8 → Re‑allocate funds to targeted retrofits or expand affordable‑housing set‑aside. |
# | **5. Council/Mayor Public‑Support Index** (average score of city‑wide poll, 1‑5) | ≥ 3.5 (≥ 70 % “support”) | < 3.0 → Launch city‑wide communication campaign; consider adjusting financing mechanism. |
#
# Indicators are compiled by the **Climate‑Resilience Office** and presented at the quarterly City Council “Resilience Review”.
#
# ---
#
# ## 7.  Cost‑Benefit Estimate (NPV, 10 yr)
#
# ### Assumptions
# * **Discount rates**: 3 % (social planner) vs. 7 % (municipal finance).
# * **Damage trajectories** (baseline without adaptation):
#   * **Low** – 1 %/yr increase (minimal storm intensification).
#   * **Medium** – 3 %/yr (current IPCC median).
#   * **High** – 6 %/yr (upper‑range storm surge).
# * **Adaptation effect** – 45 % reduction in damages (flat over the horizon).
#
# | Scenario | Discount % | Present Value of Damages (no action) | PV of Damages **with plan** | PV of Adaptation Cost* | **Net Benefit (NPV)** |
# |----------|-----------|--------------------------------------|----------------------------|------------------------|----------------------|
# | Low | 3 % | $3.2 B | $1.8 B | $1.5 B | **+$0.0 B** |
# | Low | 7 % | $2.8 B | $1.6 B | $1.5 B | **+$0.1 B** |
# | Medium | 3 % | $4.9 B | $2.7 B | $1.5 B | **+$0.7 B** |
# | Medium | 7 % | $4.2 B | $2.3 B | $1.5 B | **+$0.3 B** |
# | High | 3 % | $7.9 B | $4.4 B | $1.5
#
# # Response from competitor 6
#
# **Prioritized 10-Year Adaptation Plan**
#
# With a $2.0 billion budget, I propose the following interventions:
#
# 1. **Seawall and Dunes System** (2.5B, $1.25B, 2024-2029):
# 	* Construct a 5 km seawall and build a 3 km long dunes system to protect the city center.
# 	* Expected reduction in annual flood damages: $120 million (20% decrease).
# 	* Number of displaced/households relocated: 10,000 (20% decrease).
# 	* Change in socioeconomic equity: Reduction in flood-related economic hardship among the poorest 20%.
# 2. **Smart Grid and Flood-Proofing Zoning** (400M, $200M, 2024-2028):
# 	* Upgrade the city's electrical grid to withstand flooding and install smart sensors to monitor storm surges.
# 	* Implement zoning regulations that require new construction to be built above grade or use flood-proof materials.
# 3. **Relocation/ Buyout Program** (300M, $150M, 2024-2029):
# 	* Establish a voluntary relocation program for low-income households in high-risk flood areas.
# 	* Offer buyouts or relocation packages to encourage voluntary participation.
# 	* Expected increase in voluntary participation: 40% ( increase in program enrollment).
# 4. **Insurance/Subbidy Programs** (400M, $200M, 2024-2028):
# 	* Implement a city-funded insurance program to cover flood-related losses.
# 	* Offer subsidies to households in high-risk flood areas to help mitigate financial burden.
# 5. **Governance Reforms** (200M, $100M, 2025-2029):
# 	* Implement a participatory budgeting process to ensure inclusive decision-making.
# 	* Establish a flood resiliency trust fund to prioritize adaptation investments.
#
# **Assumptions and Sensitivity**
#
# 1. **Sea-Level Rise and Storm Surge Intensity**: High sensitivity (50% impact on plan's success, 1:1 probability range). Assuming 0.6 m sea-level rise and doubling of 100-year storm surge intensity is a reasonable assumption based on current IPCC projections.
# 2. **Economic Growth and Inflation**: Medium sensitivity (30% impact on plan's success, 2:1 probability range). Assuming a 2% annual economic growth rate and moderate inflation (1.5%) is a conservative estimate based on historical data.
# 3. **Citizen Engagement and Participation**: Medium sensitivity (30% impact on plan's success, 2:1 probability range). Assuming high levels of citizen engagement and participation in the adaptation process is crucial for successful implementation.
#
# **Failure Modes and Contingency Planning**
#
# 1. **Political Backlash**: Establish a stakeholder advisory committee to ensure inclusive decision-making.
# 2. **Adverse Incentives**: Implement a revenue neutral, carbon-fund-based financing mechanism to reduce the burden on taxpayers.
# 3. **Insufficient Public Engagement**: Establish community outreach programs to ensure informed decision-making by all stakeholders.
# 4. **Inadequate Funding**: Prioritize interventions with the greatest expected outcomes and implement phase-in financing plans.
# 5. **Low-Intensity Storms**: Implement adaptive management plans to address unexpected storm intensity.
#
# **Pilot Study**
#
# Title: "Flood-Resilient Neighborhoods"
#
# * Sample Frame: 1,500 low-income households in high-risk flood areas.
# * Treatment Arms:
# 	+ Group A: Standard relocation/buyout program.
# 	+ Group B: Enhanced program with community engagement and education components.
# 	+ Group C: Control group with no additional program components.
# * Primary Outcome: Increase in voluntary participation in the relocation/buyout program among low-income households.
# * Ethical Safeguards: Randomized controlled trial with informed consent and anonymized data.
#
# **Performance Monitoring**
#
# 1. Annual Flood Risk Assessment.
# 2. Displacement/Relocation Program Metrics: Enrollment rates, retention rates, and program effectiveness.
# 3. Economic Benefit Categorization: Reduction in flood-related losses, increase in economic productivity, and reduction in poverty rates.
# 4. Social Equity Metrics: Distribution of benefits, reduction in flood-related hardship among vulnerable populations.
# 5. Stakeholder Engagement Indices: Citizen participation rates, stakeholder satisfaction, and community engagement quality.
#
# **Cost-Benefit Analysis**
#
# Scenario 1 (3% discount rate): -$1.3 billion (benefit: - $1.1 billion displacement cost reduction, - $150 million increased economic costs; - $50 million loss of avoided damages).
#
# Scenario 2 (7% discount rate): -2.1 billion (benefit: - $1.6 billion displacement cost reduction, - $200 million increased economic costs; - $80 million loss of avoided damages).
#
# Scenario 3 (Low Climate Damage Trajectory): +$1.5 billion (benefit: +$1.2 billion displacement cost reduction, + $100 million increased economic costs; -$200 million loss of avoided damages).
#
# Scenario 4 (Medium Climate Damage Trajectory): +$2.2 billion (benefit: +$1.8 billion displacement cost reduction, + $150 million increased economic costs; -$300 million loss of avoided damages).
#
# Scenario 5 (High Climate Damage Trajectory): +$3.2 billion (benefit: +$2.6 billion displacement cost reduction, + $200 million increased economic costs; -$400 million loss of avoided damages).
#
# **Confidence Levels**
#
# 1. Seawall and Dunes System: High (90%), 3D lidar data collection within 12 months to increase confidence.
# 2. Relocation/Buyout Program: High (90%), Establish a stakeholder advisory committee to ensure inclusive decision-making.
# 3. Smart Grid and Flood-Proofing Zoning: Medium (60%), Monitor performance and make adjustments as necessary.
# 4. Insurance/Subsidy Programs: Medium (60%), Develop comprehensive actuarial models to ensure risk-sharing mechanisms are in place.
# 5. Governance Reforms: Medium (60%), Implement participatory budgeting and community outreach programs to ensure inclusive decision-making.
#
# Note: A comprehensive, multi-year implementation plan will require ongoing monitoring, adaptation, and fine-tuning to achieve the planned outcomes. This plan provides a starting point for the city to prioritize their adaptations.
#
#
#
# The judge ranked the competitors as follows:
#
# {"results": ["1", "3", "4", "5", "2", "6"]}
#
# Now respond with either "I agree" or "I disagree" with your comments on why the judge got it wrong

# %%
reviewer_messages = [{"role": "user", "content": reviewer}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=reviewer_messages,
)
review = response.choices[0].message.content
print(review)
# Out:
# I agree.
#
# Reasoning:
# - Competitor 1 (rank 1): Correct top pick. Their response is the most complete and actionable: full budgeting to $2.0B, phased timing, quantified expected outcomes, clear assumptions with probability ranges, specific top failure modes with contingencies, a rigorous randomized encouragement pilot, five monitoring indicators with thresholds, and a two‑discount‑rate cost‑benefit laid out. Coverage and defensibility are superior to others.
#
# - Competitor 3 (rank 2): Reasonable second. Strong layered strategy, good phase/budget breakdown, explicit equity targets, and a viable pilot and monitoring framework. Slightly less granular on some monetized CBA details than #1, so second place is appropriate.
#
# - Competitor 4 (rank 3): Good, crisp plan with clear budget, monitoring thresholds, and practicality (contingency reserves, governance). Fewer long‑run monetized scenarios than #1/#3 but high clarity and good trade‑offs—appropriate as third.
#
# - Competitor 5 (rank 4): Solid and pragmatic (clear table, large seawall option, quantified outcomes), but heavier on a single hard‑infrastructure choice and less nuanced on buyout pilots and failure‑mode mitigations than the top three. Placing it fourth is defensible.
#
# - Competitor 2 (rank 5): Contains many strong, technical elements and a sensible phased funding approach, but the submission is noticeably truncated/incomplete (mid‑Phase 3 cut‑off) and lacks fully articulated final sections and comprehensive CBA/monitoring. That incompleteness justifies dropping it below the more polished #4 and #5.
#
# - Competitor 6 (rank 6): Correct last. Response is inconsistent (internal budget errors and contradictory numbers), many claims lack defensible quantification or clear timing, and the cost‑benefit/accounting appears unreliable. It fails to meet the brief’s requirements compared with the others.
#
# Overall the judge’s ranking aligns with quality, completeness, defensibility, and fidelity to the prompt; the main downgrade decision—placing Competitor 2 below 4 and 5—is justified by its incomplete submission, and placing Competitor 6 last is clearly warranted.

# %%
while "I agree" not in review:
    judge = f"""You are judging a competition between {len(competitors)} competitors.
    Each model has been given this question:

    {question}

    Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
    Respond with JSON, and only JSON, with the following format:
    {{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

    Here are the responses from each competitor:

    {together}

    Your peer reviewer disagrees with your ranking with the following comments:

    {review}

    Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

    judge_messages = [{"role": "user", "content": judge}]
    openai = OpenAI()
    response = openai.chat.completions.create(
        model="gpt-5-mini",
        messages=judge_messages,
    )
    results = response.choices[0].message.content
    print(results)

    reviewer = f"""You are the peer reviewer of a competition result between {len(competitors)} competitors.
    Each model has been given this question:

    {question}

    Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
    Respond with JSON, and only JSON, with the following format:
    {{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

    Here are the responses from each competitor:

    {together}

    The judge ranked the competitors as follows:

    {results}

    Now respond with either "I agree", nothing else, or "I disagree" with your comments on why the judge got it wrong. Provide comments only when you disagree."""

    reviewer_messages = [{"role": "user", "content": reviewer}]
    openai = OpenAI()
    response = openai.chat.completions.create(
        model="gpt-5-mini",
        messages=reviewer_messages,
    )
    review = response.choices[0].message.content
    print(review)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gpt-5-nano
# Rank 2: gemini-2.5-flash
# Rank 3: deepseek-chat
# Rank 4: openai/gpt-oss-120b
# Rank 5: claude-sonnet-4-5
# Rank 6: llama3.2

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
